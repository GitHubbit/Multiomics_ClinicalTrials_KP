# %%
# display cells to maximum width 
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))

# lets you preint multiple outputs per cell, not just last
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>

# %%
#!/usr/bin/env conda run -n ct_extract_env python

import pandas as pd
import os
import json

def parse_edges(data_folder):
    filename = "ClinTrials_KG_edges_v01_3.csv"
    filepath = os.path.join(data_folder, filename)

    edges = pd.read_csv(filepath, sep='\t')
    for index, row in edges.iterrows():
        id_dict = {}
        subject_dict = {}
        association_dict = {}
        object_dict = {}
        source_dict = {}

        # id generated by concatenating the following: numbers from nctid, CUI of subject, CUI of object
        id_dict["_id"] = "{}_{}_{}".format(row["nctid"].split("NCT")[1], row["subject"].split(':')[1], row["object"].split(':')[1])

        subject_dict["{}".format(row["subject"].split(':')[0])] = "{}".format(row["subject"].split(':')[1])
        subject_dict["name"] = row["subject_name"]
        # subject_dict["{}_semantic_types".format(row["subject"].split(':')[0])] = "TBD" # fix in next version
        subject_dict["type"] = "Disease"

        association_dict["predicate"] = "{}".format(row["predicate"].split(':')[1])
        association_dict["edge_attributes"] = []
        association_dict["edge_attributes"].append(
            {"attribute_type_id":"clinicaltrials_id",
             "value":row["nctid"]
            }
        )
        association_dict["edge_attributes"].append(
            {"attribute_type_id":"biolink:aggregator_knowledge_source",
             "value":"infores:biothings-multiomics-clinicaltrials"}
        )
        association_dict["edge_attributes"].append(
            {"attribute_type_id": "biolink:primary_knowledge_source",
             "value": "infores:aact"}
        )
        association_dict["edge_attributes"].append(
            {"attribute_type_id": "biolink:supporting_data_source",
             "value": "infores:clinicaltrials"})

        object_dict["{}".format(row["object"].split(':')[0])] = "{}".format(row["object"].split(':')[1])
        object_dict["name"] = row["object_name"]
        object_dict["type"] = "Treatment"
        # object_dict["{}_semantic_types".format(row["object"].split(':')[0])] = "TBD" # fix in next version
        
        source_dict["edge_sources"] = []
        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:biothings-multiomics-clinicaltrials",
                "resource_role": "aggregator_knowledge_source"
            }
        )
        
        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:aact",
                "resource_role": "primary_knowledge_source"
            }
        )
        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:clinicaltrials",
                "resource_role": "supporting_data_source"
            }
        )

        id_dict["subject"] = subject_dict
        id_dict["association"] = association_dict
        id_dict["object"] = object_dict 
        id_dict["source"] = source_dict
        
        # print(json.dumps(id_dict, indent=2)) # uncomment for testing

        # yield the JSON one by one
        yield id_dict # comment for testing

# data_folder = "../outputs" # uncomment for testing
# parse_edges(data_folder) # uncomment for testing

# %%
#!/usr/bin/env conda run -n ct_extract_env python

import pandas as pd
import os
import json

# %%
data_folder = "./outputs/version_1" # uncomment for testing
filename = "ClinTrials_KG_edges_v01_3.csv"
filepath = os.path.join(data_folder, filename)

edges = pd.read_csv(filepath, sep='\t')
edges.head()
# Out:
#          subject           predicate         object         subject_name  \
# 0  UMLS:C0011848  biolink:related_to  UMLS:C0025598   diabetes insipidus
# 1  UMLS:C1527344  biolink:related_to  UMLS:C1660599            dysphonia
# 2  UMLS:C0238441  biolink:related_to  UMLS:C1660599  subglottic stenosis
# 3  UMLS:C0042940  biolink:related_to  UMLS:C1660599      voice disorders
# 4  UMLS:C0016658  biolink:related_to  UMLS:C0025605             fracture
#
#         object_name             category        nctid  \
# 0         metformin  biolink:Association  NCT02460354
# 1  videofluoroscopy  biolink:Association  NCT04584658
# 2  videofluoroscopy  biolink:Association  NCT04584658
# 3  videofluoroscopy  biolink:Association  NCT04584658
# 4         methadone  biolink:Association  NCT00892606
#
#                   nctid_curie
# 0  clinicaltrials:NCT02460354
# 1  clinicaltrials:NCT04584658
# 2  clinicaltrials:NCT04584658
# 3  clinicaltrials:NCT04584658
# 4  clinicaltrials:NCT00892606

# %%
edges.rename(columns={'subject': 'disease', 'object': 'intervention', 'subject_name': 'disease_name', 'object_name': 'intervention_name'}, inplace=True)
edges.rename(columns={'disease': 'object', 'intervention': 'subject', 'disease_name': 'object_name', 'intervention_name': 'subject_name'}, inplace=True)
edges.head()
# Out:
#           object           predicate        subject          object_name  \
# 0  UMLS:C0011848  biolink:related_to  UMLS:C0025598   diabetes insipidus
# 1  UMLS:C1527344  biolink:related_to  UMLS:C1660599            dysphonia
# 2  UMLS:C0238441  biolink:related_to  UMLS:C1660599  subglottic stenosis
# 3  UMLS:C0042940  biolink:related_to  UMLS:C1660599      voice disorders
# 4  UMLS:C0016658  biolink:related_to  UMLS:C0025605             fracture
#
#        subject_name             category        nctid  \
# 0         metformin  biolink:Association  NCT02460354
# 1  videofluoroscopy  biolink:Association  NCT04584658
# 2  videofluoroscopy  biolink:Association  NCT04584658
# 3  videofluoroscopy  biolink:Association  NCT04584658
# 4         methadone  biolink:Association  NCT00892606
#
#                   nctid_curie
# 0  clinicaltrials:NCT02460354
# 1  clinicaltrials:NCT04584658
# 2  clinicaltrials:NCT04584658
# 3  clinicaltrials:NCT04584658
# 4  clinicaltrials:NCT00892606

# %%
for index, row in edges[:10].iterrows():
    id_dict = {}
    subject_dict = {}
    association_dict = {}
    object_dict = {}
    source_dict = {}
    
    id_dict["_id"] = "{}_{}_{}".format(row["nctid"].split("NCT")[1], row["subject"].split(':')[1], row["object"].split(':')[1])
#     print(id_dict)
    
    subject_dict["{}".format(row["subject"].split(':')[0])] = "{}".format(row["subject"].split(':')[1])
    subject_dict["name"] = row["subject_name"]
    # subject_dict["{}_semantic_types".format(row["subject"].split(':')[0])] = "TBD" # fix in next version
    subject_dict["type"] = "biolink:Treatment"
#     print(subject_dict)
    
    association_dict["predicate"] = "{}".format(row["predicate"].split(':')[1])
    association_dict["edge_attributes"] = []
    association_dict["edge_attributes"].append(
        {"attribute_type_id":"clinicaltrials_id",
         "value":row["nctid"]
        }
    )
    association_dict["edge_attributes"].append(
        {"attribute_type_id":"biolink:aggregator_knowledge_source",
         "value":"infores:aact"}
        )
    association_dict["edge_attributes"].append(
        {"attribute_type_id": "biolink:primary_knowledge_source",
         "value": "infores:clinicaltrials"}
    )
    association_dict["edge_attributes"].append(
    {"attribute_type_id": "biolink:aggregator_knowledge_source",
     "value": "infores:biothings-multiomics-clinicaltrials"})
#     print(association_dict)
    
    object_dict["{}".format(row["object"].split(':')[0])] = "{}".format(row["object"].split(':')[1])
    object_dict["name"] = row["object_name"]
    object_dict["type"] = "biolink:DiseaseorPhenotypicFeature"
    # object_dict["{}_semantic_types".format(row["object"].split(':')[0])] = "TBD" # fix in next version
#     print(object_dict)

    source_dict["edge_sources"] = []
    source_dict["edge_sources"].append(
        {
            "resource_id": "infores:biothings-multiomics-clinicaltrials",
            "resource_role": "aggregator_knowledge_source"
        }
    )

    source_dict["edge_sources"].append(
        {
            "resource_id": "infores:aact",
            "resource_role": "aggregator_knowledge_source"
        }
    )
    source_dict["edge_sources"].append(
        {
            "resource_id": "infores:clinicaltrials",
            "resource_role": "primary_knowledge_source"
        }
    )
    
    id_dict["subject"] = subject_dict
    id_dict["association"] = association_dict
    id_dict["object"] = object_dict 
    id_dict["source"] = source_dict
    
    print(json.dumps(id_dict,sort_keys=True, indent=2))

    # yield the JSON one by one
#     yield id_dict # comment for testing
    
    
data_folder = "./outputs" # uncomment for testing
parse_edges(data_folder) # uncomment for testing
# Out:
# {
#   "_id": "02460354_C0025598_C0011848",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT02460354"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0011848",
#     "name": "diabetes insipidus",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0025598",
#     "name": "metformin",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C1527344",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C1527344",
#     "name": "dysphonia",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C0238441",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0238441",
#     "name": "subglottic stenosis",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C0042940",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0042940",
#     "name": "voice disorders",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892606_C0025605_C0016658",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892606"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0016658",
#     "name": "fracture",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0025605",
#     "name": "methadone",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892606_C0026549_C0016658",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892606"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0016658",
#     "name": "fracture",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0026549",
#     "name": "morphine",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C1876229_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1876229",
#     "name": "telaprevir",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C0391001_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0391001",
#     "name": "peginterferon alfa-2a",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C0035525_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0035525",
#     "name": "ribavirin",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00893113_C0051150_C0242350",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00893113"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0242350",
#     "name": "erectile dysfunction",
#     "type": "biolink:DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0051150",
#     "name": "alfuzosin",
#     "type": "biolink:Treatment"
#   }
# }
# ----------------------------------------------------------------------
# FileNotFoundError                    Traceback (most recent call last)
# <ipython-input-46-81a8f737c7bc> in <module>
#      74
#      75 data_folder = "../outputs" # uncomment for testing
# ---> 76 parse_edges(data_folder) # uncomment for testing
#      77
#
# <ipython-input-43-96842be8d140> in parse_edges(data_folder)
#       3     filepath = os.path.join(data_folder, filename)
#       4
# ----> 5     edges = pd.read_csv(filepath, sep='\t')
#       6     edges.rename(columns={'subject': 'disease', 'object': 'intervention', 'subject_name': 'disease_name', 'object_name': 'intervention_name'}, inplace=True)
#       7     edges.rename(columns={'disease': 'object', 'intervention': 'subject', 'disease_name': 'object_name', 'intervention_name': 'subject_name'}, inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../outputs/ClinTrials_KG_edges_v01_3.csv does not exist: '../outputs/ClinTrials_KG_edges_v01_3.csv'

# %%
def parse_edges(data_folder):
    filename = "ClinTrials_KG_edges_v01_3.csv"
    filepath = os.path.join(data_folder, filename)

    edges = pd.read_csv(filepath, sep='\t')
    edges.rename(columns={'subject': 'disease', 'object': 'intervention', 'subject_name': 'disease_name', 'object_name': 'intervention_name'}, inplace=True)
    edges.rename(columns={'disease': 'object', 'intervention': 'subject', 'disease_name': 'object_name', 'intervention_name': 'subject_name'}, inplace=True)

    for index, row in edges[:10].iterrows():
        id_dict = {}
        subject_dict = {}
        association_dict = {}
        object_dict = {}
        source_dict = {}

        id_dict["_id"] = "{}_{}_{}".format(row["nctid"].split("NCT")[1], row["subject"].split(':')[1], row["object"].split(':')[1])

        subject_dict["{}".format(row["subject"].split(':')[0])] = "{}".format(row["subject"].split(':')[1])
        subject_dict["name"] = row["subject_name"]
        # subject_dict["{}_semantic_types".format(row["subject"].split(':')[0])] = "TBD" # fix in next version
        subject_dict["type"] = "biolink:Treatment"

        association_dict["predicate"] = "{}".format(row["predicate"].split(':')[1])
        association_dict["edge_attributes"] = []
        association_dict["edge_attributes"].append(
            {"attribute_type_id":"clinicaltrials_id",
             "value":row["nctid"]
            }
        )
        association_dict["edge_attributes"].append(
            {"attribute_type_id":"biolink:aggregator_knowledge_source",
             "value":"infores:aact"}
            )
        association_dict["edge_attributes"].append(
            {"attribute_type_id": "biolink:primary_knowledge_source",
             "value": "infores:clinicaltrials"}
        )
        association_dict["edge_attributes"].append(
        {"attribute_type_id": "biolink:aggregator_knowledge_source",
         "value": "infores:biothings-multiomics-clinicaltrials"})

        object_dict["{}".format(row["object"].split(':')[0])] = "{}".format(row["object"].split(':')[1])
        object_dict["name"] = row["object_name"]
        object_dict["type"] = "DiseaseorPhenotypicFeature"
        # object_dict["{}_semantic_types".format(row["object"].split(':')[0])] = "TBD" # fix in next version

        source_dict["edge_sources"] = []
        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:biothings-multiomics-clinicaltrials",
                "resource_role": "aggregator_knowledge_source"
            }
        )

        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:aact",
                "resource_role": "aggregator_knowledge_source"
            }
        )
        source_dict["edge_sources"].append(
            {
                "resource_id": "infores:clinicaltrials",
                "resource_role": "primary_knowledge_source"
            }
        )

        id_dict["subject"] = subject_dict
        id_dict["association"] = association_dict
        id_dict["object"] = object_dict 
        id_dict["source"] = source_dict

        print(json.dumps(id_dict,sort_keys=True, indent=2))

        # yield the JSON one by one
#         yield id_dict # comment for testing
        
def main():
    data_folder = "../outputs/version_1" # uncomment for testing
    parse_edges(data_folder) # uncomment for testing

if __name__ == "__main__":
    main()
# Out:
# {
#   "_id": "02460354_C0025598_C0011848",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT02460354"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0011848",
#     "name": "diabetes insipidus",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0025598",
#     "name": "metformin",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C1527344",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C1527344",
#     "name": "dysphonia",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C0238441",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0238441",
#     "name": "subglottic stenosis",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "04584658_C1660599_C0042940",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT04584658"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0042940",
#     "name": "voice disorders",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1660599",
#     "name": "videofluoroscopy",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892606_C0025605_C0016658",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892606"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0016658",
#     "name": "fracture",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0025605",
#     "name": "methadone",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892606_C0026549_C0016658",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892606"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0016658",
#     "name": "fracture",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0026549",
#     "name": "morphine",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C1876229_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C1876229",
#     "name": "telaprevir",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C0391001_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0391001",
#     "name": "peginterferon alfa-2a",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00892697_C0035525_C0019196",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00892697"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0019196",
#     "name": "hepatitis c",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0035525",
#     "name": "ribavirin",
#     "type": "biolink:Treatment"
#   }
# }
# {
#   "_id": "00893113_C0051150_C0242350",
#   "association": {
#     "edge_attributes": [
#       {
#         "attribute_type_id": "clinicaltrials_id",
#         "value": "NCT00893113"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:aact"
#       },
#       {
#         "attribute_type_id": "biolink:primary_knowledge_source",
#         "value": "infores:clinicaltrials"
#       },
#       {
#         "attribute_type_id": "biolink:aggregator_knowledge_source",
#         "value": "infores:biothings-multiomics-clinicaltrials"
#       }
#     ],
#     "predicate": "related_to"
#   },
#   "object": {
#     "UMLS": "C0242350",
#     "name": "erectile dysfunction",
#     "type": "DiseaseorPhenotypicFeature"
#   },
#   "source": {
#     "edge_sources": [
#       {
#         "resource_id": "infores:biothings-multiomics-clinicaltrials",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:aact",
#         "resource_role": "aggregator_knowledge_source"
#       },
#       {
#         "resource_id": "infores:clinicaltrials",
#         "resource_role": "primary_knowledge_source"
#       }
#     ]
#   },
#   "subject": {
#     "UMLS": "C0051150",
#     "name": "alfuzosin",
#     "type": "biolink:Treatment"
#   }
# }

# %% [markdown]
# # Section is to tie Adverse Events and Phase to Version 1.3 TSVs

# %%
import pandas as pd
import os
import json

# %%
data_folder = "./outputs/version_1" # uncomment for testing
filename = "ClinTrials_KG_edges_v01_3.csv"
filepath = os.path.join(data_folder, filename)

edges = pd.read_csv(filepath, sep='\t')
edges
# Out:
#              subject           predicate         object  \
# 0      UMLS:C0011848  biolink:related_to  UMLS:C0025598
# 1      UMLS:C1527344  biolink:related_to  UMLS:C1660599
# 2      UMLS:C0238441  biolink:related_to  UMLS:C1660599
# 3      UMLS:C0042940  biolink:related_to  UMLS:C1660599
# 4      UMLS:C0016658  biolink:related_to  UMLS:C0025605
# ...              ...                 ...            ...
# 55308  UMLS:C4288754  biolink:related_to  UMLS:C2826354
# 55309  UMLS:C4721698  biolink:related_to  UMLS:C1516615
# 55310  UMLS:C0410808  biolink:related_to  UMLS:C4507320
# 55311  UMLS:C0017638  biolink:related_to  UMLS:C5207035
# 55312  UMLS:C0017638  biolink:related_to  UMLS:C2709220
#
#                           subject_name          object_name  \
# 0                   diabetes insipidus            metformin
# 1                            dysphonia     videofluoroscopy
# 2                  subglottic stenosis     videofluoroscopy
# 3                      voice disorders     videofluoroscopy
# 4                             fracture            methadone
# ...                                ...                  ...
# 55308  metastatic urothelial carcinoma     ixazomib citrate
# 55309  metastatic renal cell carcinoma  clinical management
# 55310       prosthetic joint infection             tnp-2092
# 55311                           glioma               fitbit
# 55312                           glioma            pedometer
#
#                   category        nctid                 nctid_curie
# 0      biolink:Association  NCT02460354  clinicaltrials:NCT02460354
# 1      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 2      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 3      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 4      biolink:Association  NCT00892606  clinicaltrials:NCT00892606
# ...                    ...          ...                         ...
# 55308  biolink:Association  NCT02420847  clinicaltrials:NCT02420847
# 55309  biolink:Association  NCT04467021  clinicaltrials:NCT04467021
# 55310  biolink:Association  NCT04294862  clinicaltrials:NCT04294862
# 55311  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
# 55312  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
#
# [55313 rows x 8 columns]

# %%
data_extracted = "/Users/Kamileh/Work/ISB/NCATS_BiomedicalTranslator/Projects/ClinicalTrials/ETL_Python/data/08_21_2023_extracted"
reported_event_totals = pd.read_csv(data_extracted + '/reported_event_totals.txt', sep='|', index_col=False, header=0)
studies = pd.read_csv(data_extracted + '/studies.txt', sep='|', index_col=False, header=0)
reported_event_totals
with pd.option_context('display.max_rows', 20, 'display.max_columns', None): 
    display(studies)
# Out:
# /Users/Kamileh/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (46,47,48,53,68,69) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               id       nct_id ctgov_group_code event_type  \
# 0       28806901  NCT00045942            EG000    serious
# 1       28806902  NCT00045942            EG000      other
# 2       28806903  NCT00045942            EG000     deaths
# 3       28806904  NCT00045942            EG001    serious
# 4       28806905  NCT00045942            EG001      other
# ...          ...          ...              ...        ...
# 434338  28980863  NCT01059357            EG000      other
# 434339  28980864  NCT01059357            EG000     deaths
# 434340  28980865  NCT01360398            EG000    serious
# 434341  28980866  NCT01360398            EG000      other
# 434342  28980867  NCT01360398            EG000     deaths
#
#                        classification  subjects_affected  subjects_at_risk  \
# 0       Total, serious adverse events               12.0              20.0
# 1         Total, other adverse events               20.0              20.0
# 2          Total, all-cause mortality                NaN               NaN
# 3       Total, serious adverse events               16.0              18.0
# 4         Total, other adverse events               17.0              18.0
# ...                               ...                ...               ...
# 434338    Total, other adverse events                7.0              54.0
# 434339     Total, all-cause mortality                0.0              54.0
# 434340  Total, serious adverse events                0.0             127.0
# 434341    Total, other adverse events                0.0               0.0
# 434342     Total, all-cause mortality                0.0             127.0
#
#                         created_at                  updated_at
# 0       2023-08-18 18:18:16.215445  2023-08-18 18:18:16.215445
# 1       2023-08-18 18:18:16.215445  2023-08-18 18:18:16.215445
# 2       2023-08-18 18:18:16.215445  2023-08-18 18:18:16.215445
# 3       2023-08-18 18:18:16.215445  2023-08-18 18:18:16.215445
# 4       2023-08-18 18:18:16.215445  2023-08-18 18:18:16.215445
# ...                            ...                         ...
# 434338  2023-08-20 19:01:55.927501  2023-08-20 19:01:55.927501
# 434339  2023-08-20 19:01:55.927501  2023-08-20 19:01:55.927501
# 434340  2023-08-20 19:01:58.615882  2023-08-20 19:01:58.615882
# 434341  2023-08-20 19:01:58.615882  2023-08-20 19:01:58.615882
# 434342  2023-08-20 19:01:58.615882  2023-08-20 19:01:58.615882
#
# [434343 rows x 9 columns]
#              nct_id  nlm_download_date_description study_first_submitted_date  \
# 0       NCT03971825                            NaN                 2019-05-31
# 1       NCT04856488                            NaN                 2021-04-06
# 2       NCT01126554                            NaN                 2010-05-17
# 3       NCT01072019                            NaN                 2010-02-18
# 4       NCT01126632                            NaN                 2010-05-15
# ...             ...                            ...                        ...
# 462810  NCT03351387                            NaN                 2017-11-20
# 462811  NCT05165589                            NaN                 2021-10-15
# 462812  NCT01376674                            NaN                 2011-06-16
# 462813  NCT01126476                            NaN                 2010-05-17
# 462814  NCT04455555                            NaN                 2020-06-28
#
#        results_first_submitted_date disposition_first_submitted_date  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# ...                             ...                              ...
# 462810                          NaN                              NaN
# 462811                          NaN                              NaN
# 462812                          NaN                              NaN
# 462813                          NaN                              NaN
# 462814                          NaN                              NaN
#
#        last_update_submitted_date study_first_submitted_qc_date  \
# 0                      2021-08-24                    2019-05-31
# 1                      2022-01-18                    2021-04-19
# 2                      2014-04-28                    2010-05-18
# 3                      2018-06-25                    2010-02-18
# 4                      2016-01-27                    2010-05-18
# ...                           ...                           ...
# 462810                 2021-12-15                    2017-11-20
# 462811                 2021-12-14                    2021-12-14
# 462812                 2013-08-15                    2011-06-16
# 462813                 2020-04-23                    2010-05-18
# 462814                 2020-07-01                    2020-07-01
#
#        study_first_posted_date study_first_posted_date_type  \
# 0                   2019-06-03                       Actual
# 1                   2021-04-23                       Actual
# 2                   2010-05-19                     Estimate
# 3                   2010-02-19                     Estimate
# 4                   2010-05-20                     Estimate
# ...                        ...                          ...
# 462810              2017-11-22                       Actual
# 462811              2021-12-21                       Actual
# 462812              2011-06-20                     Estimate
# 462813              2010-05-19                     Estimate
# 462814              2020-07-02                       Actual
#
#        results_first_submitted_qc_date results_first_posted_date  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 462810                             NaN                       NaN
# 462811                             NaN                       NaN
# 462812                             NaN                       NaN
# 462813                             NaN                       NaN
# 462814                             NaN                       NaN
#
#        results_first_posted_date_type disposition_first_submitted_qc_date  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
# ...                               ...                                 ...
# 462810                            NaN                                 NaN
# 462811                            NaN                                 NaN
# 462812                            NaN                                 NaN
# 462813                            NaN                                 NaN
# 462814                            NaN                                 NaN
#
#        disposition_first_posted_date disposition_first_posted_date_type  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# ...                              ...                                ...
# 462810                           NaN                                NaN
# 462811                           NaN                                NaN
# 462812                           NaN                                NaN
# 462813                           NaN                                NaN
# 462814                           NaN                                NaN
#
#        last_update_submitted_qc_date last_update_posted_date  \
# 0                         2021-08-24              2021-08-30
# 1                         2022-01-18              2022-01-19
# 2                         2014-04-28              2014-04-29
# 3                         2018-06-25              2018-06-27
# 4                         2016-01-27              2016-01-28
# ...                              ...                     ...
# 462810                    2021-12-15              2021-12-17
# 462811                    2021-12-14              2021-12-21
# 462812                    2013-08-15              2013-08-16
# 462813                    2020-04-23              2020-04-24
# 462814                    2020-07-01              2020-07-02
#
#        last_update_posted_date_type   start_month_year start_date_type  \
# 0                            Actual      July 24, 2018          Actual
# 1                            Actual  November 18, 2021          Actual
# 2                          Estimate          July 2010             NaN
# 3                            Actual         March 2010             NaN
# 4                          Estimate          June 2010             NaN
# ...                             ...                ...             ...
# 462810                       Actual   October 20, 2017          Actual
# 462811                       Actual   October 15, 2021          Actual
# 462812                     Estimate         March 2011             NaN
# 462813                       Actual      February 2010          Actual
# 462814                       Actual     August 1, 2018          Actual
#
#         start_date verification_month_year verification_date  \
# 0       2018-07-24             August 2021        2021-08-31
# 1       2021-11-18            January 2022        2022-01-31
# 2       2010-07-31              April 2014        2014-04-30
# 3       2010-03-31               June 2018        2018-06-30
# 4       2010-06-30            January 2016        2016-01-31
# ...            ...                     ...               ...
# 462810  2017-10-20           December 2021        2021-12-31
# 462811  2021-10-15           December 2021        2021-12-31
# 462812  2011-03-31             August 2013        2013-08-31
# 462813  2010-02-28              April 2020        2020-04-30
# 462814  2018-08-01               July 2020        2020-07-31
#
#        completion_month_year completion_date_type completion_date  \
# 0             August 5, 2021               Actual      2021-08-05
# 1              February 2024          Anticipated      2024-02-29
# 2              February 2011               Actual      2011-02-28
# 3                   May 2014               Actual      2014-05-31
# 4               January 2012               Actual      2012-01-31
# ...                      ...                  ...             ...
# 462810        April 18, 2018               Actual      2018-04-18
# 462811            April 2022          Anticipated      2022-04-30
# 462812                   NaN                  NaN             NaN
# 462813            April 2020               Actual      2020-04-30
# 462814      February 1, 2019               Actual      2019-02-01
#
#        primary_completion_month_year primary_completion_date_type  \
# 0                     August 5, 2021                       Actual
# 1                        August 2023                  Anticipated
# 2                      December 2010                       Actual
# 3                           May 2014                       Actual
# 4                       January 2012                       Actual
# ...                              ...                          ...
# 462810                April 18, 2018                       Actual
# 462811                  January 2022                  Anticipated
# 462812                           NaN                          NaN
# 462813                 February 2017                       Actual
# 462814              February 1, 2019                       Actual
#
#        primary_completion_date target_duration      study_type        acronym  \
# 0                   2021-08-05             NaN  Interventional            NaN
# 1                   2023-08-31             NaN  Interventional            NaN
# 2                   2010-12-31             NaN   Observational       Greenpep
# 3                   2014-05-31             NaN  Interventional  Cutting Block
# 4                   2012-01-31             NaN   Observational            CAC
# ...                        ...             ...             ...            ...
# 462810              2018-04-18             NaN   Observational            NaN
# 462811              2022-01-31             NaN  Interventional            NaN
# 462812                     NaN             NaN   Observational            NaN
# 462813              2017-02-28             NaN  Interventional            NaN
# 462814              2019-02-01             NaN  Interventional            NaN
#
#        baseline_population                                        brief_title  \
# 0                      NaN  A Safety Study of CC-92252 in Healthy Adult Su...
# 1                      NaN  Preoperative Lugol's Solution in Graves' Disea...
# 2                      NaN  ICG- Liver Test Versus New Biomarkers as Progn...
# 3                      NaN  A Randomized Prospective Trial of Total Knee A...
# 4                      NaN  Will Cap-Assisted Colonoscopy Improve Performa...
# ...                    ...                                                ...
# 462810                 NaN          Wound Necrosis in Lower Extremity Surgery
# 462811                 NaN  Validation of Active-Insights Device to Measur...
# 462812                 NaN  T-cell-immunity During Standard Radiotherapy i...
# 462813                 NaN           Proton Radiotherapy for Recurrent Tumors
# 462814                 NaN  Efficacy and Safety of Rotigotine in the Treat...
#
#                                            official_title overall_status  \
# 0       A Phase 1, Randomized, 3-Part Study to Evaluat...     Terminated
# 1       Preoperative Lugol's Solution in Graves' Disea...     Recruiting
# 2       ICG- Liver Test Versus New Biomarkers as Progn...      Completed
# 3       Comparative Clinical Study of the Vanguard® Kn...      Completed
# 4       Will Cap-Assisted Colonoscopy Improve Performa...      Withdrawn
# ...                                                   ...            ...
# 462810  Assessment of Wound Necrosis in Lower Extremit...      Completed
# 462811  Pilot & Exploratory - Validation of Active-Ins...     Recruiting
# 462812  Changes of T-cell-immune-status During Curativ...      Completed
# 462813  Retreatment of Recurrent Tumors Using Proton T...      Completed
# 462814  Efficacy and Safety of Rotigotine in the Treat...      Completed
#
#        last_known_status           phase  enrollment enrollment_type  \
# 0                    NaN         Phase 1       131.0          Actual
# 1                    NaN         Phase 3       182.0     Anticipated
# 2                    NaN             NaN       110.0     Anticipated
# 3                    NaN  Not Applicable        25.0          Actual
# 4                    NaN             NaN         0.0          Actual
# ...                  ...             ...         ...             ...
# 462810               NaN             NaN        10.0          Actual
# 462811               NaN  Not Applicable        13.0     Anticipated
# 462812               NaN             NaN        22.0          Actual
# 462813               NaN  Not Applicable        24.0     Anticipated
# 462814               NaN         Phase 3       294.0          Actual
#
#                                           source  limitations_and_caveats  \
# 0                                        Celgene                      NaN
# 1                 Karolinska University Hospital                      NaN
# 2                           University of Zurich                      NaN
# 3       Washington University School of Medicine                      NaN
# 4                   Nova Scotia Health Authority                      NaN
# ...                                          ...                      ...
# 462810                               Mayo Clinic                      NaN
# 462811                                BioGaia AB                      NaN
# 462812             University Hospital Tuebingen                      NaN
# 462813   Abramson Cancer Center at Penn Medicine                      NaN
# 462814          Peking University Third Hospital                      NaN
#
#         number_of_arms  number_of_groups  \
# 0                  2.0               NaN
# 1                  2.0               NaN
# 2                  NaN               1.0
# 3                  2.0               NaN
# 4                  NaN               2.0
# ...                ...               ...
# 462810             NaN               1.0
# 462811             2.0               NaN
# 462812             NaN               NaN
# 462813             2.0               NaN
# 462814             2.0               NaN
#
#                                     why_stopped has_expanded_access  \
# 0             Did not meet progression criteria                   f
# 1                                           NaN                   f
# 2                                           NaN                   f
# 3                                           NaN                   f
# 4       Caps became unavailable by manufacturer                   f
# ...                                         ...                 ...
# 462810                                      NaN                   f
# 462811                                      NaN                   f
# 462812                                      NaN                   f
# 462813                                      NaN                   f
# 462814                                      NaN                   f
#
#        expanded_access_type_individual expanded_access_type_intermediate  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 462810                             NaN                               NaN
# 462811                             NaN                               NaN
# 462812                             NaN                               NaN
# 462813                             NaN                               NaN
# 462814                             NaN                               NaN
#
#        expanded_access_type_treatment has_dmc is_fda_regulated_drug  \
# 0                                 NaN       f                     t
# 1                                 NaN     NaN                     f
# 2                                 NaN       t                   NaN
# 3                                 NaN       t                   NaN
# 4                                 NaN       f                   NaN
# ...                               ...     ...                   ...
# 462810                            NaN       f                     f
# 462811                            NaN     NaN                     f
# 462812                            NaN       f                   NaN
# 462813                            NaN       t                   NaN
# 462814                            NaN       f                     f
#
#        is_fda_regulated_device is_unapproved_device is_ppsd is_us_export  \
# 0                            f                  NaN     NaN            t
# 1                            f                  NaN     NaN          NaN
# 2                          NaN                  NaN     NaN          NaN
# 3                          NaN                  NaN     NaN          NaN
# 4                          NaN                  NaN     NaN          NaN
# ...                        ...                  ...     ...          ...
# 462810                       t                  NaN     NaN            f
# 462811                       f                  NaN     NaN          NaN
# 462812                     NaN                  NaN     NaN          NaN
# 462813                     NaN                  NaN     NaN          NaN
# 462814                       f                  NaN     NaN          NaN
#
#        biospec_retention                                biospec_description  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 462810               NaN                                                NaN
# 462811               NaN                                                NaN
# 462812  Samples With DNA  Peripheral blood mononuclear cells and serum a...
# 462813               NaN                                                NaN
# 462814               NaN                                                NaN
#
#                                            ipd_time_frame  \
# 0                                    See Plan Description
# 1       The original contributions presented in the st...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 462810                                                NaN
# 462811                                                NaN
# 462812                                                NaN
# 462813                                                NaN
# 462814                                                NaN
#
#                                       ipd_access_criteria  \
# 0                                    See Plan Description
# 1       Further inquiries can be directed to the corre...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 462810                                                NaN
# 462811                                                NaN
# 462812                                                NaN
# 462813                                                NaN
# 462814                                                NaN
#
#                                                   ipd_url plan_to_share_ipd  \
# 0       https://www.celgene.com/research-development/c...               Yes
# 1                                                     NaN               Yes
# 2                                                     NaN               NaN
# 3                                                     NaN               NaN
# 4                                                     NaN                No
# ...                                                   ...               ...
# 462810                                                NaN                No
# 462811                                                NaN                No
# 462812                                                NaN               NaN
# 462813                                                NaN               NaN
# 462814                                                NaN                No
#
#                             plan_to_share_ipd_description  \
# 0       Information relating to our policy on data sha...
# 1       The original contributions presented in the st...
# 2                                                     NaN
# 3                                                     NaN
# 4                                    Study was terminated
# ...                                                   ...
# 462810                                                NaN
# 462811                                                NaN
# 462812                                                NaN
# 462813                                                NaN
# 462814                                                NaN
#
#                         created_at                  updated_at source_class  \
# 0       2023-08-18 18:38:13.337008  2023-08-18 18:38:13.337008     INDUSTRY
# 1        2023-08-18 18:38:14.03975   2023-08-18 18:38:14.03975        OTHER
# 2       2023-08-18 18:38:14.723441  2023-08-18 18:38:14.723441        OTHER
# 3       2023-08-18 18:38:15.338961  2023-08-18 18:38:15.338961        OTHER
# 4       2023-08-18 18:38:15.961115  2023-08-18 18:38:15.961115        OTHER
# ...                            ...                         ...          ...
# 462810  2023-08-19 17:16:46.976535  2023-08-19 17:16:46.976535        OTHER
# 462811  2023-08-19 17:16:47.599338  2023-08-19 17:16:47.599338     INDUSTRY
# 462812  2023-08-18 18:38:11.032433  2023-08-18 18:38:11.032433        OTHER
# 462813  2023-08-18 18:38:11.639866  2023-08-18 18:38:11.639866        OTHER
# 462814  2023-08-19 17:16:48.670065  2023-08-19 17:16:48.670065        OTHER
#
#        delayed_posting expanded_access_nctid expanded_access_status_for_nctid  \
# 0                  NaN                   NaN                              NaN
# 1                  NaN                   NaN                              NaN
# 2                  NaN                   NaN                              NaN
# 3                  NaN                   NaN                              NaN
# 4                  NaN                   NaN                              NaN
# ...                ...                   ...                              ...
# 462810             NaN                   NaN                              NaN
# 462811             NaN                   NaN                              NaN
# 462812             NaN                   NaN                              NaN
# 462813             NaN                   NaN                              NaN
# 462814             NaN                   NaN                              NaN
#
#        fdaaa801_violation baseline_type_units_analyzed
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
# ...                   ...                          ...
# 462810                NaN                          NaN
# 462811                NaN                          NaN
# 462812                NaN                          NaN
# 462813                NaN                          NaN
# 462814                NaN                          NaN
#
# [462815 rows x 70 columns]

# %%
edges_phase = pd.merge(edges, studies[["nct_id", "study_first_posted_date", "updated_at", "overall_status", "phase", "enrollment", "number_of_arms",]], how='left', left_on=['nctid'], right_on = ['nct_id'])
edges_phase
# Out:
#              subject           predicate         object  \
# 0      UMLS:C0011848  biolink:related_to  UMLS:C0025598
# 1      UMLS:C1527344  biolink:related_to  UMLS:C1660599
# 2      UMLS:C0238441  biolink:related_to  UMLS:C1660599
# 3      UMLS:C0042940  biolink:related_to  UMLS:C1660599
# 4      UMLS:C0016658  biolink:related_to  UMLS:C0025605
# ...              ...                 ...            ...
# 55308  UMLS:C4288754  biolink:related_to  UMLS:C2826354
# 55309  UMLS:C4721698  biolink:related_to  UMLS:C1516615
# 55310  UMLS:C0410808  biolink:related_to  UMLS:C4507320
# 55311  UMLS:C0017638  biolink:related_to  UMLS:C5207035
# 55312  UMLS:C0017638  biolink:related_to  UMLS:C2709220
#
#                           subject_name          object_name  \
# 0                   diabetes insipidus            metformin
# 1                            dysphonia     videofluoroscopy
# 2                  subglottic stenosis     videofluoroscopy
# 3                      voice disorders     videofluoroscopy
# 4                             fracture            methadone
# ...                                ...                  ...
# 55308  metastatic urothelial carcinoma     ixazomib citrate
# 55309  metastatic renal cell carcinoma  clinical management
# 55310       prosthetic joint infection             tnp-2092
# 55311                           glioma               fitbit
# 55312                           glioma            pedometer
#
#                   category        nctid                 nctid_curie  \
# 0      biolink:Association  NCT02460354  clinicaltrials:NCT02460354
# 1      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 2      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 3      biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 4      biolink:Association  NCT00892606  clinicaltrials:NCT00892606
# ...                    ...          ...                         ...
# 55308  biolink:Association  NCT02420847  clinicaltrials:NCT02420847
# 55309  biolink:Association  NCT04467021  clinicaltrials:NCT04467021
# 55310  biolink:Association  NCT04294862  clinicaltrials:NCT04294862
# 55311  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
# 55312  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
#
#             nct_id study_first_posted_date                  updated_at  \
# 0      NCT02460354              2015-06-02   2023-08-20 15:40:47.06955
# 1      NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 2      NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 3      NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 4      NCT00892606              2009-05-04  2023-08-20 13:43:38.732535
# ...            ...                     ...                         ...
# 55308  NCT02420847              2015-04-20  2023-08-19 20:09:24.997057
# 55309  NCT04467021              2020-07-10  2023-08-20 06:10:43.735458
# 55310  NCT04294862              2020-03-04  2023-08-21 00:35:27.952944
# 55311  NCT04186832              2019-12-05  2023-08-18 18:17:52.108033
# 55312  NCT04186832              2019-12-05  2023-08-18 18:17:52.108033
#
#                overall_status            phase  enrollment  number_of_arms
# 0                  Terminated          Phase 1         2.0             1.0
# 1              Unknown status              NaN        36.0             NaN
# 2              Unknown status              NaN        36.0             NaN
# 3              Unknown status              NaN        36.0             NaN
# 4                   Completed          Phase 4        75.0             2.0
# ...                       ...              ...         ...             ...
# 55308  Active, not recruiting  Phase 1/Phase 2        57.0             1.0
# 55309              Recruiting   Not Applicable        60.0             2.0
# 55310               Completed          Phase 1        13.0             1.0
# 55311              Recruiting   Not Applicable        50.0             2.0
# 55312              Recruiting   Not Applicable        50.0             2.0
#
# [55313 rows x 15 columns]

# %%
reported_event_totals.loc[reported_event_totals['nct_id'] == 'NCT00000125']

test = reported_event_totals.pivot(index=['nct_id', 'id'], columns='event_type', values=['subjects_affected', 'subjects_at_risk'])
test
# Out:
#               id       nct_id ctgov_group_code event_type  \
# 219226  28868500  NCT00000125            EG000    serious
# 219227  28868501  NCT00000125            EG000      other
# 219228  28868502  NCT00000125            EG000     deaths
# 219229  28868503  NCT00000125            EG001    serious
# 219230  28868504  NCT00000125            EG001      other
# 219231  28868505  NCT00000125            EG001     deaths
#
#                        classification  subjects_affected  subjects_at_risk  \
# 219226  Total, serious adverse events               12.0             819.0
# 219227    Total, other adverse events              481.0             819.0
# 219228     Total, all-cause mortality                NaN               NaN
# 219229  Total, serious adverse events               13.0             817.0
# 219230    Total, other adverse events              570.0             817.0
# 219231     Total, all-cause mortality                NaN               NaN
#
#                        created_at                 updated_at
# 219226  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
# 219227  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
# 219228  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
# 219229  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
# 219230  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
# 219231  2023-08-19 17:37:46.39051  2023-08-19 17:37:46.39051
#                      subjects_affected                subjects_at_risk         \
# event_type                      deaths  other serious           deaths  other
# nct_id      id
# NCT00000125 28868500               NaN    NaN    12.0              NaN    NaN
#             28868501               NaN  481.0     NaN              NaN  819.0
#             28868502               NaN    NaN     NaN              NaN    NaN
#             28868503               NaN    NaN    13.0              NaN    NaN
#             28868504               NaN  570.0     NaN              NaN  817.0
# ...                                ...    ...     ...              ...    ...
# NCT05890586 28732502               NaN    0.0     NaN              NaN  583.0
#             28732503               0.0    NaN     NaN            583.0    NaN
# NCT05940077 28891636               NaN    NaN     0.0              NaN    NaN
#             28891637               NaN    0.0     NaN              NaN   20.0
#             28891638               0.0    NaN     NaN             20.0    NaN
#
#
# event_type           serious
# nct_id      id
# NCT00000125 28868500   819.0
#             28868501     NaN
#             28868502     NaN
#             28868503   817.0
#             28868504     NaN
# ...                      ...
# NCT05890586 28732502     NaN
#             28732503     NaN
# NCT05940077 28891636    20.0
#             28891637     NaN
#             28891638     NaN
#
# [434343 rows x 6 columns]

# %%
# test.columns = test.columns.map('|'.join).str.strip('|')
test.columns = test.columns.map(lambda x: f'{x[0]} - {x[1]}')
test = test.reset_index(level=1, drop=True)
test = test.reset_index()
test=test.groupby('nct_id').sum().reset_index()


test
# Out:
#             nct_id  subjects_affected - deaths  subjects_affected - other  \
# 0      NCT00000125                         0.0                     1051.0
# 1      NCT00000134                         0.0                       24.0
# 2      NCT00000135                         0.0                        0.0
# 3      NCT00000136                         0.0                        0.0
# 4      NCT00000142                         0.0                        4.0
# ...            ...                         ...                        ...
# 59451  NCT05838456                        57.0                       34.0
# 59452  NCT05867342                         0.0                        0.0
# 59453  NCT05887388                         1.0                        0.0
# 59454  NCT05890586                         0.0                        0.0
# 59455  NCT05940077                         0.0                        0.0
#
#        subjects_affected - serious  subjects_at_risk - deaths  \
# 0                             25.0                        0.0
# 1                            124.0                        0.0
# 2                              0.0                        0.0
# 3                            133.0                        0.0
# 4                             24.0                        0.0
# ...                            ...                        ...
# 59451                          9.0                      243.0
# 59452                          0.0                       80.0
# 59453                          2.0                       38.0
# 59454                          9.0                     1229.0
# 59455                          0.0                       20.0
#
#        subjects_at_risk - other  subjects_at_risk - serious
# 0                        1636.0                      1636.0
# 1                         274.0                       274.0
# 2                         209.0                       209.0
# 3                         234.0                       234.0
# 4                          64.0                        64.0
# ...                         ...                         ...
# 59451                     243.0                       243.0
# 59452                      80.0                        80.0
# 59453                      38.0                        38.0
# 59454                    1229.0                      1229.0
# 59455                      20.0                        20.0
#
# [59456 rows x 7 columns]

# %%
test
# Out:
#                       subjects_affected - deaths  subjects_affected - other  \
# nct_id      id
# NCT00000125 28868500                         NaN                        NaN
#             28868501                         NaN                      481.0
#             28868502                         NaN                        NaN
#             28868503                         NaN                        NaN
#             28868504                         NaN                      570.0
# ...                                          ...                        ...
# NCT05890586 28732502                         NaN                        0.0
#             28732503                         0.0                        NaN
# NCT05940077 28891636                         NaN                        NaN
#             28891637                         NaN                        0.0
#             28891638                         0.0                        NaN
#
#                       subjects_affected - serious  subjects_at_risk - deaths  \
# nct_id      id
# NCT00000125 28868500                         12.0                        NaN
#             28868501                          NaN                        NaN
#             28868502                          NaN                        NaN
#             28868503                         13.0                        NaN
#             28868504                          NaN                        NaN
# ...                                           ...                        ...
# NCT05890586 28732502                          NaN                        NaN
#             28732503                          NaN                      583.0
# NCT05940077 28891636                          0.0                        NaN
#             28891637                          NaN                        NaN
#             28891638                          NaN                       20.0
#
#                       subjects_at_risk - other  subjects_at_risk - serious
# nct_id      id
# NCT00000125 28868500                       NaN                       819.0
#             28868501                     819.0                         NaN
#             28868502                       NaN                         NaN
#             28868503                       NaN                       817.0
#             28868504                     817.0                         NaN
# ...                                        ...                         ...
# NCT05890586 28732502                     583.0                         NaN
#             28732503                       NaN                         NaN
# NCT05940077 28891636                       NaN                        20.0
#             28891637                      20.0                         NaN
#             28891638                       NaN                         NaN
#
# [434343 rows x 6 columns]

# %%
test.reset_index(level = "nct_id", inplace=True)
test.columns = test.columns.map('|'.join).str.strip('|')
test.reset_index(drop=True)
# test = test.drop('id', axis=1)

test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/49/18qlr0bn7xg_mk2pzxvrb0f80000gn/T/ipykernel_11476/3050403264.py in <module>
# ----> 1 test.reset_index(level = "nct_id", inplace=True)
#       2 test.columns = test.columns.map('|'.join).str.strip('|')
#       3 test.reset_index(drop=True)
#       4 test.reset_index(level=1, drop=True).stack().unstack()
#       5 # test = test.drop('id', axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4975             if not isinstance(level, (tuple, list)):
#    4976                 level = [level]
# -> 4977             level = [self.index._get_level_number(lev) for lev in level]
#    4978             if len(level) < self.index.nlevels:
#    4979                 new_index = self.index.droplevel(level)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4975             if not isinstance(level, (tuple, list)):
#    4976                 level = [level]
# -> 4977             level = [self.index._get_level_number(lev) for lev in level]
#    4978             if len(level) < self.index.nlevels:
#    4979                 new_index = self.index.droplevel(level)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1482
#    1483     def _get_level_number(self, level) -> int:
# -> 1484         self._validate_index_level(level)
#    1485         return 0
#    1486
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1478         elif level != self.name:
#    1479             raise KeyError(
# -> 1480                 f"Requested level ({level}) does not match index name ({self.name})"
#    1481             )
#    1482
#
# KeyError: 'Requested level (nct_id) does not match index name (id)'

# %%
edges_phase_adv = pd.merge(edges_phase, reported_event_totals[["nct_id",  "event_type", "subjects_affected", "subjects_at_risk"]], how='left', left_on=['nct_id'], right_on = ['nct_id'])

edges_phase_adv
# Out:
#               subject           predicate         object  \
# 0       UMLS:C0011848  biolink:related_to  UMLS:C0025598
# 1       UMLS:C1527344  biolink:related_to  UMLS:C1660599
# 2       UMLS:C0238441  biolink:related_to  UMLS:C1660599
# 3       UMLS:C0042940  biolink:related_to  UMLS:C1660599
# 4       UMLS:C0016658  biolink:related_to  UMLS:C0025605
# ...               ...                 ...            ...
# 132193  UMLS:C4288754  biolink:related_to  UMLS:C2826354
# 132194  UMLS:C4721698  biolink:related_to  UMLS:C1516615
# 132195  UMLS:C0410808  biolink:related_to  UMLS:C4507320
# 132196  UMLS:C0017638  biolink:related_to  UMLS:C5207035
# 132197  UMLS:C0017638  biolink:related_to  UMLS:C2709220
#
#                            subject_name          object_name  \
# 0                    diabetes insipidus            metformin
# 1                             dysphonia     videofluoroscopy
# 2                   subglottic stenosis     videofluoroscopy
# 3                       voice disorders     videofluoroscopy
# 4                              fracture            methadone
# ...                                 ...                  ...
# 132193  metastatic urothelial carcinoma     ixazomib citrate
# 132194  metastatic renal cell carcinoma  clinical management
# 132195       prosthetic joint infection             tnp-2092
# 132196                           glioma               fitbit
# 132197                           glioma            pedometer
#
#                    category        nctid                 nctid_curie  \
# 0       biolink:Association  NCT02460354  clinicaltrials:NCT02460354
# 1       biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 2       biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 3       biolink:Association  NCT04584658  clinicaltrials:NCT04584658
# 4       biolink:Association  NCT00892606  clinicaltrials:NCT00892606
# ...                     ...          ...                         ...
# 132193  biolink:Association  NCT02420847  clinicaltrials:NCT02420847
# 132194  biolink:Association  NCT04467021  clinicaltrials:NCT04467021
# 132195  biolink:Association  NCT04294862  clinicaltrials:NCT04294862
# 132196  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
# 132197  biolink:Association  NCT04186832  clinicaltrials:NCT04186832
#
#              nct_id study_first_posted_date                  updated_at  \
# 0       NCT02460354              2015-06-02   2023-08-20 15:40:47.06955
# 1       NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 2       NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 3       NCT04584658              2020-10-14  2023-08-17 06:36:34.213937
# 4       NCT00892606              2009-05-04  2023-08-20 13:43:38.732535
# ...             ...                     ...                         ...
# 132193  NCT02420847              2015-04-20  2023-08-19 20:09:24.997057
# 132194  NCT04467021              2020-07-10  2023-08-20 06:10:43.735458
# 132195  NCT04294862              2020-03-04  2023-08-21 00:35:27.952944
# 132196  NCT04186832              2019-12-05  2023-08-18 18:17:52.108033
# 132197  NCT04186832              2019-12-05  2023-08-18 18:17:52.108033
#
#                 overall_status            phase  enrollment  number_of_arms  \
# 0                   Terminated          Phase 1         2.0             1.0
# 1               Unknown status              NaN        36.0             NaN
# 2               Unknown status              NaN        36.0             NaN
# 3               Unknown status              NaN        36.0             NaN
# 4                    Completed          Phase 4        75.0             2.0
# ...                        ...              ...         ...             ...
# 132193  Active, not recruiting  Phase 1/Phase 2        57.0             1.0
# 132194              Recruiting   Not Applicable        60.0             2.0
# 132195               Completed          Phase 1        13.0             1.0
# 132196              Recruiting   Not Applicable        50.0             2.0
# 132197              Recruiting   Not Applicable        50.0             2.0
#
#        event_type  subjects_affected  subjects_at_risk
# 0             NaN                NaN               NaN
# 1             NaN                NaN               NaN
# 2             NaN                NaN               NaN
# 3             NaN                NaN               NaN
# 4         serious                0.0              33.0
# ...           ...                ...               ...
# 132193        NaN                NaN               NaN
# 132194        NaN                NaN               NaN
# 132195        NaN                NaN               NaN
# 132196        NaN                NaN               NaN
# 132197        NaN                NaN               NaN
#
# [132198 rows x 18 columns]

# %%
clinicaltrials.gov <--- primary KS
aact <--- aggregate KS
multiomics clinical trials <--- aggregate KS
