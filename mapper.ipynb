# %% [markdown]
# #### Attempt to map the conditions and interventions to CURIEs

# %%
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup
import re
import collections
import os
import json
import numpy as np

# %%
# %pip install thefuzz
# Out:
# Requirement already satisfied: thefuzz in /Users/Kamileh/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages (0.19.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from thefuzz import fuzz # fuzzy matching explained: https://www.datacamp.com/tutorial/fuzzy-string-python

# %%
# for testing
data_extracted = "/Users/Kamileh/Work/ISB/NCATS_BiomedicalTranslator/Projects/ClinicalTrials/ETL_Python/data/2023-04-03_extracted"

# %%
# read in pipe-delimited files
conditions_df = pd.read_csv(data_extracted + '/conditions.txt', sep='|', index_col=False, header=0)
interventions_df = pd.read_csv(data_extracted + '/interventions.txt', sep='|', index_col=False, header=0)
browse_conditions_df = pd.read_csv(data_extracted + '/browse_conditions.txt', sep='|', index_col=False, header=0)
browse_interventions_df = pd.read_csv(data_extracted + '/browse_interventions.txt', sep='|', index_col=False, header=0)

browse_interventions_df.head()
# Out:
#          id       nct_id          mesh_term downcase_mesh_term      mesh_type
# 0  57856435  NCT00246285        Risperidone        risperidone      mesh-list
# 1  57856584  NCT04626778  Hydrogen Peroxide  hydrogen peroxide      mesh-list
# 2  57856732  NCT00219908       Mitoxantrone       mitoxantrone      mesh-list
# 3  57856807  NCT00220064           Vitamins           vitamins  mesh-ancestor
# 4  57857560  NCT04612894           Apatinib           apatinib      mesh-list

# %%
conditions_df.head()
# Out:
#          id       nct_id            name   downcase_name
# 0  31338340  NCT01819987      Overweight      overweight
# 1  31338518  NCT01821599  Rehabilitation  rehabilitation
# 2  31338693  NCT01823731  Ovarian Cancer  ovarian cancer
# 3  31338879  NCT01825850         Healthy         healthy
# 4  31339149  NCT01829022           Myoma           myoma

# %%
browse_conditions_df.head()
# Out:
#           id       nct_id    mesh_term downcase_mesh_term      mesh_type
# 0  113697939  NCT00185796     Syndrome           syndrome      mesh-list
# 1  113698103  NCT00185913    Neoplasms          neoplasms  mesh-ancestor
# 2  113698185  NCT03516604   Depression         depression      mesh-list
# 3  113698265  NCT03318952         Pain               pain  mesh-ancestor
# 4  113698420  NCT02789800  Tauopathies        tauopathies  mesh-ancestor

# %%
# every clinical trial has at least one MeSH-list (leaf), and may have 0 or more MeSH-ancestors (see MeSH analytics script)
# subset browse_conditions to get only the MeSH-list terms or leaves
condition_mesh_leaves = browse_conditions_df[browse_conditions_df["mesh_type"].str.contains("mesh-list")]
condition_mesh_leaves
# Out:
#                 id       nct_id             mesh_term    downcase_mesh_term  \
# 0        113697939  NCT00185796              Syndrome              syndrome
# 2        113698185  NCT03516604            Depression            depression
# 5        113698730  NCT00461539            Depression            depression
# 6        113698920  NCT05324137                Polyps                polyps
# 11       113700140  NCT00176514             Mucositis             mucositis
# ...            ...          ...                   ...                   ...
# 2849547  111234990  NCT00733525       Bulimia Nervosa       bulimia nervosa
# 2849551  111234994  NCT02653131  Short Bowel Syndrome  short bowel syndrome
# 2849552  111234995  NCT02653131              Syndrome              syndrome
# 2849564  111204205  NCT04834908            Infections            infections
# 2849565  111204206  NCT04834908              COVID-19              covid-19
#
#          mesh_type
# 0        mesh-list
# 2        mesh-list
# 5        mesh-list
# 6        mesh-list
# 11       mesh-list
# ...            ...
# 2849547  mesh-list
# 2849551  mesh-list
# 2849552  mesh-list
# 2849564  mesh-list
# 2849565  mesh-list
#
# [761406 rows x 5 columns]

# %%
# conditions_exact_mapped = pd.merge(conditions_df[['nct_id', 'name', 'downcase_name']],
#                              browse_conditions_df[['nct_id', 'mesh_term', 'downcase_mesh_term', 'mesh_type']],
#                              how='left',
#                              left_on=['nct_id', 'downcase_name'],
#                              right_on = ['nct_id', 'downcase_mesh_term'])
                             
# conditions_exact_mapped = conditions_exact_mapped.sort_values(by=['nct_id'])
# conditions_exact_mapped[:20]
# Out:
#              nct_id                                name  \
# 25683   NCT00000102      Congenital Adrenal Hyperplasia
# 249369  NCT00000104                      Lead Poisoning
# 228818  NCT00000105                              Cancer
# 203650  NCT00000106                  Rheumatic Diseases
# 255481  NCT00000107           Heart Defects, Congenital
# 277916  NCT00000108                    Coronary Disease
# 277915  NCT00000108             Cardiovascular Diseases
# 249384  NCT00000110                             Obesity
# 228820  NCT00000111                      Mouth Diseases
# 203654  NCT00000112                Acanthosis Nigricans
# 203653  NCT00000112                            Diabetes
# 203652  NCT00000112                 Glucose Intolerance
# 203651  NCT00000112                             Obesity
# 29374   NCT00000113                              Myopia
# 23296   NCT00000114                Retinitis Pigmentosa
# 22854   NCT00000115              Macular Edema, Cystoid
# 457043  NCT00000116                Retinitis Pigmentosa
# 228824  NCT00000117                      Optic Neuritis
# 203667  NCT00000118                      HIV Infections
# 203668  NCT00000118  Acquired Immunodeficiency Syndrome
#
#                              downcase_name  \
# 25683       congenital adrenal hyperplasia
# 249369                      lead poisoning
# 228818                              cancer
# 203650                  rheumatic diseases
# 255481           heart defects, congenital
# 277916                    coronary disease
# 277915             cardiovascular diseases
# 249384                             obesity
# 228820                      mouth diseases
# 203654                acanthosis nigricans
# 203653                            diabetes
# 203652                 glucose intolerance
# 203651                             obesity
# 29374                               myopia
# 23296                 retinitis pigmentosa
# 22854               macular edema, cystoid
# 457043                retinitis pigmentosa
# 228824                      optic neuritis
# 203667                      hiv infections
# 203668  acquired immunodeficiency syndrome
#
#                                  mesh_term  \
# 25683                                  NaN
# 249369                      Lead Poisoning
# 228818                                 NaN
# 203650                  Rheumatic Diseases
# 255481           Heart Defects, Congenital
# 277916                    Coronary Disease
# 277915             Cardiovascular Diseases
# 249384                                 NaN
# 228820                      Mouth Diseases
# 203654                Acanthosis Nigricans
# 203653                                 NaN
# 203652                 Glucose Intolerance
# 203651                                 NaN
# 29374                               Myopia
# 23296                 Retinitis Pigmentosa
# 22854                                  NaN
# 457043                Retinitis Pigmentosa
# 228824                      Optic Neuritis
# 203667                      HIV Infections
# 203668  Acquired Immunodeficiency Syndrome
#
#                         downcase_mesh_term  mesh_type
# 25683                                  NaN        NaN
# 249369                      lead poisoning  mesh-list
# 228818                                 NaN        NaN
# 203650                  rheumatic diseases  mesh-list
# 255481           heart defects, congenital  mesh-list
# 277916                    coronary disease  mesh-list
# 277915             cardiovascular diseases  mesh-list
# 249384                                 NaN        NaN
# 228820                      mouth diseases  mesh-list
# 203654                acanthosis nigricans  mesh-list
# 203653                                 NaN        NaN
# 203652                 glucose intolerance  mesh-list
# 203651                                 NaN        NaN
# 29374                               myopia  mesh-list
# 23296                 retinitis pigmentosa  mesh-list
# 22854                                  NaN        NaN
# 457043                retinitis pigmentosa  mesh-list
# 228824                      optic neuritis  mesh-list
# 203667                      hiv infections  mesh-list
# 203668  acquired immunodeficiency syndrome  mesh-list

# %%
# some conditions have a MESH term match, even if it doesn't show up in the same clinical trial
# add those matches based on MESH term alone (irrespective of clinical trial)
all_mesh_conditions = browse_conditions_df.downcase_mesh_term.unique()
print(len(all_mesh_conditions))
# Out:
# 4315

# %%
conditions_exact_mapped = conditions_df.copy()
mask = np.isin(conditions_exact_mapped['downcase_name'], all_mesh_conditions)
conditions_exact_mapped['mesh_conditions_exact_mapped'] = np.where(mask, conditions_exact_mapped['downcase_name'], np.nan)

with pd.option_context("display.max_rows", 30000):
    display(conditions_exact_mapped[:3000])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [175], in <cell line: 2>()
#       1 conditions_exact_mapped = conditions_df.copy()
# ----> 2 mask = np.isin(conditions_exact_mapped['downcase_name'], all_mesh_conditions)
#       3 conditions_exact_mapped['mesh_conditions_exact_mapped'] = np.where(mask, conditions_exact_mapped['downcase_name'], np.nan)
#       5 with pd.option_context("display.max_rows", 30000):
#
# File <__array_function__ internals>:180, in isin(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/numpy/lib/arraysetops.py:735, in isin(element, test_elements, assume_unique, invert)
#     642 """
#     643 Calculates `element in test_elements`, broadcasting over `element` only.
#     644 Returns a boolean array of the same shape as `element` that is True
#    (...)
#     732        [ True, False]])
#     733 """
#     734 element = np.asarray(element)
# --> 735 return in1d(element, test_elements, assume_unique=assume_unique,
#     736             invert=invert).reshape(element.shape)
#
# File <__array_function__ internals>:180, in in1d(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/numpy/lib/arraysetops.py:608, in in1d(ar1, ar2, assume_unique, invert)
#     606         mask = np.zeros(len(ar1), dtype=bool)
#     607         for a in ar2:
# --> 608             mask |= (ar1 == a)
#     609     return mask
#     611 # Otherwise use sorting
#
# KeyboardInterrupt:

# %%
test = conditions_exact_mapped[conditions_exact_mapped['mesh_conditions_exact_mapped'].isnull()] # get the rows where mesh_term is empty bc there was no match there
test
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 203653  NCT00000112                                           Diabetes
# 22854   NCT00000115                             Macular Edema, Cystoid
# 277917  NCT00000126                          Ischemic Optic Neuropathy
# ...             ...                                                ...
# 472888  NCT05794048                                    Hepatocarcinoma
# 472887  NCT05794061                               Psychiatric Disorder
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name mesh_term  \
# 25683                      congenital adrenal hyperplasia       NaN
# 228818                                             cancer       NaN
# 203653                                           diabetes       NaN
# 22854                              macular edema, cystoid       NaN
# 277917                          ischemic optic neuropathy       NaN
# ...                                                   ...       ...
# 472888                                    hepatocarcinoma       NaN
# 472887                               psychiatric disorder       NaN
# 472885                               cognitive impairment       NaN
# 472884  nutrition deficiency (xanth deficiency) due to...       NaN
# 472883                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type mesh_conditions_exact_mapped
# 25683                 NaN       NaN                          NaN
# 228818                NaN       NaN                          NaN
# 203653                NaN       NaN                          NaN
# 22854                 NaN       NaN                          NaN
# 277917                NaN       NaN                          NaN
# ...                   ...       ...                          ...
# 472888                NaN       NaN                          NaN
# 472887                NaN       NaN                          NaN
# 472885                NaN       NaN                          NaN
# 472884                NaN       NaN                          NaN
# 472883                NaN       NaN                          NaN
#
# [545877 rows x 7 columns]

# %% [markdown]
# ## Use fuzzy string matching to get MESH terms matches that are identical to downcase_name, but rearranged

# %%
# fuzzy matching explained: https://www.datacamp.com/tutorial/fuzzy-string-python

def get_token_sort_ratio(str1, str2):
    try:
        return fuzz.token_sort_ratio(str1, str2)
    except:
        return None
    
sort_ratio = np.vectorize(get_token_sort_ratio)

def get_token_set_ratio(str1, str2):
    try:
        return fuzz.token_set_ratio(str1, str2)
    except:
        return None  
set_ratio = np.vectorize(get_token_set_ratio)

def get_similarity_score(str1, str2):
    try:
        return fuzz.ratio(str1, str2)
    except:
        return None
sim_score = np.vectorize(get_similarity_score)

# %%
mesh_conditions_per_study = pd.DataFrame(browse_conditions_df[["nct_id", "downcase_mesh_term", "mesh_type"]].groupby("nct_id")["downcase_mesh_term"].apply(list))
with pd.option_context("max_colwidth", None):
    display(mesh_conditions_per_study[:30])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              downcase_mesh_term
# nct_id
# NCT00000102                                                                                                                                                      [adrenal hyperplasia, congenital, adrenogenital syndrome, adrenocortical hyperfunction, hyperplasia, pathologic processes, disorders of sex development, urogenital abnormalities, congenital abnormalities, genetic diseases, inborn, steroid metabolism, inborn errors, metabolism, inborn errors, metabolic diseases, adrenal gland diseases, endocrine system diseases, gonadal disorders]
# NCT00000104                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [poisoning, lead poisoning, chemically-induced disorders, heavy metal poisoning]
# NCT00000105                                                                                                                                                                                                                                                                                                                                                                                                           [tetanus, clostridium infections, gram-positive bacterial infections, bacterial infections, bacterial infections and mycoses, infections]
# NCT00000106                                                                                                                                                                                                                                                                                                                                                                                                                                                       [rheumatic diseases, collagen diseases, musculoskeletal diseases, connective tissue diseases]
# NCT00000107                                                                                                                                                                                                                                                                                                                                                                                                                        [heart defects, congenital, congenital abnormalities, heart diseases, cardiovascular diseases, cardiovascular abnormalities]
# NCT00000108                                                                                                                                                                                                                                                                                                                                                                                                                                                 [cardiovascular diseases, coronary disease, myocardial ischemia, heart diseases, vascular diseases]
# NCT00000111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [mouth diseases, stomatognathic diseases]
# NCT00000112                                                                                                                                                                                                                                                                                                                                                                   [melanosis, acanthosis nigricans, glucose intolerance, hyperglycemia, glucose metabolism disorders, metabolic diseases, hyperpigmentation, pigmentation disorders, skin diseases]
# NCT00000113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [myopia, refractive errors, eye diseases]
# NCT00000114                                                                                                                                                                                                                                                                                                                                                                                    [retinitis, retinitis pigmentosa, retinal diseases, eye diseases, eye diseases, hereditary, retinal dystrophies, retinal degeneration, genetic diseases, inborn]
# NCT00000115                                                                                                                                                                                                                                                                                                                                                                                                                                                  [retinal diseases, macular edema, edema, macular degeneration, retinal degeneration, eye diseases]
# NCT00000116                                                                                                                                                                                                                                                                                                                                                                                    [retinitis, retinitis pigmentosa, retinal diseases, eye diseases, eye diseases, hereditary, retinal dystrophies, retinal degeneration, genetic diseases, inborn]
# NCT00000117                                                                                                                                                                                                                                                                                                                                                                         [neuritis, optic neuritis, peripheral nervous system diseases, neuromuscular diseases, nervous system diseases, optic nerve diseases, cranial nerve diseases, eye diseases]
# NCT00000118  [eye diseases, hiv infections, acquired immunodeficiency syndrome, cytomegalovirus retinitis, retinitis, immunologic deficiency syndromes, blood-borne infections, communicable diseases, infections, sexually transmitted diseases, viral, sexually transmitted diseases, lentivirus infections, retroviridae infections, rna virus infections, virus diseases, immune system diseases, slow virus diseases, retinal diseases, eye infections, viral, eye infections, cytomegalovirus infections, herpesviridae infections, dna virus infections]
# NCT00000119                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [cataract, uveitis, lens diseases, eye diseases, uveal diseases]
# NCT00000120                                                                                     [chlamydia infections, ophthalmia neonatorum, chlamydiaceae infections, gram-negative bacterial infections, bacterial infections, bacterial infections and mycoses, infections, sexually transmitted diseases, bacterial, sexually transmitted diseases, communicable diseases, eye infections, eye diseases, conjunctivitis, bacterial, eye infections, bacterial, neisseriaceae infections, conjunctivitis, conjunctival diseases, infant, newborn, diseases]
# NCT00000121                                                                                                                                                                                                                                                                                                                                                                                                                                   [esotropia, strabismus, ocular motility disorders, cranial nerve diseases, nervous system diseases, eye diseases]
# NCT00000122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [glaucoma, ocular hypertension, eye diseases]
# NCT00000123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [astigmatism, refractive errors, eye diseases]
# NCT00000124                                                                                                                                                                                                                                                                                                                                                                                                          [choroid neoplasms, uveitis, neoplasms, uveal diseases, eye diseases, uveal neoplasms, eye neoplasms, neoplasms by site, choroid diseases]
# NCT00000125                                                                                                                                                                                                                                                                                                                                                                                                                                             [glaucoma, ocular hypertension, hypertension, vascular diseases, cardiovascular diseases, eye diseases]
# NCT00000126                                                                                                                                                                                                                                                                                                                                                       [ischemia, optic nerve diseases, optic neuropathy, ischemic, pathologic processes, nervous system diseases, cranial nerve diseases, eye diseases, vascular diseases, cardiovascular diseases]
# NCT00000127                                                                                                                                                                                                                                                                                                                                                       [optic nerve diseases, optic neuropathy, ischemic, ischemia, pathologic processes, nervous system diseases, cranial nerve diseases, eye diseases, vascular diseases, cardiovascular diseases]
# NCT00000128                                                                                                                                                                                                                                                                                                                                                                                                                                   [strabismus, esotropia, eye diseases, ocular motility disorders, cranial nerve diseases, nervous system diseases]
# NCT00000129                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [myopia, refractive errors, eye diseases]
# NCT00000130                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [endophthalmitis, eye infections, infections, eye diseases]
# NCT00000131                                                                                                                                                                                                                                                                                                                                                                                        [retinal vein occlusion, retinal diseases, eye diseases, venous thrombosis, thrombosis, embolism and thrombosis, vascular diseases, cardiovascular diseases]
# NCT00000132                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [glaucoma, glaucoma, open-angle, ocular hypertension, eye diseases]
# NCT00000133                                                                                                                                                                                                                                                                                                                           [retinal diseases, retinopathy of prematurity, premature birth, eye diseases, obstetric labor, premature, obstetric labor complications, pregnancy complications, infant, premature, diseases, infant, newborn, diseases]
# NCT00000134  [hiv infections, acquired immunodeficiency syndrome, cytomegalovirus retinitis, retinitis, immunologic deficiency syndromes, blood-borne infections, communicable diseases, infections, sexually transmitted diseases, viral, sexually transmitted diseases, lentivirus infections, retroviridae infections, rna virus infections, virus diseases, immune system diseases, slow virus diseases, retinal diseases, eye diseases, eye infections, viral, eye infections, cytomegalovirus infections, herpesviridae infections, dna virus infections]

# %%
# reassorted_ratio = ratio(row["downcase_name"], term)
conditions_unmapped = conditions_exact_mapped[conditions_exact_mapped['mesh_term'].isnull()] # get the rows where mesh_term is empty bc there was no match there
conditions_unmapped = conditions_unmapped.drop(['mesh_term', 'downcase_mesh_term', 'mesh_type'], axis=1) # drop those rows (don't need them now)
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 249384  NCT00000110                                            Obesity
# 203653  NCT00000112                                           Diabetes
# 203651  NCT00000112                                            Obesity
# ...             ...                                                ...
# 472887  NCT05794061                               Psychiatric Disorder
# 472886  NCT05794061                                           Dementia
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name
# 25683                      congenital adrenal hyperplasia
# 228818                                             cancer
# 249384                                            obesity
# 203653                                           diabetes
# 203651                                            obesity
# ...                                                   ...
# 472887                               psychiatric disorder
# 472886                                           dementia
# 472885                               cognitive impairment
# 472884  nutrition deficiency (xanth deficiency) due to...
# 472883                                      air pollution
#
# [563678 rows x 3 columns]

# %%
conditions_unmapped_all_mesh_terms = pd.merge(conditions_unmapped[["nct_id", "downcase_name"]], # only these columns needed bc all other columns have null anyway (no match from previous merge)
                                                mesh_conditions_per_study,
                                                how='left',
                                                left_on=['nct_id'],
                                                right_on = ['nct_id'])

# some clinical trials are missing from browse_conditions (those nct_ids are not present in the browse_conditions text) They have NaN in the downcase_mesh_term column
conditions_unmapped_all_mesh_terms
# Out:
#              nct_id                                      downcase_name  \
# 0       NCT00000102                     congenital adrenal hyperplasia
# 1       NCT00000105                                             cancer
# 2       NCT00000110                                            obesity
# 3       NCT00000112                                           diabetes
# 4       NCT00000112                                            obesity
# ...             ...                                                ...
# 563673  NCT05794061                               psychiatric disorder
# 563674  NCT05794061                                           dementia
# 563675  NCT05794061                               cognitive impairment
# 563676  NCT05794074  nutrition deficiency (xanth deficiency) due to...
# 563677  NCT05794087                                      air pollution
#
#                                        downcase_mesh_term
# 0       [adrenal hyperplasia, congenital, adrenogenita...
# 1       [tetanus, clostridium infections, gram-positiv...
# 2                                                     NaN
# 3       [melanosis, acanthosis nigricans, glucose into...
# 4       [melanosis, acanthosis nigricans, glucose into...
# ...                                                   ...
# 563673  [mental disorders, problem behavior, behaviora...
# 563674  [mental disorders, problem behavior, behaviora...
# 563675  [mental disorders, problem behavior, behaviora...
# 563676                                                NaN
# 563677                                                NaN
#
# [563678 rows x 3 columns]

# %%
conditions_unmapped_all_mesh_terms = conditions_unmapped_all_mesh_terms.explode('downcase_mesh_term')
conditions_unmapped_all_mesh_terms
# Out:
#              nct_id                                      downcase_name  \
# 0       NCT00000102                     congenital adrenal hyperplasia
# 0       NCT00000102                     congenital adrenal hyperplasia
# 0       NCT00000102                     congenital adrenal hyperplasia
# 0       NCT00000102                     congenital adrenal hyperplasia
# 0       NCT00000102                     congenital adrenal hyperplasia
# ...             ...                                                ...
# 563675  NCT05794061                               cognitive impairment
# 563675  NCT05794061                               cognitive impairment
# 563675  NCT05794061                               cognitive impairment
# 563676  NCT05794074  nutrition deficiency (xanth deficiency) due to...
# 563677  NCT05794087                                      air pollution
#
#                      downcase_mesh_term
# 0       adrenal hyperplasia, congenital
# 0                adrenogenital syndrome
# 0          adrenocortical hyperfunction
# 0                           hyperplasia
# 0                  pathologic processes
# ...                                 ...
# 563675                 mental disorders
# 563675                 problem behavior
# 563675              behavioral symptoms
# 563676                              NaN
# 563677                              NaN
#
# [5393907 rows x 3 columns]

# %%
conditions_unmapped_all_mesh_terms = conditions_unmapped_all_mesh_terms[~conditions_unmapped_all_mesh_terms['downcase_name'].isnull()] # subset or delete rows where either column is empty/Nonetype bc fuzzymatching functions will throw error if handling
conditions_unmapped_all_mesh_terms = conditions_unmapped_all_mesh_terms[~conditions_unmapped_all_mesh_terms['downcase_mesh_term'].isnull()] # subset or delete rows where either column is empty/Nonetype bc fuzzymatching functions will throw error if handling
print(len(conditions_unmapped_all_mesh_terms))

conditions_unmapped_all_mesh_terms["sort_ratio"] = sort_ratio(conditions_unmapped_all_mesh_terms[["downcase_mesh_term"]].values, conditions_unmapped_all_mesh_terms[["downcase_name"]].values)
# conditions_unmapped_all_mesh_terms["set_ratio"] = set_ratio(conditions_unmapped_all_mesh_terms[["downcase_mesh_term"]].values, conditions_unmapped_all_mesh_terms[["downcase_name"]].values)
conditions_unmapped_all_mesh_terms["sim_score"] = sim_score(conditions_unmapped_all_mesh_terms[["downcase_mesh_term"]].values, conditions_unmapped_all_mesh_terms[["downcase_name"]].values)

conditions_unmapped_all_mesh_terms
# Out:
# 5292633
#              nct_id                   downcase_name  \
# 0       NCT00000102  congenital adrenal hyperplasia
# 0       NCT00000102  congenital adrenal hyperplasia
# 0       NCT00000102  congenital adrenal hyperplasia
# 0       NCT00000102  congenital adrenal hyperplasia
# 0       NCT00000102  congenital adrenal hyperplasia
# ...             ...                             ...
# 563674  NCT05794061                        dementia
# 563674  NCT05794061                        dementia
# 563675  NCT05794061            cognitive impairment
# 563675  NCT05794061            cognitive impairment
# 563675  NCT05794061            cognitive impairment
#
#                      downcase_mesh_term  sort_ratio  sim_score
# 0       adrenal hyperplasia, congenital         100         62
# 0                adrenogenital syndrome          62         46
# 0          adrenocortical hyperfunction          59         48
# 0                           hyperplasia          54         54
# 0                  pathologic processes          36         32
# ...                                 ...         ...        ...
# 563674                 problem behavior          17         33
# 563674              behavioral symptoms          22         22
# 563675                 mental disorders          39         33
# 563675                 problem behavior          28         33
# 563675              behavioral symptoms          31         31
#
# [5292633 rows x 5 columns]

# %%
conditions_mesh_fuzz_scored = conditions_unmapped_all_mesh_terms[(conditions_unmapped_all_mesh_terms['sim_score'] > 88) | (conditions_unmapped_all_mesh_terms['sort_ratio'] > 88)]

conditions_mesh_fuzz_scored
# Out:
#              nct_id                          downcase_name  \
# 0       NCT00000102         congenital adrenal hyperplasia
# 7       NCT00000126              ischemic optic neuropathy
# 8       NCT00000127              ischemic optic neuropathy
# 11      NCT00000132                    open-angle glaucoma
# 18      NCT00000140        proliferative vitreoretinopathy
# ...             ...                                    ...
# 563627  NCT05793684                obstructive sleep apnea
# 563628  NCT05793697  chronic obstructive pulmonary disease
# 563647  NCT05793827                 traumatic brain injury
# 563662  NCT05793983        liver failure, acute on chronic
# 563666  NCT05793983                       cirrhosis, liver
#
#                             downcase_mesh_term  sort_ratio  sim_score
# 0              adrenal hyperplasia, congenital         100         62
# 7                   optic neuropathy, ischemic         100         63
# 8                   optic neuropathy, ischemic         100         63
# 11                        glaucoma, open-angle         100         51
# 18            vitreoretinopathy, proliferative         100         54
# ...                                        ...         ...        ...
# 563627                sleep apnea, obstructive         100         47
# 563628  pulmonary disease, chronic obstructive         100         51
# 563647               brain injuries, traumatic          91         47
# 563662          acute-on-chronic liver failure         100         46
# 563666                         liver cirrhosis         100         58
#
# [75580 rows x 5 columns]

# %%
conditions_mesh_fuzz_mapped = pd.merge(conditions_unmapped, # only these columns needed bc all other columns have null anyway (no match from previous merge)
                                        conditions_mesh_fuzz_scored,
                                        how='left',
                                        left_on=['nct_id', 'downcase_name'],
                                        right_on = ['nct_id', 'downcase_name'])

# %%
with pd.option_context("display.max_rows", 30000):
    display(conditions_mesh_fuzz_mapped[:3000])
# Out:
#            nct_id                                               name  \
# 0     NCT00000102                     Congenital Adrenal Hyperplasia
# 1     NCT00000105                                             Cancer
# 2     NCT00000110                                            Obesity
# 3     NCT00000112                                           Diabetes
# 4     NCT00000112                                            Obesity
# 5     NCT00000115                             Macular Edema, Cystoid
# 6     NCT00000123                                             Myopia
# 7     NCT00000126                          Ischemic Optic Neuropathy
# 8     NCT00000127                          Ischemic Optic Neuropathy
# 9     NCT00000128                                          Esophoria
# 10    NCT00000128                                             Myopia
# 11    NCT00000132                                Open-Angle Glaucoma
# 12    NCT00000135                                     HIV Infections
# 13    NCT00000136                                     HIV Infections
# 14    NCT00000137                                    Graft Rejection
# 15    NCT00000137                            Corneal Transplantation
# 16    NCT00000138                              Ocular Herpes Simplex
# 17    NCT00000139                              Ocular Herpes Simplex
# 18    NCT00000140                    Proliferative Vitreoretinopathy
# 19    NCT00000142                                     HIV Infections
# 20    NCT00000142                      CMV Cytomegalovirus Retinitis
# 21    NCT00000143                                     HIV Infections
# 22    NCT00000144                                Open-Angle Glaucoma
# 23    NCT00000145                                     Lens Opacities
# 24    NCT00000149                                Open-Angle Glaucoma
# 25    NCT00000281                                      Shcizophrenia
# 26    NCT00000370                                      Social Phobia
# 27    NCT00000370                            Public Speaking Anxiety
# 28    NCT00000375                          Major Depressive Disorder
# 29    NCT00000376                          Drug-resistant Depression
# 30    NCT00000378                                        Melancholia
# 31    NCT00000380                                    Sleep Disorders
# 32    NCT00000382                                        Child Abuse
# 33    NCT00000388                                 Dyssocial Behavior
# 34    NCT00000389                       Generalized Anxiety Disorder
# 35    NCT00000389                                      Social Phobia
# 36    NCT00000389                                 Separation Anxiety
# 37    NCT00000392                                     HIV Infections
# 38    NCT00000395                               Rheumatoid Arthritis
# 39    NCT00000395                                 Adjuvant Arthritis
# 40    NCT00000397                                           Insomnia
# 41    NCT00000401                               Rheumatoid Arthritis
# 42    NCT00000410                                     Herniated Disc
# 43    NCT00000412                            Cardiac Transplantation
# 44    NCT00000414                               Rheumatoid Arthritis
# 45    NCT00000415                                          Nutrition
# 46    NCT00000415                                  Physical Activity
# 47    NCT00000416                             Ankylosing Spondylitis
# 48    NCT00000416                       Systemic Lupus Erythematosus
# 49    NCT00000416                               Rheumatoid Arthritis
# 50    NCT00000417                       Systemic Lupus Erythematosus
# 51    NCT00000418                                Acute Low Back Pain
# 52    NCT00000419                       Systemic Lupus Erythematosus
# 53    NCT00000420                       Systemic Lupus Erythematosus
# 54    NCT00000421                       Systemic Lupus Erythematosus
# 55    NCT00000423                                    Quality of Life
# 56    NCT00000429                      Juvenile Rheumatoid Arthritis
# 57    NCT00000430                                         Osteopenia
# 58    NCT00000435                               Rheumatoid Arthritis
# 59    NCT00000436                            Unilateral Hip Fracture
# 60    NCT00000437                                            Smoking
# 61    NCT00000444                                            Smoking
# 62    NCT00000446                     Post-Traumatic Stress Disorder
# 63    NCT00000446                     Post-Traumatic Stress Disorder
# 64    NCT00000447                                            Smoking
# 65    NCT00000448                                    Eating Disorder
# 66    NCT00000451                                 Alcohol Dependence
# 67    NCT00000454                                            Smoking
# 68    NCT00000456                                 Alcohol Dependence
# 69    NCT00000457                                            Smoking
# 70    NCT00000458                                         Depression
# 71    NCT00000462                                  Diabetes Mellitus
# 72    NCT00000464                                         Arrhythmia
# 73    NCT00000466                                       Hypertension
# 74    NCT00000466                                  Diabetes Mellitus
# 75    NCT00000466                                      Postmenopause
# 76    NCT00000469                          Cerebral Arteriosclerosis
# 77    NCT00000470                           Defect, Congenital Heart
# 78    NCT00000470                                    Cerebral Anoxia
# 79    NCT00000471                                       Hypertension
# 80    NCT00000471                          Coronary Arteriosclerosis
# 81    NCT00000475                          Heart Failure, Congestive
# 82    NCT00000476                                   Sinus Arrhythmia
# 83    NCT00000476                                         Arrhythmia
# 84    NCT00000476                          Heart Failure, Congestive
# 85    NCT00000480                                         Arrhythmia
# 86    NCT00000481                                      Postmenopause
# 87    NCT00000492                                         Arrhythmia
# 88    NCT00000494                           Defect, Congenital Heart
# 89    NCT00000501                                            Obesity
# 90    NCT00000502                                    Cerebral Anoxia
# 91    NCT00000502                                         Arrhythmia
# 92    NCT00000504                                         Arrhythmia
# 93    NCT00000504                             Ventricular Arrhythmia
# 94    NCT00000508                          Coronary Arteriosclerosis
# 95    NCT00000509                                       Hypertension
# 96    NCT00000512                          Coronary Arteriosclerosis
# 97    NCT00000513                                       Hypertension
# 98    NCT00000515                                            Obesity
# 99    NCT00000515                                       Hypertension
# 100   NCT00000516                                      Heart Failure
# 101   NCT00000516                                       Hypertension
# 102   NCT00000517                                         Arrhythmia
# 103   NCT00000517                   Cerebral Embolism and Thrombosis
# 104   NCT00000517                           Cerebrovascular Accident
# 105   NCT00000518                                         Arrhythmia
# 106   NCT00000518                             Ventricular Arrhythmia
# 107   NCT00000519                                       Hypertension
# 108   NCT00000519                                            Obesity
# 109   NCT00000521                                       Hypertension
# 110   NCT00000526                             Ventricular Arrhythmia
# 111   NCT00000529                                       Hypertension
# 112   NCT00000530                                  Raynaud's Disease
# 113   NCT00000531                                         Arrhythmia
# 114   NCT00000532                                       Hypertension
# 115   NCT00000532                                            Obesity
# 116   NCT00000532                                          Menopause
# 117   NCT00000532                                      Postmenopause
# 118   NCT00000532                                  Diabetes Mellitus
# 119   NCT00000534                                       Hypertension
# 120   NCT00000534                                 Pregnancy Toxemias
# 121   NCT00000535                                       Hypertension
# 122   NCT00000536                                       Hypertension
# 123   NCT00000537                                       Hypertension
# 124   NCT00000538              Coronary Heart Disease Risk Reduction
# 125   NCT00000538                               Hyperlipoproteinemia
# 126   NCT00000539                                  Diabetes Mellitus
# 127   NCT00000540                             Ventricular Arrhythmia
# 128   NCT00000540                                         Arrhythmia
# 129   NCT00000541                          Coronary Arteriosclerosis
# 130   NCT00000542                                      Heart Failure
# 131   NCT00000542                                       Hypertension
# 132   NCT00000542                                  Diabetes Mellitus
# 133   NCT00000543                                 Pregnancy Toxemias
# 134   NCT00000545                                Sedentary Behaviors
# 135   NCT00000545                                            Obesity
# 136   NCT00000546                                       Hypertension
# 137   NCT00000547                                Myocardial Diseases
# 138   NCT00000547                                      Heart Failure
# 139   NCT00000549                                      Postmenopause
# 140   NCT00000549                          Coronary Arteriosclerosis
# 141   NCT00000555                                      Postmenopause
# 142   NCT00000555                          Coronary Arteriosclerosis
# 143   NCT00000556                                         Arrhythmia
# 144   NCT00000557                                         Depression
# 145   NCT00000559                                      Postmenopause
# 146   NCT00000560                          Heart Failure, Congestive
# 147   NCT00000561                           Cerebrovascular Accident
# 148   NCT00000561                                         Arrhythmia
# 149   NCT00000562                          Acute Respiratory Failure
# 150   NCT00000564              Chronic Obstructive Pulmonary Disease
# 151   NCT00000565              Chronic Obstructive Pulmonary Disease
# 152   NCT00000568              Chronic Obstructive Pulmonary Disease
# 153   NCT00000569              Chronic Obstructive Pulmonary Disease
# 154   NCT00000571              Chronic Obstructive Pulmonary Disease
# 155   NCT00000572                Acute Respiratory Distress Syndrome
# 156   NCT00000573              Chronic Obstructive Pulmonary Disease
# 157   NCT00000574                Acute Respiratory Distress Syndrome
# 158   NCT00000579               Respiratory Distress Syndrome, Adult
# 159   NCT00000581                                  Blood Transfusion
# 160   NCT00000581                                          Infection
# 161   NCT00000584                                  Blood Transfusion
# 162   NCT00000585                          Infection (S. Pneumoniae)
# 163   NCT00000587                                      Blood Disease
# 164   NCT00000588                              Anemia (Iron-Loading)
# 165   NCT00000589                        Leukemia, Myelocytic, Acute
# 166   NCT00000589                                       Immunization
# 167   NCT00000589                                    Blood Platelets
# 168   NCT00000589                                  Blood Transfusion
# 169   NCT00000590                     Disease Transmission, Vertical
# 170   NCT00000591                        Bone Marrow Transplantation
# 171   NCT00000591                               Immunologic Diseases
# 172   NCT00000591                                           Leukemia
# 173   NCT00000592                   Cerebral Embolism and Thrombosis
# 174   NCT00000593                                  Blood Transfusion
# 175   NCT00000594                     Hypercholesterolemia, Familial
# 176   NCT00000595                              Anemia (Iron-Loading)
# 177   NCT00000597                                      Blood Disease
# 178   NCT00000598                                      Postmenopause
# 179   NCT00000599                          Coronary Arteriosclerosis
# 180   NCT00000599                          Cerebral Arteriosclerosis
# 181   NCT00000601                                      Postmenopause
# 182   NCT00000603            Hematopoietic Stem Cell Transplantation
# 183   NCT00000603                                          Neoplasms
# 184   NCT00000603                                           Leukemia
# 185   NCT00000605                          Coronary Arteriosclerosis
# 186   NCT00000605                                      Postmenopause
# 187   NCT00000606              Chronic Obstructive Pulmonary Disease
# 188   NCT00000607                          Heart Failure, Congestive
# 189   NCT00000608                                       Hypertension
# 190   NCT00000609                          Heart Failure, Congestive
# 191   NCT00000609                                         Arrhythmia
# 192   NCT00000611                                      Postmenopause
# 193   NCT00000612                                          Menopause
# 194   NCT00000612                              Menopausal Complaints
# 195   NCT00000613                                         Depression
# 196   NCT00000613                                      Postmenopause
# 197   NCT00000615                                            Obesity
# 198   NCT00000616                                       Hypertension
# 199   NCT00000619                          Heart Failure, Congestive
# 200   NCT00000620                                       Hypertension
# 201   NCT00000621              Chronic Obstructive Pulmonary Disease
# 202   NCT00000623                                   Anemia, Cooley's
# 203   NCT00000626                                     HIV Infections
# 204   NCT00000626                                  Hodgkin's Disease
# 205   NCT00000630                                     HIV Infections
# 206   NCT00000631                                     HIV Infections
# 207   NCT00000632                                 HIV Seronegativity
# 208   NCT00000635                                     HIV Infections
# 209   NCT00000639                                     HIV Infections
# 210   NCT00000640                    Pneumonia, Pneumocystis Carinii
# 211   NCT00000640                                     HIV Infections
# 212   NCT00000641                                     HIV Infections
# 213   NCT00000642                                          Pregnancy
# 214   NCT00000643                                     HIV Infections
# 215   NCT00000644                                     HIV Infections
# 216   NCT00000646                                     HIV Infections
# 217   NCT00000654                                     HIV Infections
# 218   NCT00000655                                     HIV Infections
# 219   NCT00000655                    Pneumonia, Pneumocystis Carinii
# 220   NCT00000658                                     HIV Infections
# 221   NCT00000660                                     HIV Infections
# 222   NCT00000663                                     HIV Infections
# 223   NCT00000665                                     HIV Infections
# 224   NCT00000666                                     HIV Infections
# 225   NCT00000668                                     HIV Infections
# 226   NCT00000673                                     HIV Infections
# 227   NCT00000674                                     HIV Infections
# 228   NCT00000677                                     HIV Infections
# 229   NCT00000681                                     HIV Infections
# 230   NCT00000685                                     HIV Infections
# 231   NCT00000685                                     Kidney Disease
# 232   NCT00000687                                     HIV Infections
# 233   NCT00000688                                     HIV Infections
# 234   NCT00000689                                     HIV Infections
# 235   NCT00000691                                     HIV Infections
# 236   NCT00000693                                     HIV Infections
# 237   NCT00000694                                     HIV Infections
# 238   NCT00000695                                     HIV Infections
# 239   NCT00000697                                     HIV Infections
# 240   NCT00000698                                     HIV Infections
# 241   NCT00000703                                     HIV Infections
# 242   NCT00000707                                     HIV Infections
# 243   NCT00000707                    Pneumonia, Pneumocystis Carinii
# 244   NCT00000708                                     HIV Infections
# 245   NCT00000711                                         Cytopenias
# 246   NCT00000712                                     HIV Infections
# 247   NCT00000714                                     HIV Infections
# 248   NCT00000714                    Pneumonia, Pneumocystis Carinii
# 249   NCT00000715                    Pneumonia, Pneumocystis Carinii
# 250   NCT00000715                                     HIV Infections
# 251   NCT00000717                                     HIV Infections
# 252   NCT00000717                    Pneumonia, Pneumocystis Carinii
# 253   NCT00000722                    Pneumonia, Pneumocystis Carinii
# 254   NCT00000722                                     HIV Infections
# 255   NCT00000723                                     HIV Infections
# 256   NCT00000724                                     HIV Infections
# 257   NCT00000724                    Pneumonia, Pneumocystis Carinii
# 258   NCT00000725                                     HIV Infections
# 259   NCT00000727                    Pneumonia, Pneumocystis Carinii
# 260   NCT00000727                                     HIV Infections
# 261   NCT00000728                                     HIV Infections
# 262   NCT00000730                    Pneumonia, Pneumocystis Carinii
# 263   NCT00000730                                     HIV Infections
# 264   NCT00000739                    Pneumonia, Pneumocystis Carinii
# 265   NCT00000740                    Pneumonia, Pneumocystis Carinii
# 266   NCT00000740                                     HIV Infections
# 267   NCT00000741                    Pneumonia, Pneumocystis Carinii
# 268   NCT00000741                                     HIV Infections
# 269   NCT00000744                                     HIV Infections
# 270   NCT00000744                            Candidiasis, Esophageal
# 271   NCT00000746                                     HIV Infections
# 272   NCT00000748                                     HIV Infections
# 273   NCT00000748                    Pneumonia, Pneumocystis Carinii
# 274   NCT00000751                                          Pregnancy
# 275   NCT00000752                                     HIV Infections
# 276   NCT00000758                                  Cervix, Dysplasia
# 277   NCT00000758                                     HIV Infections
# 278   NCT00000759                                     HIV Infections
# 279   NCT00000763                                     HIV Infections
# 280   NCT00000766                                     HIV Infections
# 281   NCT00000767                                     HIV Infections
# 282   NCT00000768                                     HIV Infections
# 283   NCT00000769                                     HIV Infections
# 284   NCT00000771                                     HIV Infections
# 285   NCT00000773                                     HIV Infections
# 286   NCT00000773                    Pneumonia, Pneumocystis Carinii
# 287   NCT00000774                                 HIV Seronegativity
# 288   NCT00000776                                     HIV Infections
# 289   NCT00000777                                          Pregnancy
# 290   NCT00000777                                 HIV Seronegativity
# 291   NCT00000778                                     HIV Infections
# 292   NCT00000782                                     HIV Infections
# 293   NCT00000783                                            Healthy
# 294   NCT00000784                    Pneumonia, Pneumocystis Carinii
# 295   NCT00000784                                     HIV Infections
# 296   NCT00000785                                     HIV Infections
# 297   NCT00000788                                     HIV Infections
# 298   NCT00000793                  Peripheral Nervous System Disease
# 299   NCT00000794                                     HIV Infections
# 300   NCT00000796                                     HIV Infections
# 301   NCT00000799                                     HIV Infections
# 302   NCT00000801                                     HIV Infections
# 303   NCT00000802                    Pneumonia, Pneumocystis Carinii
# 304   NCT00000802                                     HIV Infections
# 305   NCT00000805                                     HIV Infections
# 306   NCT00000807                                     HIV Infections
# 307   NCT00000808                                          Pregnancy
# 308   NCT00000809                                 HIV Seronegativity
# 309   NCT00000811                    Pneumonia, Pneumocystis Carinii
# 310   NCT00000812                                     HIV Infections
# 311   NCT00000815                                     HIV Infections
# 312   NCT00000816                                     HIV Infections
# 313   NCT00000816                    Pneumonia, Pneumocystis Carinii
# 314   NCT00000817                  Peripheral Nervous System Disease
# 315   NCT00000817                                     HIV Infections
# 316   NCT00000820                                     HIV Infections
# 317   NCT00000823                                     HIV Infections
# 318   NCT00000826                                     HIV Infections
# 319   NCT00000828                                          Pregnancy
# 320   NCT00000829                                     HIV Infections
# 321   NCT00000830                                          Pregnancy
# 322   NCT00000836                                     HIV Infections
# 323   NCT00000837                                     HIV Infections
# 324   NCT00000839                                          Pregnancy
# 325   NCT00000842                                     HIV Infections
# 326   NCT00000842                  Peripheral Nervous System Disease
# 327   NCT00000843                                     HIV Infections
# 328   NCT00000856                                        Radiculitis
# 329   NCT00000856                                     HIV Infections
# 330   NCT00000856                                     Encephalopathy
# 331   NCT00000860                                     HIV Infections
# 332   NCT00000862                                          Pregnancy
# 333   NCT00000863                    Pneumonia, Pneumocystis Carinii
# 334   NCT00000866                                     HIV Infections
# 335   NCT00000868                                 HIV Seronegativity
# 336   NCT00000869                                          Pregnancy
# 337   NCT00000875                                     HIV Infections
# 338   NCT00000878                                          Pregnancy
# 339   NCT00000879                                 HIV Seronegativity
# 340   NCT00000881                                     HIV Infections
# 341   NCT00000883                                     HIV Infections
# 342   NCT00000887                                          Pregnancy
# 343   NCT00000888                                          Pregnancy
# 344   NCT00000894                                     HIV Infections
# 345   NCT00000901                                     HIV Infections
# 346   NCT00000905                                     HIV Infections
# 347   NCT00000907                                     HIV Infections
# 348   NCT00000908                    Pneumonia, Pneumocystis Carinii
# 349   NCT00000908                                     HIV Infections
# 350   NCT00000910                                          Pregnancy
# 351   NCT00000917                                          Pregnancy
# 352   NCT00000920                                          Pregnancy
# 353   NCT00000921                                     HIV Infections
# 354   NCT00000933                                     HIV Infections
# 355   NCT00000935                            End-Stage Renal Disease
# 356   NCT00000935                             Kidney Transplantation
# 357   NCT00000936                             Kidney Transplantation
# 358   NCT00000942                                          Pregnancy
# 359   NCT00000944                                          Pregnancy
# 360   NCT00000946                                 HIV Seronegativity
# 361   NCT00000947                                     HIV Infections
# 362   NCT00000949                                     HIV Infections
# 363   NCT00000950                                     HIV Infections
# 364   NCT00000951                                     HIV Infections
# 365   NCT00000953                                     HIV Infections
# 366   NCT00000954                                     HIV Infections
# 367   NCT00000960                                          Pregnancy
# 368   NCT00000966                                     HIV Infections
# 369   NCT00000968                                     HIV Infections
# 370   NCT00000970                                     HIV Infections
# 371   NCT00000971                                     HIV Infections
# 372   NCT00000972                                 HIV Seronegativity
# 373   NCT00000973                                     HIV Infections
# 374   NCT00000974                    Pneumonia, Pneumocystis Carinii
# 375   NCT00000980                                     HIV Infections
# 376   NCT00000981                                     HIV Infections
# 377   NCT00000982                                   Encephalopathies
# 378   NCT00000987                                     HIV Infections
# 379   NCT00000989                                     HIV Infections
# 380   NCT00000991                    Pneumonia, Pneumocystis Carinii
# 381   NCT00000994                                     HIV Infections
# 382   NCT00000995                                     HIV Infections
# 383   NCT00000996                                     HIV Infections
# 384   NCT00000997                                     HIV Infections
# 385   NCT00000998                                     HIV Infections
# 386   NCT00000998                    Pneumonia, Pneumocystis Carinii
# 387   NCT00001000                                     HIV Infections
# 388   NCT00001001                                     HIV Infections
# 389   NCT00001003                    Pneumonia, Pneumocystis Carinii
# 390   NCT00001003                                     HIV Infections
# 391   NCT00001010                                     HIV Infections
# 392   NCT00001013                    Pneumonia, Pneumocystis Carinii
# 393   NCT00001013                                     HIV Infections
# 394   NCT00001014                                     HIV Infections
# 395   NCT00001014                    Pneumonia, Pneumocystis Carinii
# 396   NCT00001016                                     HIV Infections
# 397   NCT00001016                    Pneumonia, Pneumocystis Carinii
# 398   NCT00001018                                     HIV Infections
# 399   NCT00001023                                     HIV Infections
# 400   NCT00001026                                     HIV Infections
# 401   NCT00001027                                     HIV Infections
# 402   NCT00001027                    Pneumonia, Pneumocystis Carinii
# 403   NCT00001028                                     HIV Infections
# 404   NCT00001028                    Pneumonia, Pneumocystis Carinii
# 405   NCT00001030                                     HIV Infections
# 406   NCT00001034                                     HIV Infections
# 407   NCT00001036                                     HIV Infections
# 408   NCT00001039                                     HIV Infections
# 409   NCT00001041                                          Pregnancy
# 410   NCT00001043                                 HIV Seronegativity
# 411   NCT00001046                                          Pregnancy
# 412   NCT00001046                                 HIV Seronegativity
# 413   NCT00001048                                     HIV Infections
# 414   NCT00001054                                     HIV Infections
# 415   NCT00001058                                     HIV Infections
# 416   NCT00001059                                     HIV Infections
# 417   NCT00001061                                     HIV Infections
# 418   NCT00001062                                     HIV Infections
# 419   NCT00001065                                     HIV Infections
# 420   NCT00001068                                     HIV Infections
# 421   NCT00001073                                  Cervix, Dysplasia
# 422   NCT00001078                                     HIV Infections
# 423   NCT00001081                                     HIV Infections
# 424   NCT00001082                                     HIV Infections
# 425   NCT00001089                                     HIV Infections
# 426   NCT00001103                                Cognitive Disorders
# 427   NCT00001103                                     HIV Infections
# 428   NCT00001104                                     HIV Infections
# 429   NCT00001105                                     HIV Infections
# 430   NCT00001106                                          Pregnancy
# 431   NCT00001109                                 HIV Seronegativity
# 432   NCT00001113                                     HIV Infections
# 433   NCT00001114                                     HIV Infections
# 434   NCT00001115                                     HIV Infections
# 435   NCT00001116                                     HIV Infections
# 436   NCT00001117                                     HIV Infections
# 437   NCT00001119                                     HIV Infections
# 438   NCT00001125                                     HIV Infections
# 439   NCT00001127                                          Influenza
# 440   NCT00001128                                     HIV Infections
# 441   NCT00001135                                          Pregnancy
# 442   NCT00001136                                 HIV Seronegativity
# 443   NCT00001142                                     HIV Infections
# 444   NCT00001142                                            Healthy
# 445   NCT00001142                                     Hyperlipidemia
# 446   NCT00001143                                            Healthy
# 447   NCT00001144                           Chronic Myeloid Leukemia
# 448   NCT00001145                       Immunoproliferative Disorder
# 449   NCT00001146                            Involutional Depression
# 450   NCT00001146                                      Mood Disorder
# 451   NCT00001147                                       Hypertension
# 452   NCT00001147                   Autonomic Nervous System Disease
# 453   NCT00001147                                            Healthy
# 454   NCT00001150                                            Healthy
# 455   NCT00001150                                           Neoplasm
# 456   NCT00001150                       Vesiculobullous Skin Disease
# 457   NCT00001154                                Hypolipoproteinemia
# 458   NCT00001154                                       Dyslipidemia
# 459   NCT00001154                                     Hyperlipidemia
# 460   NCT00001155                           Wegener's Granulomatosis
# 461   NCT00001156                       Tropical Spastic Paraparesis
# 462   NCT00001156                                   HTLV-I Infection
# 463   NCT00001156                            Herpesviridae Infection
# 464   NCT00001158                                          Neoplasms
# 465   NCT00001159                                    Grave's Disease
# 466   NCT00001160                          Follicular Thyroid Cancer
# 467   NCT00001160                        Hurthle Cell Thyroid Cancer
# 468   NCT00001160                   Tall Cell Variant Thyroid Cancer
# 469   NCT00001160                                     Thyroid Cancer
# 470   NCT00001160                           Papillary Thyroid Cancer
# 471   NCT00001161                                Open Angle Glaucoma
# 472   NCT00001161                                    Eye Abnormality
# 473   NCT00001162                       Parasitic Intestinal Disease
# 474   NCT00001162                                  Parasitic Disease
# 475   NCT00001162               Gastrointestinal Helminth Infections
# 476   NCT00001163                   Genetic Predisposition to Cancer
# 477   NCT00001163                                             Cancer
# 478   NCT00001163                                        Environment
# 479   NCT00001163                               Hereditary Neoplasms
# 480   NCT00001164                                            Healthy
# 481   NCT00001164                                 Muscular Dystrophy
# 482   NCT00001165                         Zollinger Ellison Syndrome
# 483   NCT00001165                                 Islet Cell Adenoma
# 484   NCT00001167                      Otorhinolaryngologic Neoplasm
# 485   NCT00001167                       Otorhinolaryngologic Disease
# 486   NCT00001167                                    Speech Disorder
# 487   NCT00001167                                Pharyngeal Neoplasm
# 488   NCT00001168                  Evaluation of Plasma Lipoproteins
# 489   NCT00001170                            Involutional Depression
# 490   NCT00001170                                      Mood Disorder
# 491   NCT00001171                                     Brain Neoplasm
# 492   NCT00001171                                 Pituitary Neoplasm
# 493   NCT00001172                                            Healthy
# 494   NCT00001173                                            Healthy
# 495   NCT00001177                                      Mood Disorder
# 496   NCT00001178                                    Down's Syndrome
# 497   NCT00001178                                Alzheimer's Disease
# 498   NCT00001180                                            Healthy
# 499   NCT00001180                        Adrenal Gland Hyperfunction
# 500   NCT00001180                         Adrenal Gland Hypofunction
# 501   NCT00001180                                 Cushing's Syndrome
# 502   NCT00001181                                 Precocious Puberty
# 503   NCT00001181                      Polyostotic Fibrous Dysplasia
# 504   NCT00001182                                      Tooth Disease
# 505   NCT00001182                                            Healthy
# 506   NCT00001183                                  Pulmonary Disease
# 507   NCT00001184                                 Ulcerative Colitis
# 508   NCT00001184                         Inflammatory Bowel Disease
# 509   NCT00001184                                   Chrohn's Disease
# 510   NCT00001186                                   Pediatric Cancer
# 511   NCT00001190                                    Growth Disorder
# 512   NCT00001191                         Zollinger Ellison Syndrome
# 513   NCT00001192                                        Head Injury
# 514   NCT00001192                                      Mood Disorder
# 515   NCT00001192                                   Anxiety Disorder
# 516   NCT00001194                                 Diagnostic Imaging
# 517   NCT00001195                                            Healthy
# 518   NCT00001196                                     Salivary Gland
# 519   NCT00001197                                 Sickle Cell Anemia
# 520   NCT00001198                Childhood Onset Psychotic Disorders
# 521   NCT00001198                                  Genetic Structure
# 522   NCT00001198                           Schizoaffective Disorder
# 523   NCT00001198                                          Psychosis
# 524   NCT00001201                              Neuromuscular Disease
# 525   NCT00001201                  Peripheral Nervous System Disease
# 526   NCT00001201                                            Healthy
# 527   NCT00001202                                 Precocious Puberty
# 528   NCT00001203                                      Heart Disease
# 529   NCT00001204           Homozygous Familial Hypercholesterolemic
# 530   NCT00001206  Attention Deficit and Disruptive Behavior Diso...
# 531   NCT00001209                                   Neuroepithelioma
# 532   NCT00001209                                   Sarcoma, Ewing's
# 533   NCT00001209                   Neuroectodermal Tumor, Primitive
# 534   NCT00001210                                            Healthy
# 535   NCT00001212                       Systemic Lupus Erythematosus
# 536   NCT00001215                        Lysosomal Storage Disorders
# 537   NCT00001216                                            Healthy
# 538   NCT00001218                                            Healthy
# 539   NCT00001219                                             Tumors
# 540   NCT00001219                   Abdominal Organs - Lipodystrophy
# 541   NCT00001220                               Deglutition Disorder
# 542   NCT00001221                                  Turner's Syndrome
# 543   NCT00001223                                           Diabetes
# 544   NCT00001223                     Liver Disease or Abnormalities
# 545   NCT00001223  Pancreatic Insufficiency (Exocrine and Endocrine)
# 546   NCT00001224                                        Eye Disease
# 547   NCT00001225                        Hypertrophic Cardiomyopathy
# 548   NCT00001226                               Hyperlipoproteinemia
# 549   NCT00001226                                            Healthy
# 550   NCT00001228                         Zollinger Ellison Syndrome
# 551   NCT00001228                                 Islet Cell Adenoma
# 552   NCT00001230                                Parasitic Infection
# 553   NCT00001231                                      Mood Disorder
# 554   NCT00001232                                            Healthy
# 555   NCT00001234                                  Gaucher's Disease
# 556   NCT00001235                                Alzheimer's Disease
# 557   NCT00001235                             Nervous System Disease
# 558   NCT00001237                      Lymphoma, Large-Cell, Diffuse
# 559   NCT00001237                    Lymphoma, Small Noncleaved-Cell
# 560   NCT00001238                        Familial Renal Cancer (FRC)
# 561   NCT00001238                       Urologic Malignant Disorders
# 562   NCT00001238                            Clear Cell Renal Cancer
# 563   NCT00001238                               Renal Cell Carcinoma
# 564   NCT00001238                                      Kidney Cancer
# 565   NCT00001239                                      Breast Cancer
# 566   NCT00001240                         Zollinger Ellison Syndrome
# 567   NCT00001241                         Zollinger Ellison Syndrome
# 568   NCT00001242                      Pseudopseudohpoparathyroidism
# 569   NCT00001243                                      HIV Infection
# 570   NCT00001244                                                XLA
# 571   NCT00001244                                               CVID
# 572   NCT00001245                                      HIV Infection
# 573   NCT00001245                                 Nematode Infection
# 574   NCT00001246           Attention Deficit Hyperactivity Disorder
# 575   NCT00001250                                    Breast Neoplasm
# 576   NCT00001251                                           Lymphoma
# 577   NCT00001251                                 Meningeal Neoplasm
# 578   NCT00001251                                           Leukemia
# 579   NCT00001252                                  Movement Disorder
# 580   NCT00001253                                  Turner's Syndrome
# 581   NCT00001254                         Zollinger Ellison Syndrome
# 582   NCT00001256                           Wegener's Granulomatosis
# 583   NCT00001257                        Abnormal Phagocyte Function
# 584   NCT00001257                                 Healthy Volunteers
# 585   NCT00001258                                   Healthy Subjects
# 586   NCT00001260                                Tourette's Syndrome
# 587   NCT00001261                            Inclusion Body Myositis
# 588   NCT00001262                                Kinky Hair Syndrome
# 589   NCT00001266                                 Prostatic Neoplasm
# 590   NCT00001271                                    B Cell Lymphoma
# 591   NCT00001275                          Premature Ovarian Failure
# 592   NCT00001277                               Parathyroid Neoplasm
# 593   NCT00001277                                               MEN1
# 594   NCT00001281                                                HIV
# 595   NCT00001281                                 Immunodeficiencies
# 596   NCT00001281                                Infectious Diseases
# 597   NCT00001282                                      HIV Infection
# 598   NCT00001284                                      Brain Mapping
# 599   NCT00001284                                           Genotype
# 600   NCT00001284                                               fMRI
# 601   NCT00001284             Allelic Frequencies of Genetic Markers
# 602   NCT00001284                                      Brain Disease
# 603   NCT00001285                                   Circadian Rhythm
# 604   NCT00001288                           Cerebrovascular Disorder
# 605   NCT00001289                                  Gaucher's Disease
# 606   NCT00001291                               Rheumatoid Arthritis
# 607   NCT00001292                               Genetic Skin Disease
# 608   NCT00001292                                Lamellar Ichthyosis
# 609   NCT00001292                             Keratosis Follicularis
# 610   NCT00001294                                   Kaposi's Sarcoma
# 611   NCT00001294                                      Homosexuality
# 612   NCT00001294                                      HIV Infection
# 613   NCT00001295                                             Cancer
# 614   NCT00001295                                                HIV
# 615   NCT00001302                                    Kidney Neoplasm
# 616   NCT00001302                                      Breast Cancer
# 617   NCT00001302                                           Lymphoma
# 618   NCT00001302                                     Ovarian Cancer
# 619   NCT00001303                                            Healthy
# 620   NCT00001303                                       Lung Disease
# 621   NCT00001303                                             Sepsis
# 622   NCT00001303                                       Septic Shock
# 623   NCT00001306                          Premature Ovarian Failure
# 624   NCT00001306                                 Autoimmune Disease
# 625   NCT00001307                  Peripheral Nervous System Disease
# 626   NCT00001307                                               Pain
# 627   NCT00001307                                            Healthy
# 628   NCT00001308                                            Healthy
# 629   NCT00001308                                     Voice Disorder
# 630   NCT00001308                             Communication Disorder
# 631   NCT00001309                                 Healthy Volunteers
# 632   NCT00001310                                    Corneal Disease
# 633   NCT00001310                                    Retinal Disease
# 634   NCT00001310                   Age-Related Macular Degeneration
# 635   NCT00001311                                          Cataracts
# 636   NCT00001313                             Pulmonary Hypertension
# 637   NCT00001313                         Diabetes and Heart Failure
# 638   NCT00001313                             Dilated Cardiomyopathy
# 639   NCT00001313                              Renal Artery Stenosis
# 640   NCT00001313                          Peripheral Artery Disease
# 641   NCT00001316                                                HIV
# 642   NCT00001317                      Chronic Granulomatous Disease
# 643   NCT00001318                                            Healthy
# 644   NCT00001318                 Mycobacterium Infections, Atypical
# 645   NCT00001319                                CD4 Lymphocytopenia
# 646   NCT00001319          Idiopathic CD4 Positive T Lymphocytopenia
# 647   NCT00001320                                            Healthy
# 648   NCT00001322                                 Healthy Volunteers
# 649   NCT00001323                                            Healthy
# 650   NCT00001323                                       Brain Injury
# 651   NCT00001323                                    Mental Disorder
# 652   NCT00001323                                           Dementia
# 653   NCT00001324                           Cerebrovascular Accident
# 654   NCT00001324                                  Movement Disorder
# 655   NCT00001324                                            Healthy
# 656   NCT00001325                                  Metabolic Disease
# 657   NCT00001325                               Generalized Epilepsy
# 658   NCT00001325                                   Infantile Spasms
# 659   NCT00001325                                   Partial Epilepsy
# 660   NCT00001327                            Arnold Chiari Deformity
# 661   NCT00001328                                     Brain Neoplasm
# 662   NCT00001329                                            Healthy
# 663   NCT00001329                   Autonomic Nervous System Disease
# 664   NCT00001330                         Scleroderma, Circumscribed
# ...
# 2803                                                NaN         NaN        NaN
# 2804                                                NaN         NaN        NaN
# 2805                                                NaN         NaN        NaN
# 2806                                                NaN         NaN        NaN
# 2807                                                NaN         NaN        NaN
# 2808                                                NaN         NaN        NaN
# 2809                                                NaN         NaN        NaN
# 2810                            precancerous conditions        98.0       98.0
# 2811                                                NaN         NaN        NaN
# 2812                                                NaN         NaN        NaN
# 2813                                                NaN         NaN        NaN
# 2814                                                NaN         NaN        NaN
# 2815                                                NaN         NaN        NaN
# 2816                                                NaN         NaN        NaN
# 2817                                                NaN         NaN        NaN
# 2818                                                NaN         NaN        NaN
# 2819                                                NaN         NaN        NaN
# 2820                                                NaN         NaN        NaN
# 2821                                                NaN         NaN        NaN
# 2822                                                NaN         NaN        NaN
# 2823                                                NaN         NaN        NaN
# 2824                                                NaN         NaN        NaN
# 2825                                                NaN         NaN        NaN
# 2826                                                NaN         NaN        NaN
# 2827                                                NaN         NaN        NaN
# 2828                                                NaN         NaN        NaN
# 2829                                                NaN         NaN        NaN
# 2830                                                NaN         NaN        NaN
# 2831                                                NaN         NaN        NaN
# 2832                                                NaN         NaN        NaN
# 2833                                                NaN         NaN        NaN
# 2834             leukemia, lymphocytic, chronic, b-cell       100.0       44.0
# 2835                                                NaN         NaN        NaN
# 2836                                                NaN         NaN        NaN
# 2837                                                NaN         NaN        NaN
# 2838                                                NaN         NaN        NaN
# 2839                                                NaN         NaN        NaN
# 2840                                                NaN         NaN        NaN
# 2841                                                NaN         NaN        NaN
# 2842                                                NaN         NaN        NaN
# 2843                                                NaN         NaN        NaN
# 2844                                                NaN         NaN        NaN
# 2845                                                NaN         NaN        NaN
# 2846                                                NaN         NaN        NaN
# 2847                                                NaN         NaN        NaN
# 2848                                                NaN         NaN        NaN
# 2849                                                NaN         NaN        NaN
# 2850                                                NaN         NaN        NaN
# 2851                                                NaN         NaN        NaN
# 2852                                                NaN         NaN        NaN
# 2853                                                NaN         NaN        NaN
# 2854                                                NaN         NaN        NaN
# 2855                                                NaN         NaN        NaN
# 2856                                                NaN         NaN        NaN
# 2857                                                NaN         NaN        NaN
# 2858                                                NaN         NaN        NaN
# 2859                                                NaN         NaN        NaN
# 2860                                                NaN         NaN        NaN
# 2861                                                NaN         NaN        NaN
# 2862                                                NaN         NaN        NaN
# 2863                                                NaN         NaN        NaN
# 2864                                                NaN         NaN        NaN
# 2865                                                NaN         NaN        NaN
# 2866                                                NaN         NaN        NaN
# 2867                                                NaN         NaN        NaN
# 2868                                                NaN         NaN        NaN
# 2869                                                NaN         NaN        NaN
# 2870                                                NaN         NaN        NaN
# 2871                                                NaN         NaN        NaN
# 2872                                                NaN         NaN        NaN
# 2873                                                NaN         NaN        NaN
# 2874                                                NaN         NaN        NaN
# 2875                                                NaN         NaN        NaN
# 2876                                                NaN         NaN        NaN
# 2877                                                NaN         NaN        NaN
# 2878                                                NaN         NaN        NaN
# 2879                                                NaN         NaN        NaN
# 2880                                                NaN         NaN        NaN
# 2881                                                NaN         NaN        NaN
# 2882                                                NaN         NaN        NaN
# 2883                                                NaN         NaN        NaN
# 2884                                                NaN         NaN        NaN
# 2885                                                NaN         NaN        NaN
# 2886                                                NaN         NaN        NaN
# 2887                                                NaN         NaN        NaN
# 2888                                                NaN         NaN        NaN
# 2889                                                NaN         NaN        NaN
# 2890                                                NaN         NaN        NaN
# 2891                              graft vs host disease        91.0       91.0
# 2892                                                NaN         NaN        NaN
# 2893                                                NaN         NaN        NaN
# 2894                              graft vs host disease        91.0       91.0
# 2895                                                NaN         NaN        NaN
# 2896                                                NaN         NaN        NaN
# 2897                                                NaN         NaN        NaN
# 2898                                                NaN         NaN        NaN
# 2899                                                NaN         NaN        NaN
# 2900                                                NaN         NaN        NaN
# 2901                                                NaN         NaN        NaN
# 2902                                                NaN         NaN        NaN
# 2903                                                NaN         NaN        NaN
# 2904                                                NaN         NaN        NaN
# 2905                                                NaN         NaN        NaN
# 2906                                                NaN         NaN        NaN
# 2907                                                NaN         NaN        NaN
# 2908                                                NaN         NaN        NaN
# 2909                                                NaN         NaN        NaN
# 2910                                                NaN         NaN        NaN
# 2911                                                NaN         NaN        NaN
# 2912                                                NaN         NaN        NaN
# 2913                                                NaN         NaN        NaN
# 2914                                                NaN         NaN        NaN
# 2915                                                NaN         NaN        NaN
# 2916                                                NaN         NaN        NaN
# 2917                                                NaN         NaN        NaN
# 2918                                                NaN         NaN        NaN
# 2919                                                NaN         NaN        NaN
# 2920                                                NaN         NaN        NaN
# 2921                                                NaN         NaN        NaN
# 2922                                                NaN         NaN        NaN
# 2923                                                NaN         NaN        NaN
# 2924                                                NaN         NaN        NaN
# 2925                                                NaN         NaN        NaN
# 2926                                                NaN         NaN        NaN
# 2927                                                NaN         NaN        NaN
# 2928                                                NaN         NaN        NaN
# 2929                                                NaN         NaN        NaN
# 2930                                                NaN         NaN        NaN
# 2931                                                NaN         NaN        NaN
# 2932                                                NaN         NaN        NaN
# 2933                                                NaN         NaN        NaN
# 2934                                                NaN         NaN        NaN
# 2935                                                NaN         NaN        NaN
# 2936                                                NaN         NaN        NaN
# 2937   leukemia, myelogenous, chronic, bcr-abl positive        99.0       69.0
# 2938                                                NaN         NaN        NaN
# 2939                                                NaN         NaN        NaN
# 2940                                                NaN         NaN        NaN
# 2941                                                NaN         NaN        NaN
# 2942                                                NaN         NaN        NaN
# 2943                                                NaN         NaN        NaN
# 2944                                                NaN         NaN        NaN
# 2945                                                NaN         NaN        NaN
# 2946                                                NaN         NaN        NaN
# 2947                                                NaN         NaN        NaN
# 2948                                                NaN         NaN        NaN
# 2949                                                NaN         NaN        NaN
# 2950                                                NaN         NaN        NaN
# 2951                                                NaN         NaN        NaN
# 2952                                                NaN         NaN        NaN
# 2953                                                NaN         NaN        NaN
# 2954                                                NaN         NaN        NaN
# 2955                                                NaN         NaN        NaN
# 2956                                                NaN         NaN        NaN
# 2957                                                NaN         NaN        NaN
# 2958                                                NaN         NaN        NaN
# 2959                                                NaN         NaN        NaN
# 2960                                                NaN         NaN        NaN
# 2961                                                NaN         NaN        NaN
# 2962                                                NaN         NaN        NaN
# 2963                                                NaN         NaN        NaN
# 2964                                                NaN         NaN        NaN
# 2965                                                NaN         NaN        NaN
# 2966                                                NaN         NaN        NaN
# 2967                            mesothelioma, malignant       100.0       53.0
# 2968                                                NaN         NaN        NaN
# 2969                                                NaN         NaN        NaN
# 2970                                                NaN         NaN        NaN
# 2971                                                NaN         NaN        NaN
# 2972                                                NaN         NaN        NaN
# 2973                                                NaN         NaN        NaN
# 2974                                                NaN         NaN        NaN
# 2975                                                NaN         NaN        NaN
# 2976                                                NaN         NaN        NaN
# 2977                                                NaN         NaN        NaN
# 2978                                                NaN         NaN        NaN
# 2979                                                NaN         NaN        NaN
# 2980                                                NaN         NaN        NaN
# 2981                                                NaN         NaN        NaN
# 2982                                                NaN         NaN        NaN
# 2983                                                NaN         NaN        NaN
# 2984                                                NaN         NaN        NaN
# 2985                                                NaN         NaN        NaN
# 2986                                                NaN         NaN        NaN
# 2987                                                NaN         NaN        NaN
# 2988                                                NaN         NaN        NaN
# 2989                                                NaN         NaN        NaN
# 2990                                                NaN         NaN        NaN
# 2991                                                NaN         NaN        NaN
# 2992                                                NaN         NaN        NaN
# 2993                                                NaN         NaN        NaN
# 2994                                                NaN         NaN        NaN
# 2995                                                NaN         NaN        NaN
# 2996                                                NaN         NaN        NaN
# 2997                                                NaN         NaN        NaN
# 2998                                                NaN         NaN        NaN
# 2999                                                NaN         NaN        NaN

# %%
conditions_reassorted_mapped = conditions_unmapped_all_mesh_terms[conditions_unmapped_all_mesh_terms["reassorted_ratio"] > 95]
with pd.option_context("display.max_rows", 1000):
    display(conditions_reassorted_mapped[:20])
print(len(conditions_reassorted_mapped))
# Out:
#          nct_id                    downcase_name  \
# 0   NCT00000102   congenital adrenal hyperplasia
# 7   NCT00000126        ischemic optic neuropathy
# 8   NCT00000127        ischemic optic neuropathy
# 11  NCT00000132              open-angle glaucoma
# 18  NCT00000140  proliferative vitreoretinopathy
# 22  NCT00000144              open-angle glaucoma
# 24  NCT00000149              open-angle glaucoma
# 26  NCT00000370                    social phobia
# 28  NCT00000375        major depressive disorder
# 35  NCT00000389                    social phobia
# 36  NCT00000389               separation anxiety
# 38  NCT00000395             rheumatoid arthritis
# 41  NCT00000401             rheumatoid arthritis
# 44  NCT00000414             rheumatoid arthritis
# 47  NCT00000416           ankylosing spondylitis
# 48  NCT00000416     systemic lupus erythematosus
# 50  NCT00000417     systemic lupus erythematosus
# 52  NCT00000419     systemic lupus erythematosus
# 53  NCT00000420     systemic lupus erythematosus
# 54  NCT00000421     systemic lupus erythematosus
#
#                   downcase_mesh_term  reassorted_ratio
# 0    adrenal hyperplasia, congenital               100
# 7         optic neuropathy, ischemic               100
# 8         optic neuropathy, ischemic               100
# 11              glaucoma, open-angle               100
# 18  vitreoretinopathy, proliferative               100
# 22              glaucoma, open-angle               100
# 24              glaucoma, open-angle               100
# 26                    phobia, social               100
# 28        depressive disorder, major               100
# 35                    phobia, social               100
# 36               anxiety, separation               100
# 38             arthritis, rheumatoid               100
# 41             arthritis, rheumatoid               100
# 44             arthritis, rheumatoid               100
# 47           spondylitis, ankylosing               100
# 48     lupus erythematosus, systemic               100
# 50     lupus erythematosus, systemic               100
# 52     lupus erythematosus, systemic               100
# 53     lupus erythematosus, systemic               100
# 54     lupus erythematosus, systemic               100
# 51671

# %%
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 249384  NCT00000110                                            Obesity
# 203653  NCT00000112                                           Diabetes
# 203651  NCT00000112                                            Obesity
# ...             ...                                                ...
# 472887  NCT05794061                               Psychiatric Disorder
# 472886  NCT05794061                                           Dementia
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name
# 25683                      congenital adrenal hyperplasia
# 228818                                             cancer
# 249384                                            obesity
# 203653                                           diabetes
# 203651                                            obesity
# ...                                                   ...
# 472887                               psychiatric disorder
# 472886                                           dementia
# 472885                               cognitive impairment
# 472884  nutrition deficiency (xanth deficiency) due to...
# 472883                                      air pollution
#
# [563678 rows x 3 columns]

# %%
conditions_95_reassorted_mapped = pd.merge(conditions_unmapped, # only these columns needed bc all other columns have null anyway (no match from previous merge)
                                            conditions_reassorted_mapped,
                                            how='left',
                                            left_on=['nct_id', 'downcase_name'],
                                            right_on = ['nct_id', 'downcase_name'])
conditions_95_reassorted_mapped
# Out:
#              nct_id                                               name  \
# 0       NCT00000102                     Congenital Adrenal Hyperplasia
# 1       NCT00000105                                             Cancer
# 2       NCT00000110                                            Obesity
# 3       NCT00000112                                           Diabetes
# 4       NCT00000112                                            Obesity
# ...             ...                                                ...
# 563768  NCT05794061                               Psychiatric Disorder
# 563769  NCT05794061                                           Dementia
# 563770  NCT05794061                               Cognitive Impairment
# 563771  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 563772  NCT05794087                                      Air Pollution
#
#                                             downcase_name  \
# 0                          congenital adrenal hyperplasia
# 1                                                  cancer
# 2                                                 obesity
# 3                                                diabetes
# 4                                                 obesity
# ...                                                   ...
# 563768                               psychiatric disorder
# 563769                                           dementia
# 563770                               cognitive impairment
# 563771  nutrition deficiency (xanth deficiency) due to...
# 563772                                      air pollution
#
#                      downcase_mesh_term  reassorted_ratio
# 0       adrenal hyperplasia, congenital             100.0
# 1                                   NaN               NaN
# 2                                   NaN               NaN
# 3                                   NaN               NaN
# 4                                   NaN               NaN
# ...                                 ...               ...
# 563768                              NaN               NaN
# 563769                              NaN               NaN
# 563770                              NaN               NaN
# 563771                              NaN               NaN
# 563772                              NaN               NaN
#
# [563773 rows x 5 columns]

# %%
conditions_unmapped = conditions_95_reassorted_mapped[conditions_95_reassorted_mapped['reassorted_ratio'].isnull()] # get the rows where mesh_term is empty bc there was no match there
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 1       NCT00000105                                             Cancer
# 2       NCT00000110                                            Obesity
# 3       NCT00000112                                           Diabetes
# 4       NCT00000112                                            Obesity
# 5       NCT00000115                             Macular Edema, Cystoid
# ...             ...                                                ...
# 563768  NCT05794061                               Psychiatric Disorder
# 563769  NCT05794061                                           Dementia
# 563770  NCT05794061                               Cognitive Impairment
# 563771  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 563772  NCT05794087                                      Air Pollution
#
#                                             downcase_name downcase_mesh_term  \
# 1                                                  cancer                NaN
# 2                                                 obesity                NaN
# 3                                                diabetes                NaN
# 4                                                 obesity                NaN
# 5                                  macular edema, cystoid                NaN
# ...                                                   ...                ...
# 563768                               psychiatric disorder                NaN
# 563769                                           dementia                NaN
# 563770                               cognitive impairment                NaN
# 563771  nutrition deficiency (xanth deficiency) due to...                NaN
# 563772                                      air pollution                NaN
#
#         reassorted_ratio
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ...                  ...
# 563768               NaN
# 563769               NaN
# 563770               NaN
# 563771               NaN
# 563772               NaN
#
# [512102 rows x 5 columns]

# %%
# find the best match from MESH list terms per term (one with highest ratio)

# %%
conditions_unmapped_list = conditions_unmapped.downcase_name.to_list()[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 conditions_unmapped_list = conditions_unmapped.downcase_name.to_list()[:10]
#
# NameError: name 'conditions_unmapped' is not defined

# %%
conditions_fuzzmatched = conditions_unmapped_fuzzmatch.dropna(subset=['downcase_mesh_term'])
conditions_fuzzmatched[:20]
# Out:
#          nct_id                    downcase_name  \
# 0   NCT00000102   congenital adrenal hyperplasia
# 1   NCT00000105                           cancer
# 3   NCT00000112                         diabetes
# 4   NCT00000112                          obesity
# 5   NCT00000115           macular edema, cystoid
# 6   NCT00000123                           myopia
# 7   NCT00000126        ischemic optic neuropathy
# 8   NCT00000127        ischemic optic neuropathy
# 9   NCT00000128                        esophoria
# 10  NCT00000128                           myopia
# 11  NCT00000132              open-angle glaucoma
# 12  NCT00000135                   hiv infections
# 13  NCT00000136                   hiv infections
# 16  NCT00000138            ocular herpes simplex
# 17  NCT00000139            ocular herpes simplex
# 18  NCT00000140  proliferative vitreoretinopathy
# 19  NCT00000142                   hiv infections
# 20  NCT00000142    cmv cytomegalovirus retinitis
# 21  NCT00000143                   hiv infections
# 22  NCT00000144              open-angle glaucoma
#
#                                    downcase_mesh_term
# 0   [adrenal hyperplasia, congenital, adrenogenita...
# 1   [tetanus, clostridium infections, gram-positiv...
# 3   [melanosis, acanthosis nigricans, glucose into...
# 4   [melanosis, acanthosis nigricans, glucose into...
# 5   [retinal diseases, macular edema, edema, macul...
# 6      [astigmatism, refractive errors, eye diseases]
# 7   [ischemia, optic nerve diseases, optic neuropa...
# 8   [optic nerve diseases, optic neuropathy, ische...
# 9   [strabismus, esotropia, eye diseases, ocular m...
# 10  [strabismus, esotropia, eye diseases, ocular m...
# 11  [glaucoma, glaucoma, open-angle, ocular hypert...
# 12  [cytomegalovirus retinitis, retinitis, infecti...
# 13  [cytomegalovirus retinitis, retinitis, infecti...
# 16  [herpes simplex, keratitis, herpetic, keratiti...
# 17  [herpes simplex, keratitis, herpetic, keratiti...
# 18  [retinal detachment, vitreoretinopathy, prolif...
# 19  [cytomegalovirus retinitis, retinitis, infecti...
# 20  [cytomegalovirus retinitis, retinitis, infecti...
# 21  [cytomegalovirus retinitis, retinitis, infecti...
# 22  [glaucoma, glaucoma, open-angle, ocular hypert...

# %%
len(conditions_fuzzmatched)
# Out:
# 462404

# %%
for index, row in conditions_fuzzmatched.iterrows():
#     print(row["downcase_mesh_term"])
    for term in row["downcase_mesh_term"]:
        reassorted_ratio = ratio(row["downcase_name"], term)
#         print([row["downcase_name"], term])
#         print(reassorted_ratio)
        if reassorted_ratio == 100:
            conditions_fuzzmatched.loc[index,"reassorted_mesh_match"] = term

conditions_fuzzmatched[:30]
# Out:
# /var/folders/49/18qlr0bn7xg_mk2pzxvrb0f80000gn/T/ipykernel_17812/3826430153.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conditions_fuzzmatched.loc[index,"reassorted_mesh_match"] = term
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [140], in <cell line: 1>()
#       1 for index, row in conditions_fuzzmatched.iterrows():
#       2 #     print(row["downcase_mesh_term"])
#       3     for term in row["downcase_mesh_term"]:
# ----> 4         reassorted_ratio = ratio(row["downcase_name"], term)
#       5 #         print([row["downcase_name"], term])
#       6 #         print(reassorted_ratio)
#       7         if reassorted_ratio == 100:
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/numpy/lib/function_base.py:2304, in vectorize.__call__(self, *args, **kwargs)
#    2301     vargs = [args[_i] for _i in inds]
#    2302     vargs.extend([kwargs[_n] for _n in names])
# -> 2304 return self._vectorize_call(func=func, args=vargs)
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/numpy/lib/function_base.py:2382, in vectorize._vectorize_call(self, func, args)
#    2380     res = func()
#    2381 else:
# -> 2382     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2384     # Convert args to object arrays first
#    2385     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~/opt/anaconda3/envs/ct_extract_env/lib/python3.9/site-packages/numpy/lib/function_base.py:2342, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2338     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2339                      'unless `otypes` is set')
#    2341 inputs = [arg.flat[0] for arg in args]
# -> 2342 outputs = func(*inputs)
#    2344 # Performance note: profiling indicates that -- for simple
#    2345 # functions at least -- this wrapping can almost double the
#    2346 # execution time.
#    2347 # Hence we make it optional.
#    2348 if self.cache:
#
# Input In [114], in get_token_sort_ratio(str1, str2)
#       1 def get_token_sort_ratio(str1, str2):
# ----> 2     return fuzz.token_sort_ratio(str1, str2)
#
# KeyboardInterrupt:

# %%
# find studies for which there is only 1 condition listed (from unmapped conditions)
conditions_unmapped_per_study = pd.DataFrame(conditions_unmapped.groupby("nct_id")["downcase_name"].apply(list))
with pd.option_context("display.max_rows", 1000):
    display(conditions_unmapped_per_study[:20])
# Out:
#                                                downcase_name
# nct_id
# NCT00000102                 [congenital adrenal hyperplasia]
# NCT00000105                                         [cancer]
# NCT00000110                                        [obesity]
# NCT00000112                              [diabetes, obesity]
# NCT00000115                         [macular edema, cystoid]
# NCT00000123                                         [myopia]
# NCT00000126                      [ischemic optic neuropathy]
# NCT00000127                      [ischemic optic neuropathy]
# NCT00000128                              [esophoria, myopia]
# NCT00000132                            [open-angle glaucoma]
# NCT00000135                                 [hiv infections]
# NCT00000136                                 [hiv infections]
# NCT00000137       [graft rejection, corneal transplantation]
# NCT00000138                          [ocular herpes simplex]
# NCT00000139                          [ocular herpes simplex]
# NCT00000140                [proliferative vitreoretinopathy]
# NCT00000142  [hiv infections, cmv cytomegalovirus retinitis]
# NCT00000143                                 [hiv infections]
# NCT00000144                            [open-angle glaucoma]
# NCT00000145                                 [lens opacities]

# %%
conditions_unmapped_per_study["condition_counts"] = conditions_unmapped_per_study["downcase_name"].str.len()
conditions_unmapped_per_study
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# ...                                                        ...
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000112                 2
# NCT00000115                 1
# ...                       ...
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
# NCT05794074                 1
# NCT05794087                 1
#
# [344498 rows x 2 columns]

# %%
unmapped_single_conditions = conditions_unmapped_per_study[conditions_unmapped_per_study["condition_counts"] == 1]
unmapped_single_conditions
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000115                           [macular edema, cystoid]
# NCT00000123                                           [myopia]
# ...                                                        ...
# NCT05793944                                        [pregnancy]
# NCT05794009                                 [exercise therapy]
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000115                 1
# NCT00000123                 1
# ...                       ...
# NCT05793944                 1
# NCT05794009                 1
# NCT05794035                 1
# NCT05794074                 1
# NCT05794087                 1
#
# [241959 rows x 2 columns]

# %%
mapped_single_conditions = pd.merge(unmapped_single_conditions, condition_mesh_leaves[["nct_id", "downcase_mesh_term"]], left_on=["nct_id"], right_on=["nct_id"])
with pd.option_context("display.max_rows", 1000):
    display(mapped_single_conditions[:20])
# Out:
#          nct_id                     downcase_name  condition_counts  \
# 0   NCT00000102  [congenital adrenal hyperplasia]                 1
# 1   NCT00000102  [congenital adrenal hyperplasia]                 1
# 2   NCT00000102  [congenital adrenal hyperplasia]                 1
# 3   NCT00000102  [congenital adrenal hyperplasia]                 1
# 4   NCT00000105                          [cancer]                 1
# 5   NCT00000115          [macular edema, cystoid]                 1
# 6   NCT00000115          [macular edema, cystoid]                 1
# 7   NCT00000123                          [myopia]                 1
# 8   NCT00000126       [ischemic optic neuropathy]                 1
# 9   NCT00000126       [ischemic optic neuropathy]                 1
# 10  NCT00000126       [ischemic optic neuropathy]                 1
# 11  NCT00000127       [ischemic optic neuropathy]                 1
# 12  NCT00000127       [ischemic optic neuropathy]                 1
# 13  NCT00000127       [ischemic optic neuropathy]                 1
# 14  NCT00000132             [open-angle glaucoma]                 1
# 15  NCT00000132             [open-angle glaucoma]                 1
# 16  NCT00000135                  [hiv infections]                 1
# 17  NCT00000135                  [hiv infections]                 1
# 18  NCT00000136                  [hiv infections]                 1
# 19  NCT00000136                  [hiv infections]                 1
#
#                  downcase_mesh_term
# 0   adrenal hyperplasia, congenital
# 1            adrenogenital syndrome
# 2      adrenocortical hyperfunction
# 3                       hyperplasia
# 4                           tetanus
# 5                     macular edema
# 6                             edema
# 7                       astigmatism
# 8                          ischemia
# 9              optic nerve diseases
# 10       optic neuropathy, ischemic
# 11             optic nerve diseases
# 12       optic neuropathy, ischemic
# 13                         ischemia
# 14                         glaucoma
# 15             glaucoma, open-angle
# 16        cytomegalovirus retinitis
# 17                        retinitis
# 18        cytomegalovirus retinitis
# 19                        retinitis

# %% [markdown]
# ### Conclusion: there are multiple candidate MeSH terms (leaf nodes only, not ancestors) available per 1 condition

# %% [markdown]
# # Use MetaMap to find more candidate matches

# %%
CAS_SERVERURL = "https://utslogin.nlm.nih.gov/cas/v1"
II_SKR_SERVERURL = 'https://ii.nlm.nih.gov/cgi-bin/II/UTS_Required'
METAMAP_INTERACTIVE_URL = II_SKR_SERVERURL + "/API_MM_interactive.pl"
stserverurl = "https://utslogin.nlm.nih.gov/cas/v1/tickets"
tgtserverurl = "https://utslogin.nlm.nih.gov/cas/v1/api-key"
apikey = '54041f07-fc66-4558-b038-b46ca8bdcc6b'
serviceurl = METAMAP_INTERACTIVE_URL
ksource = '2020AB'

def get_service_ticket(serverurl, ticket_granting_ticket, serviceurl):
    """ Obtain a Single-Use Proxy Ticket (also known as service ticket).
    Request for a Service Ticket:
        POST /cas/v1/tickets/{TGT id} HTTP/1.0
    data:
           service={form encoded parameter for the service url}
    Sucessful Response:
        200 OK
        ST-1-FFDFHDSJKHSDFJKSDHFJKRUEYREWUIFSD2132
    @param serverurl authentication server
    @param ticketGrantingTicket a Proxy Granting Ticket.
    @param serviceurl url of service with protected resources
    @return authentication ticket for service. """
    resp = requests.post("{}/{}".format(serverurl, ticket_granting_ticket),
                         {"service": serviceurl})
    if resp.status_code == 200:
        return resp.content
    return 'Error: status: {}'.format(resp.content)


def extract_tgt_ticket(htmlcontent):
    "Extract ticket granting ticket from HTML."
    # print('htmlcontent: {}'.format(htmlcontent))
    html = HTML(html=htmlcontent)
    # get form element
    elements = html.xpath("//form")
    # print('html response: {}'.format(etree.tostring(html.lxml).decode()))
    # print('action attribure: {}'.format(elements[0].attrs['action']))
    # extract ticket granting ticket out of 'action' attribute
    if elements != []:
        return elements[0].attrs['action'].split('/')[-1]
    else:
        return "form element missing from ticket granting ticket response"

def get_ticket(cas_serverurl, apikey, serviceurl):
    # set ticket granting ticket server url
    tgtserverurl = cas_serverurl + "/api-key"
    # set service ticket server url
    stserverurl = cas_serverurl + "/tickets"
    tgt = get_ticket_granting_ticket(tgtserverurl, apikey)
    return get_service_ticket(stserverurl, tgt, serviceurl)

def get_ticket_granting_ticket(tgtserverurl, apikey):
    # http://serviceurl/cas/v1/tickets/{TGT id}
    response = requests.post(tgtserverurl, {'apikey': apikey},
                             headers={'Accept': 'test/plain'})
    return extract_tgt_ticket(response.content)

def extract_tgt_ticket(htmlcontent):
    "Extract ticket granting ticket from HTML."    
    soup = BeautifulSoup(htmlcontent)
#     print(soup.find('form').get("action"))
    cas_url = soup.find("form").get("action")
    "Extract ticket granting ticket out of 'action' attribute"
#     tgt = cas_url.rsplit('/')[-1]
    return cas_url.rsplit('/')[-1]
    
ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)

# %%
def get_redirect_target(resp):
        """Receives a Response. Returns a redirect URI or ``None``"""
        # Due to the nature of how requests processes redirects this method will
        # be called at least once upon the original response and at least twice
        # on each subsequent redirect response (if any).
        # If a custom mixin is used to handle this logic, it may be advantageous
        # to cache the redirect location onto the response object as a private
        # attribute.
        if resp.is_redirect:
            location = resp.headers["location"]
            # Currently the underlying http module on py3 decode headers
            # in latin1, but empirical evidence suggests that latin1 is very
            # rarely used with non-ASCII characters in HTTP headers.
            # It is more likely to get UTF8 header rather than latin1.
            # This causes incorrect handling of UTF8 encoded location headers.
            # To solve this, we re-encode the location in latin1.
#             print(location)
            location = location.encode("latin1")
#             print(location)
#             print(to_native_string(location, "utf8"))
            return to_native_string(location, "utf8")
        return None

if response.status_code == 302:
    newurl = s.get_redirect_target(response)
    response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)

# %%
# get concepts to map
conditions_unmapped.downcase_name.to_list()[:10]
# Out:
# ['congenital adrenal hyperplasia',
#  'cancer',
#  'obesity',
#  'diabetes',
#  'obesity',
#  'macular edema, cystoid',
#  'myopia',
#  'ischemic optic neuropathy',
#  'ischemic optic neuropathy',
#  'esophoria']

# %%
conditions_unmapped
# Out:
#              nct_id                                               name  \
# 25683   NCT00000102                     Congenital Adrenal Hyperplasia
# 228818  NCT00000105                                             Cancer
# 249384  NCT00000110                                            Obesity
# 203653  NCT00000112                                           Diabetes
# 203651  NCT00000112                                            Obesity
# ...             ...                                                ...
# 472887  NCT05794061                               Psychiatric Disorder
# 472886  NCT05794061                                           Dementia
# 472885  NCT05794061                               Cognitive Impairment
# 472884  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 472883  NCT05794087                                      Air Pollution
#
#                                             downcase_name mesh_term  \
# 25683                      congenital adrenal hyperplasia       NaN
# 228818                                             cancer       NaN
# 249384                                            obesity       NaN
# 203653                                           diabetes       NaN
# 203651                                            obesity       NaN
# ...                                                   ...       ...
# 472887                               psychiatric disorder       NaN
# 472886                                           dementia       NaN
# 472885                               cognitive impairment       NaN
# 472884  nutrition deficiency (xanth deficiency) due to...       NaN
# 472883                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type
# 25683                 NaN       NaN
# 228818                NaN       NaN
# 249384                NaN       NaN
# 203653                NaN       NaN
# 203651                NaN       NaN
# ...                   ...       ...
# 472887                NaN       NaN
# 472886                NaN       NaN
# 472885                NaN       NaN
# 472884                NaN       NaN
# 472883                NaN       NaN
#
# [563678 rows x 6 columns]

# %%
len(conditions_unmapped['downcase_name'].to_list())
# Out:
# 563678

# %%
len(set(conditions_unmapped['downcase_name'].to_list()))
# Out:
# 99253

# %%
conditions_unmapped_list = list(set(conditions_unmapped.downcase_name.to_list())) # get unique unmapped terms
conditions_unmapped_list = [s + "\r\n" for s in conditions_unmapped_list] # you must include newline to process each term separately!
print(len(conditions_unmapped_list))
# Out:
# 99253

# %%
def split_list_by_length(lst):
    result = []
    current_sublist = []
    current_length = 0
    for item in lst:
        item_length = len(item)
        if current_length + item_length > 9990: # max is 10,000 char allowed by MetaMap
            result.append(current_sublist)
            current_sublist = []
            current_length = 0
        current_sublist.append(item)
        current_length += item_length
    result.append(current_sublist)
    return result

# %%
chunked_conditions_unmapped = split_list_by_length(conditions_unmapped_list)
chunked_conditions_unmapped[:1]
# Out:
# [['kearns sayer\r\n',
#   'hereditary angioedema - type 1\r\n',
#   'respiratory muscles\r\n',
#   'hepatic tumor\r\n',
#   'parent-child relationship\r\n',
#   'caesarean scar pregnancy\r\n',
#   'sleep hygiene\r\n',
#   'ganglioneuroblastoma of central nervous system\r\n',
#   'g6pd\r\n',
#   'antineoplastic adverse reaction\r\n',
#   'isoflurane\r\n',
#   'ocular tumor\r\n',
#   'triple negative breast cancer, tnbc\r\n',
#   'risk of bone fracture occurrences\r\n',
#   'infants\r\n',
#   'attenuated or transient psychosis\r\n',
#   'erythema migrans\r\n',
#   'malignant pleural mesothelioma, advanced\r\n',
#   'degenerative\r\n',
#   'ataxia\r\n',
#   'non alcoholic fatty liver\r\n',
#   'myoma of uterus\r\n',
#   'macular degeneration, choroidal neovascularization\r\n',
#   'newborn, infant, disease\r\n',
#   'viral; infection, coxsackie(virus)\r\n',
#   'functional dysphonia\r\n',
#   'advanced recurrent ovarian tumors\r\n',
#   'primary focal hyperhidrosis of the hands\r\n',
#   'gallbladder adenocarcinoma, biliary type\r\n',
#   'sacral myelomeningocele\r\n',
#   'gender differences\r\n',
#   'home blood pressure monitoring\r\n',
#   'slippery pulse\r\n',
#   'neonatal phototherapy\r\n',
#   'gene transfer\r\n',
#   'thoracic endovascular repair\r\n',
#   'drug binding to dat receptors\r\n',
#   'periodontal disease and caries\r\n',
#   'pulmonary mac\r\n',
#   'c-staged hepatocellular carcinoma in bclc classification\r\n',
#   'respiratory distress syndrome, pediatric\r\n',
#   'bloodpressure\r\n',
#   'hepatocyte receptor\r\n',
#   'deep wrinkles of the forehead\r\n',
#   'clinical decision support system (cdss)\r\n',
#   'malignant ovarian endometrioid tumor\r\n',
#   'severe marrow failure\r\n',
#   'diagnoses that require stem cell transplant\r\n',
#   'emotional disorder\r\n',
#   'mannose-binding lectin complement pathway\r\n',
#   'cervical neoplasia\r\n',
#   'hormonal changes\r\n',
#   'head and neck surgeries\r\n',
#   'hemolytic-uremic syndrome, atypical\r\n',
#   'abdominal aortic aneurysms with challenging anatomy\r\n',
#   'central blood pressure\r\n',
#   'vaccine\r\n',
#   'lower grade glioma, recurrent\r\n',
#   'male sterilization\r\n',
#   'diabetes mellitus type 2 without complication\r\n',
#   'body contouring surgery\r\n',
#   'parenteral nutrition (no primary condition studied)\r\n',
#   'lung structure determination\r\n',
#   'immunologically-induced lung disease\r\n',
#   'medulloblastoma, group 4\r\n',
#   'death, sudden,cardiac\r\n',
#   'the clinical application guide of conebeam breast ct\r\n',
#   'beta rhythm\r\n',
#   'fracture of long bones\r\n',
#   'target controlled infusion (tci)\r\n',
#   'elite athletes\r\n',
#   'primary\r\n',
#   'spina bifida and anencephaly\r\n',
#   'pre-term birth\r\n',
#   'grönblad-stranberg disease (pseudoxanthoma elasticum)\r\n',
#   'hip impairments\r\n',
#   'vulval dermatoses\r\n',
#   'sex hormones\r\n',
#   'squamous-cell non-small cell lung cancer\r\n',
#   'suspected lung cancer\r\n',
#   'sleep disturbances in survivors of critical illness\r\n',
#   'age-related sarcopenia\r\n',
#   'bra strap fat (bsf)\r\n',
#   'chronic periaortitis\r\n',
#   'undetected intraoperative blood loss\r\n',
#   'human bocavirus\r\n',
#   'decayed tooth\r\n',
#   'allogeneic hematopoietic cell transplant recipients\r\n',
#   'popliteal nerve block\r\n',
#   'superinfection lung\r\n',
#   'pd\r\n',
#   'single dose\r\n',
#   'pustular psoriasis\r\n',
#   'pharmacologic action\r\n',
#   'chronic migraine headache\r\n',
#   'additional indications below for module 4 and 5\r\n',
#   'methamphetamine withdrawal\r\n',
#   'cortical organisation of vestibular integration\r\n',
#   'planned rrso\r\n',
#   'articular cartilage defects of knee\r\n',
#   'self reported ratings of hunger\r\n',
#   'rectal hyposensitivity\r\n',
#   'fetal renal anomaly\r\n',
#   'cartilage injuries in the human knee\r\n',
#   'kcnma1-channelopathy\r\n',
#   'community-dwelling older adults\r\n',
#   'parkinson disease, mitochondrial\r\n',
#   'adherence to personalized ebm anticoagulant treatment in patients at high risk for stroke\r\n',
#   'acute alcohol intoxication\r\n',
#   'rheumatoid arthritis - hand joint\r\n',
#   'pharmacogenetic study\r\n',
#   'recurrent staphylococcal infection\r\n',
#   'ass-nonresponse\r\n',
#   'hematopoietic stem cell transplantation-associated thrombotic microangiopathy\r\n',
#   'small bowel bacterial overgrowth syndrome (sbbos)\r\n',
#   'adverse outcomes\r\n',
#   'absorption; chemicals\r\n',
#   'well-being\r\n',
#   'arterial thromboembolism\r\n',
#   'breast hypoplasia\r\n',
#   'brain edema caused by drugs\r\n',
#   'innate inflammatory response\r\n',
#   'stage iii kidney cancer\r\n',
#   'unresponsive wakefulness syndrome\r\n',
#   'early childhood caries, vitamin d deficiency\r\n',
#   'vulvar cancer\r\n',
#   'morquio syndrome a\r\n',
#   'blood donors, traumatic blood loss\r\n',
#   'inflammatory myopathy\r\n',
#   'basic english speaker\r\n',
#   'norwalk gastroenteritis\r\n',
#   'thyroid hormones\r\n',
#   'short uterine cervical length\r\n',
#   'extrapyramidal symptoms\r\n',
#   'neonatal hypothermia\r\n',
#   'parotid gland tumor\r\n',
#   'taste testing\r\n',
#   'prostate cancer metastatic\r\n',
#   'upper airway sonographic evaluation\r\n',
#   'multiresistant bacterial pathogens\r\n',
#   'hemiplegic\r\n',
#   'hepatitis c virus (hcv) coinfection\r\n',
#   'central pain syndromes\r\n',
#   'familial atrial fibrillation\r\n',
#   'gastric, or gastroesophageal junction adenocarcinoma\r\n',
#   'osteosarcoma of pelvis\r\n',
#   'cataract mature\r\n',
#   'caries; initial\r\n',
#   'arthroplasty, replacement, knee\r\n',
#   'crohn disease of vulva\r\n',
#   'single photon emission computed tomography\r\n',
#   'ibs-c and ibs with mixed bowel habits\r\n',
#   'enterobacteria susceptible to carbapenem carrier\r\n',
#   'rendu osler weber\r\n',
#   'postoperative ecchymosis\r\n',
#   'choroidal neo-vascular age-onset macular degeneration\r\n',
#   'solid organ transplantation recipient\r\n',
#   'radiation-induced fibrosis in patients with head and neck cancer\r\n',
#   'asphyxiating thoracic dystrophy\r\n',
#   'dropout\r\n',
#   'diphtheria vaccine adverse reaction\r\n',
#   'progressive metastatic malignancies\r\n',
#   'oculopalatal tremor\r\n',
#   'sars-cov 2\r\n',
#   'malignant hematologic neoplasm\r\n',
#   'small cell lung cancers\r\n',
#   'post-anoxic coma\r\n',
#   'bilateral nasal polyposis\r\n',
#   'advance directives\r\n',
#   'perfusion index as an early predictor of successful supraclavicular block\r\n',
#   'diabetic foot ulcer outcome\r\n',
#   'ear, nose and throat disorder\r\n',
#   'onset and duration of a digital nerve block\r\n',
#   'adult stem cells\r\n',
#   'craniocerebral injuries\r\n',
#   'gynecologic oncological pelvic/abdominal surgery\r\n',
#   'minimally invasive fetoscopic procedures\r\n',
#   "vater's ampulla\r\n",
#   'loiasis\r\n',
#   'chloasma\r\n',
#   'glucose-galactose malabsorption\r\n',
#   'case fatality rate\r\n',
#   'allogeneic hematopoietic transplant\r\n',
#   'treatment-refractory mycobacterium avium complex-lung disease (mac-ld)\r\n',
#   'anemia, neoplasms\r\n',
#   'intracranial surgery\r\n',
#   'dietary selenium deficiency\r\n',
#   'polr3a mutatie\r\n',
#   'noncontiguous stage ii grade 3 follicular lymphoma\r\n',
#   'cohort studies\r\n',
#   'elderly cancer patients\r\n',
#   'stage ii testicular choriocarcinoma ajcc v6 and v7\r\n',
#   'hydatidiform moles\r\n',
#   'ovarian papillary serous carcinoma\r\n',
#   'body contouring\r\n',
#   'skin graft (allograft)(autograft) failure\r\n',
#   'high dosage buprenorphine\r\n',
#   'nervus intermedius neuralgia\r\n',
#   'signs and symptoms\r\n',
#   'adult acute myeloblastic leukemia without maturation (m1)\r\n',
#   'trauma nervous system\r\n',
#   'chiropractic\r\n',
#   'fetal heart rate or rhythm abnormality affecting fetus\r\n',
#   'behavioral performance\r\n',
#   'single-photon emission computed tomography (spect)\r\n',
#   'communication aids for disabled\r\n',
#   'delayed healing\r\n',
#   'ect.\r\n',
#   'infertile patients\r\n',
#   'painful intercourse\r\n',
#   'carcinoma prostate\r\n',
#   'carcinoma of the cervix\r\n',
#   'cerebral palsy, dyskinetic\r\n',
#   '1q21.1 deletion\r\n',
#   'paravaginal cystocele\r\n',
#   'acute migraine\r\n',
#   'cryptogenic chronic hepatitis\r\n',
#   'relapsed or refractory non-hodgkin lymphoma\r\n',
#   'coronary artery disease (cad) (e.g., angina, myocardial infarction, and atherosclerotic heart disease (ashd))\r\n',
#   'b-cell small lymphocytic lymphoma\r\n',
#   'photochemotherapy\r\n',
#   'fracture of tibia fibula\r\n',
#   'human papillomavirus (hpv) infection\r\n',
#   'exacerbation of chronic heart failure\r\n',
#   'esophageal surgery cancer\r\n',
#   'covid-19 thalidomide\r\n',
#   'metastatic castration sensitive prostate cancer\r\n',
#   'mesenchymal stromal cells\r\n',
#   'prevention of chronic disease\r\n',
#   'upper gastrointestinal lesions\r\n',
#   'thoracic aorta\r\n',
#   'stage iic fallopian tube cancer\r\n',
#   'pincer nail\r\n',
#   'mechanical ventilation time\r\n',
#   'acne detergicans\r\n',
#   'malignant and pre-malignant changes in the polyp\r\n',
#   'prophylaxis of influenza\r\n',
#   'biological samples\r\n',
#   'opiate substitution treatment\r\n',
#   'able bodied\r\n',
#   'aids-related immunoblastic large cell lymphoma\r\n',
#   'overall response rate\r\n',
#   'clinical stage iii hpv-mediated (p16-positive) oropharyngeal carcinoma ajcc v8\r\n',
#   'retirement\r\n',
#   'early-onset alzheimer disease\r\n',
#   'impoverished population\r\n',
#   'diabetic stable angina\r\n',
#   'patient without treatment against a.fumigatus\r\n',
#   'oral bacteria levels in the mouth\r\n',
#   'chronic pancreatitis\r\n',
#   'patient doctor trust\r\n',
#   'hormone-dependent prostate cancer\r\n',
#   'endometrioid adenocarcinoma\r\n',
#   'opioid use disorders\r\n',
#   'metastatic malignant neoplasm in the thoracic cavity\r\n',
#   'embolization therapeutic\r\n',
#   'ulcerative rectocolitis\r\n',
#   'adult-onset diabetes mellitus\r\n',
#   'congenital heart block\r\n',
#   'urologic surgical procedures\r\n',
#   'apomorphine-induced skin reactions\r\n',
#   'endobronchial growth\r\n',
#   'natural kicetics of d-dimers after surgery\r\n',
#   'infection rate after fingertip amputation\r\n',
#   'healed erosive esophagitis\r\n',
#   'dementia with lewy bodies diagnosis\r\n',
#   'sugammadex\r\n',
#   'platinum-sensitive ovarian cancer (upgrade-a)\r\n',
#   'sandplay therapy\r\n',
#   'brca1/2\r\n',
#   'diabetic peripheral vascular disease\r\n',
#   'carcinoma breast stage iv\r\n',
#   'airway device\r\n',
#   'icd and crt-d indicated patients\r\n',
#   'mild to moderate depression.\r\n',
#   'acute ischemic stroke, cerebral embolism and thrombosis\r\n',
#   'recurrent viral meningitis\r\n',
#   'pediatric hematologic malignancies\r\n',
#   'euglycemia\r\n',
#   'exercise fat oxidation\r\n',
#   'prostate cancer screening\r\n',
#   'malnourished children\r\n',
#   'pathologic stage ib cutaneous melanoma ajcc v8\r\n',
#   'fear of needles\r\n',
#   'atypical/malignant meningioma\r\n',
#   'vaping cessation\r\n',
#   'healthcare common procedure coding system\r\n',
#   'critical aortic stenosis\r\n',
#   'pancreas tumor\r\n',
#   'oropharynx metastases\r\n',
#   'acral melanoma that has been removed by surgery\r\n',
#   'bcr-abl positive chronic myelogenous leukemia\r\n',
#   'coronary artery dissection, spontaneous\r\n',
#   'bipolar affective disorder; remission in\r\n',
#   'transversalis fascia plane block\r\n',
#   'chronic rhinosinusitis with nasal polyposis\r\n',
#   'xerosis due to atopic dermatitis\r\n',
#   'osteoarthritis hand carpometacarpal joint first\r\n',
#   'postnatal growth disorder\r\n',
#   'hypertensive nephropathy\r\n',
#   'recurrent grade 2 follicular lymphoma\r\n',
#   'environmental allergy\r\n',
#   'posterior cerebral artery stroke\r\n',
#   'adenocarcinoma of the rectum\r\n',
#   'beta-lactam antibiotic toxicity (diagnosis)\r\n',
#   'discogenic pain\r\n',
#   'preventing blood leakage of bronchial cuff\r\n',
#   'violence, non-accidental\r\n',
#   'improved healing of scarred vocal folds\r\n',
#   'persistent pain after delivery\r\n',
#   '100 adults aged between 20 and 70 years old\r\n',
#   'resectable pancreatic cancers\r\n',
#   'cervical compression myelopathy\r\n',
#   'gastric motor dysfunction\r\n',
#   'age associated immune deficiency\r\n',
#   'infiltrating renal pelvis and ureter urothelial carcinoma\r\n',
#   'quality of signout\r\n',
#   'renal transplant complication primary non-function\r\n',
#   'relapse testicular cancer\r\n',
#   'patient hopsitalized in internal medicine unit\r\n',
#   'comfort and performance of intermittent catheter\r\n',
#   'bleeding wound\r\n',
#   'brittle type 1 diabetes mellitus\r\n',
#   'effects of krill oil on human health\r\n',
#   'dialysis catheter infections\r\n',
#   'breast neoplasms, triple-negative\r\n',
#   'rugby\r\n',
#   'composite restorations\r\n',
#   'sutured wounds\r\n',
#   'hip and knee replacement surgeries\r\n',
#   'extranodal nk-t-cell lymphoma\r\n']]

# %%
"""
-I = return CUIs/identifiers
-i = ignore word order
-C = relaxed model
-z = term processing
-f = give numbers to the final mappings (adds 1. to the first mapped concept, 2. to the 2nd, and so on...)
-c = give numbers to the candidates (adds 1. to the first candidate, 2. to the 2nd, and so on...)
--sldi = read each term in list separately, do not lump into large phrase
-N = MMI formatted output

https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/ListOfTerms.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/TermProcessing.pdf
https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/MM_2016_Usage.pdf
List of MetaMap semantic types: https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt
"""

cwd_absolute_path = os.path.dirname(os.getcwd())
outputs_folder = "outputs/version_2"
outputs_path = os.path.join(absolute_path, outputs_folder)

# args = ['--sldi -i -I -C -z -J acab,anab,bhvr,cgab,clna,dsyn,fndg,inpo,mobd,neop,patf,sosy'] # see https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt for semantic types ("acab,anab,etc.")
args = ['--sldi -i -I -C -z'] # see https://lhncbc.nlm.nih.gov/ii/tools/MetaMap/Docs/SemanticTypes_2018AB.txt for semantic types ("acab,anab,etc.")
form = {}
form['KSOURCE'] = ksource
form['COMMAND_ARGS'] = args
headers = {'Accept': 'application/json'}

mm_conditions = {}
cui_pattern = r"C\d+(?=:)"
name_pattern = r"(?<=:)[^[]+"
semtype_pattern = r"\[(.*?)\]"

# with open('../outputs/version_2/metamapped_conditions_.txt') as output:
# with open(os.path.join(outputs_path, "metamapped_conditions.txt"), 'w') as output:

for chunk in chunked_conditions_unmapped[:3]: # demo for testing
    chunk = chunk[:20] # demo for testing
#     for chunk in chunked_conditions_unmapped:
    service_ticket = get_ticket(CAS_SERVERURL, apikey, serviceurl)
    form['APIText'] = chunk
    params = {'ticket': service_ticket}
    response = s.post(serviceurl, form, headers=headers, params=params, allow_redirects=False)
    if response.status_code == 302:
        newurl = s.get_redirect_target(response)
        response = s.post(newurl, form, headers=headers, params=params, allow_redirects=False)

    for line in response.text.splitlines():
#         output.write(line)
        if not any(s in line for s in ["Meta Mapping", "Processing", "/dmzfiler/"]):
#             mm_dict = {}
            if "Phrase:" in line:
                cuis_per_input = []
                mm_input = line.split(":")[1].strip()
                print(mm_input)
            else:
                cui_match = re.findall(cui_pattern, line)
                if cui_match:
                    name_match = re.findall(name_pattern, line)
                    semtype_match = re.findall(semtype_pattern, line)
                    cui_info = [cui_match[0].strip(), name_match[0].strip(), semtype_match[0].strip()]
                    cuis_per_input.append(cui_info)    

                mm_conditions[mm_input] = cuis_per_input
    
mm_conditions
# Out:
# kearns sayer
# hereditary angioedema - type 1
# respiratory muscles
# hepatic tumor
# parent-child relationship
# caesarean scar pregnancy
# sleep hygiene
# ganglioneuroblastoma of central nervous system
# g6pd
# antineoplastic adverse reaction
# isoflurane
# ocular tumor
# triple negative breast cancer, tnbc
# risk of bone fracture occurrences
# infants
# attenuated or transient psychosis
# erythema migrans
# malignant pleural mesothelioma, advanced
# degenerative
# ataxia
# full thickness supraspinatus tendon tear
# post endodontic pain
# community-acquired mrsa infections
# low blood pressure
# transmission
# urinary infection
# mini-stroke
# flus
# infective pneumonia
# rhinosinusitis acute
# ovarian reserve
# femoral neuropathy in haemophilic patients
# anaplastic lymphoma kinase positive large b-cell lymphoma
# hyperhidrosis palmaris et plantaris
# complex regional pain syndrome
# antibodies; anti-d
# metastatic non-small cell lung cancer
# pure autonomic failure
# congenital torticollis
# disruption or dehiscence of closure of skull or craniotomy
# lens; anomaly
# acute circulatory failure during one-lung ventilation surgery
# degenerative joint disease of the ankle
# breastfeeding
# transcranial magnetic stimulation repetitive
# post-covid me/cfs
# atrium; fibrillation
# drug-related problems
# urine specimen collection
# rabies pre-exposure prophylaxis
# icd/crt-d indication
# weight loss programs
# family child care homes
# percutaneous tracheostomy
# worries
# this study was focused on selective spinal anesthesia for lower extremity surgery in order to achieve early mobilization and to shorten hospital stay
# autologous transplantation
# pcp
# platelet-rich plasma (prp)
# bone status
# {'bone status': [['C0262950',
#    'BONE (Skeletal bone)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0449438', 'Status', 'Qualitative Concept']],
#  'kearns sayer': [],
#  'hereditary angioedema - type 1': [['C0398775',
#    'Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor)',
#    'Disease or Syndrome'],
#   ['C2717905',
#    'Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II)',
#    'Disease or Syndrome']],
#  'respiratory muscles': [['C0021724',
#    'Respiratory Muscles (Structure of intercostal muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0035231', 'Respiratory Muscles', 'Body Part, Organ, or Organ Component']],
#  'hepatic tumor': [['C0023903',
#    'Hepatic tumour (Liver neoplasms)',
#    'Neoplastic Process']],
#  'parent-child relationship': [['C0030542',
#    'Parent-Child Relationship',
#    'Social Behavior'],
#   ['C1705423',
#    'Parent-Child Relationship (isa Relationship)',
#    'Idea or Concept'],
#   ['C2826537',
#    'Parent-Child Relationship (has_a Relationship)',
#    'Conceptual Entity']],
#  'caesarean scar pregnancy': [['C4289806',
#    'Cesarean Scar Pregnancy',
#    'Finding']],
#  'sleep hygiene': [['C4277672', 'Sleep Hygiene', 'Individual Behavior']],
#  'ganglioneuroblastoma of central nervous system': [['C2010420',
#    'Ganglioneuroblastoma of central nervous system (Central Nervous System Ganglioneuroblastoma)',
#    'Neoplastic Process']],
#  'g6pd': [['C0017757',
#    'G6PD (Glucosephosphate Dehydrogenase)',
#    'Amino Acid, Peptide, or Protein,Enzyme'],
#   ['C1333652', 'G6PD (G6PD gene)', 'Gene or Genome'],
#   ['C2939465',
#    'G6PD (Deficiency of glucose-6-phosphate dehydrogenase)',
#    'Disease or Syndrome']],
#  'antineoplastic adverse reaction': [['C0569491',
#    'Antineoplastic adverse reaction',
#    'Pathologic Function']],
#  'isoflurane': [['C0022180',
#    'ISOFLURANE (isoflurane)',
#    'Organic Chemical,Pharmacologic Substance']],
#  'ocular tumor': [['C0015414',
#    'Ocular Tumour (Eye Neoplasms)',
#    'Neoplastic Process']],
#  'triple negative breast cancer, tnbc': [['C3539878',
#    'TNBC - Triple-negative breast cancer (Triple Negative Breast Neoplasms)',
#    'Neoplastic Process']],
#  'risk of bone fracture occurrences': [['C0035647', 'Risk', 'Idea or Concept'],
#   ['C0016658', 'Fracture of Bone (Fracture)', 'Injury or Poisoning'],
#   ['C2745955', 'Occurrences (Occurrence)', 'Temporal Concept'],
#   ['C4552904', 'risk (Subject Risk)', 'Conceptual Entity'],
#   ['C0016658', 'Fracture of Bone (Fracture)', 'Injury or Poisoning'],
#   ['C2745955', 'Occurrences (Occurrence)', 'Temporal Concept']],
#  'infants': [['C0021270', 'Infants (Infant)', 'Age Group']],
#  'attenuated or transient psychosis': [['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0332161',
#    'Attenuated (Attenuated by (contextual qualifier))',
#    'Qualitative Concept'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0040704', 'Transient (Transient Population Group)', 'Population Group'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0033975',
#    'PSYCHOSIS (Psychotic Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C0349204',
#    'Psychosis NOS (Nonorganic psychosis)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0599946', 'Attenuated (Attenuation)', 'Activity'],
#   ['C0205374', 'Transient (Transitory)', 'Temporal Concept'],
#   ['C4554629', 'Psychosis (Psychosis, CTCAE)', 'Finding']],
#  'erythema migrans': [['C0014740',
#    'Erythema Migrans (Erythema Chronicum Migrans)',
#    'Disease or Syndrome'],
#   ['C0017677',
#    'erythema migrans (Glossitis, Benign Migratory)',
#    'Disease or Syndrome']],
#  'malignant pleural mesothelioma, advanced': [['C0854889',
#    'Advanced Malignant pleural mesothelioma (Advanced Pleural Malignant Mesothelioma)',
#    'Neoplastic Process']],
#  'degenerative': [['C0011164',
#    'Degenerative (Abnormal degeneration)',
#    'Pathologic Function'],
#   ['C1880269', 'Degenerative (biologic degeneration)', 'Functional Concept']],
#  'ataxia': [['C0004134', 'ATAXIA (Ataxia)', 'Sign or Symptom'],
#   ['C0007758', 'Ataxia (Cerebellar Ataxia)', 'Disease or Syndrome'],
#   ['C4554639', 'Ataxia (Ataxia, CTCAE 5.0)', 'Finding']],
#  'full thickness supraspinatus tendon tear': [['C0439809',
#    'Full thickness',
#    'Quantitative Concept'],
#   ['C0439059', 'Supraspinatus tear', 'Injury or Poisoning'],
#   ['C0039508',
#    'TENDON (Tendon structure)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0039409', 'TEAR (Tears body substance)', 'Body Substance'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0043246', 'Tear (Laceration)', 'Injury or Poisoning'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C1704633', 'TEAR (Tear Shape)', 'Spatial Concept'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0224868',
#    'Supraspinatus tendon (Tendon of supraspinatus muscle)',
#    'Body Part, Organ, or Organ Component'],
#   ['C3203359', 'tear (Rupture)', 'Injury or Poisoning'],
#   ['C0439809', 'Full thickness', 'Quantitative Concept'],
#   ['C0584869',
#    'Supraspinatus (Supraspinatus muscle structure)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0850773', 'tendon tear (Tendon tears)', 'Injury or Poisoning']],
#  'post endodontic pain': [['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C0687676', 'Post', 'Temporal Concept'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0030193', 'PAIN (Pain)', 'Sign or Symptom'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C0518090', 'Pain (Frequency of Pain Question)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C1962977', 'Pain NOS (Pain NOS, CTCAE)', 'Finding'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C2984058', 'Pain (Have Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085210', 'Pain (Usual Severity Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085211', 'Pain (Pain Distress Question)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4085212', 'Pain (How Much Distress Pain)', 'Intellectual Product'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4553004', 'Pain (Pain, CTCAE)', 'Finding'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0332274', 'Endodontic', 'Functional Concept'],
#   ['C4554132', 'Pain (Feel Pain)', 'Intellectual Product']],
#  'community-acquired mrsa infections': [['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C1265292',
#    'MRSA (Methicillin-Resistant Staphylococcus aureus)',
#    'Bacterium'],
#   ['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C1550281', 'Mrsa:', 'Body Part, Organ, or Organ Component'],
#   ['C0206171',
#    'Acquired Infections, Community (Community-Acquired Infections)',
#    'Disease or Syndrome'],
#   ['C4521538',
#    'MRSA (Methicillin-resistant Staphylococcus aureus Measurement)',
#    'Laboratory or Test Result']],
#  'low blood pressure': [['C0020649',
#    'Low Blood Pressure (Hypotension)',
#    'Finding']],
#  'transmission': [['C0040722',
#    'transmission (disease transmission qualifier)',
#    'Idea or Concept'],
#   ['C0242781', 'Transmission (disease transmission)', 'Pathologic Function'],
#   ['C1521797',
#    'Transmission (transmission process)',
#    'Natural Phenomenon or Process']],
#  'urinary infection': [['C0042029',
#    'Urinary infection NOS (Urinary tract infection)',
#    'Disease or Syndrome']],
#  'mini-stroke': [['C0007787',
#    'Mini stroke (Transient Ischemic Attack)',
#    'Disease or Syndrome'],
#   ['C0917805',
#    'Mini-Stroke (Transient Cerebral Ischemia)',
#    'Disease or Syndrome']],
#  'flus': [['C0021400', 'flus (Influenza)', 'Disease or Syndrome']],
#  'infective pneumonia': [['C0729704',
#    'Infective pneumonia',
#    'Disease or Syndrome']],
#  'rhinosinusitis acute': [['C2317131',
#    'Acute rhinosinusitis',
#    'Disease or Syndrome']],
#  'ovarian reserve': [['C3850153',
#    'Ovarian Reserve',
#    'Organ or Tissue Function']],
#  'femoral neuropathy in haemophilic patients': [['C0751931',
#    'Femoral Neuropathy',
#    'Disease or Syndrome'],
#   ['C0030705', 'Patients', 'Patient or Disabled Group']],
#  'anaplastic lymphoma kinase positive large b-cell lymphoma': [['C1333294',
#    'Anaplastic lymphoma kinase positive large B-cell lymphoma (ALK positive large B-cell lymphoma)',
#    'Neoplastic Process']],
#  'hyperhidrosis palmaris et plantaris': [['C1274743',
#    'HYPERHIDROSIS PALMARIS ET PLANTARIS (Hyperhidrosis Palmaris Et Plantaris)',
#    'Disease or Syndrome']],
#  'complex regional pain syndrome': [['C0458219',
#    'Complex Regional Pain Syndrome (Complex Regional Pain Syndromes)',
#    'Disease or Syndrome']],
#  'antibodies; anti-d': [['C0073188',
#    'Anti D Antibody (Rho(D) immune globulin)',
#    'Amino Acid, Peptide, or Protein,Immunologic Factor,Pharmacologic Substance'],
#   ['C0140430',
#    'anti-d antibody (Blood group antibody D)',
#    'Amino Acid, Peptide, or Protein,Immunologic Factor']],
#  'metastatic non-small cell lung cancer': [['C0278987',
#    'nonsmall cell lung cancer, metastatic (Metastatic non-small cell lung cancer)',
#    'Neoplastic Process']],
#  'pure autonomic failure': [['C0393911',
#    'AUTONOMIC FAILURE, PURE (Pure Autonomic Failure)',
#    'Disease or Syndrome']],
#  'congenital torticollis': [['C0079352',
#    'Congenital torticollis',
#    'Congenital Abnormality']],
#  'disruption or dehiscence of closure of skull or craniotomy': [['C2349777',
#    'Disruption or dehiscence of closure of skull or craniotomy',
#    'Injury or Poisoning']],
#  'lens; anomaly': [['C0023317',
#    'LENS (Lens, Crystalline)',
#    'Body Part, Organ, or Organ Component'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0023317',
#    'LENS (Lens, Crystalline)',
#    'Body Part, Organ, or Organ Component'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding'],
#   ['C0023318', 'Lens (Lens (device))', 'Manufactured Object'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0023318', 'Lens (Lens (device))', 'Manufactured Object'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding'],
#   ['C0996842', 'Lens (Genus Lens)', 'Plant'],
#   ['C0332447',
#    'Anomaly (Morphologically abnormal structure (morphologic abnormality))',
#    'Anatomical Abnormality'],
#   ['C0996842', 'Lens (Genus Lens)', 'Plant'],
#   ['C1704258', 'ANOMALY (Abnormality)', 'Finding']],
#  'acute circulatory failure during one-lung ventilation surgery': [['C0036974',
#    'Acute circulatory failure (Shock)',
#    'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0038894',
#    'Surgery (Surgery specialty)',
#    'Biomedical Occupation or Discipline'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0038895', 'surgery (Surgical aspects)', 'Functional Concept'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C0543467',
#    'Surgery (Operative Surgical Procedures)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0036974', 'Acute circulatory failure (Shock)', 'Pathologic Function'],
#   ['C0559312',
#    'One lung ventilation (One-Lung Ventilation)',
#    'Laboratory Procedure'],
#   ['C1274039',
#    'Surgery (General surgery specialty)',
#    'Biomedical Occupation or Discipline']],
#  'degenerative joint disease of the ankle': [['C0409931',
#    'Degenerative joint disease of ankle (Osteoarthritis of ankle)',
#    'Disease or Syndrome']],
#  'breastfeeding': [['C0006147',
#    'BREASTFEEDING (Breast Feeding)',
#    'Organism Function']],
#  'transcranial magnetic stimulation repetitive': [['C0872259',
#    'Repetitive Transcranial Magnetic Stimulation (Transcranial Magnetic Stimulation, Repetitive)',
#    'Therapeutic or Preventive Procedure']],
#  'post-covid me/cfs': [['C0687676', 'Post', 'Temporal Concept'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome'],
#   ['C1704687', 'Post (Post Device)', 'Manufactured Object'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome'],
#   ['C3469826', 'POST (SLC35G1 gene)', 'Gene or Genome'],
#   ['C0015674', 'ME/CFS (Chronic Fatigue Syndrome)', 'Disease or Syndrome']],
#  'atrium; fibrillation': [['C0004238',
#    'ATRIAL FIBRILLATION (Atrial Fibrillation)',
#    'Disease or Syndrome'],
#   ['C0344434',
#    'Atrial Fibrillation (Atrial Fibrillation by ECG Finding)',
#    'Laboratory or Test Result'],
#   ['C1963067', 'Atrial Fibrillation (Atrial Fibrillation, CTCAE)', 'Finding']],
#  'drug-related problems': [['C0740721',
#    'drug problems (Drug problem)',
#    'Finding'],
#   ['C0439849', 'Related (Relationships)', 'Qualitative Concept'],
#   ['C0740721', 'drug problems (Drug problem)', 'Finding'],
#   ['C0445223', 'Related (Related personal status)', 'Finding']],
#  'urine specimen collection': [['C0200354',
#    'Specimen collection, urine (Urine Specimen Collection)',
#    'Laboratory Procedure']],
#  'rabies pre-exposure prophylaxis': [['C0034494',
#    'RABIES (Rabies (disorder))',
#    'Disease or Syndrome'],
#   ['C3850098',
#    'Pre-Exposure Prophylaxis',
#    'Therapeutic or Preventive Procedure'],
#   ['C0034496',
#    'rabies, NOS (Rabies Vaccines)',
#    'Immunologic Factor,Organic Chemical,Pharmacologic Substance'],
#   ['C3850098',
#    'Pre-Exposure Prophylaxis',
#    'Therapeutic or Preventive Procedure']],
#  'icd/crt-d indication': [['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0436307',
#    'CRT (Chemoradiotherapy)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0392360',
#    'indication (Indication of (contextual qualifier))',
#    'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C0436307',
#    'CRT (Chemoradiotherapy)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3146298', 'Indication', 'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C4724071', 'CRT (SLC6A8 wt Allele)', 'Gene or Genome'],
#   ['C0392360',
#    'indication (Indication of (contextual qualifier))',
#    'Idea or Concept'],
#   ['C0021122',
#    'ICD (Disruptive, Impulse Control, and Conduct Disorders)',
#    'Mental or Behavioral Dysfunction'],
#   ['C4724071', 'CRT (SLC6A8 wt Allele)', 'Gene or Genome'],
#   ['C3146298', 'Indication', 'Idea or Concept']],
#  'weight loss programs': [['C3179079',
#    'Weight Loss Programs (Weight Reduction Programs)',
#    'Health Care Activity']],
#  'family child care homes': [['C0015576', 'Family', 'Family Group'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C0015576', 'Family', 'Family Group'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0008059', 'CHILD (Child)', 'Age Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C0680063', 'child (Offspring)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C4724242', 'CHILD (Child Relation)', 'Family Group'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0204977', 'Home Care (Home care of patient)', 'Health Care Activity'],
#   ['C1704727', 'Family (Family (taxonomic))', 'Conceptual Entity'],
#   ['C5236065', 'Child (Child Individual)', 'Human'],
#   ['C0994454', 'home care (Home care aspects)', 'Health Care Activity']],
#  'percutaneous tracheostomy': [['C0584877',
#    'Percutaneous tracheostomy',
#    'Therapeutic or Preventive Procedure']],
#  'worries': [['C0233481', 'Worries (Worried)', 'Finding']],
#  'this study was focused on selective spinal anesthesia for lower extremity surgery in order to achieve early mobilization and to shorten hospital stay': [['C1080058',
#    'This (This (eukaryote))',
#    'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C0557651', 'Study (Room of building - Study)', 'Manufactured Object'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
# ...
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C0205234', 'Focused (Focal)', 'Spatial Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705176', 'Order (Order (arrangement))', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705177', 'Order (Order (taxonomic))', 'Classification'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705178', 'Order (Order (action))', 'Activity'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1882348', 'Order (Permutation)', 'Qualitative Concept'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3889825',
#    'ORDER (Sequence of Planned Assessment Schedule)',
#    'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C0036576', 'selection (Genetic Selection)', 'Genetic Function'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C4284072', 'Order (Order (record artifact))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C0441636',
#    'shorten (Surgical shortening - action)',
#    'Therapeutic or Preventive Procedure'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ['C1080058', 'This (This (eukaryote))', 'Eukaryote'],
#   ['C2603343', 'Study', 'Research Activity'],
#   ['C1285542', 'focused (Has focus)', 'Functional Concept'],
#   ['C1707391', 'Selection (Choose (action))', 'Activity'],
#   ['C0002928',
#    'Spinal anaesthesia (Spinal Anesthesia)',
#    'Therapeutic or Preventive Procedure'],
#   ['C0187763',
#    'lower extremity surgery (Surgical procedure on lower extremity)',
#    'Therapeutic or Preventive Procedure'],
#   ['C1705175', 'Order (Order (document))', 'Intellectual Product'],
#   ['C0013459', 'Early Mobilization', 'Therapeutic or Preventive Procedure'],
#   ['C1282927', 'shorten (Shortened)', 'Qualitative Concept'],
#   ['C3489408', 'Hospital Stay', 'Temporal Concept'],
#   ...],
#  'autologous transplantation': [['C0040736',
#    'Autologous Transplantation (Transplantation, Autologous)',
#    'Therapeutic or Preventive Procedure']],
#  'pcp': [['C0431128',
#    'PCP (Papillary craniopharyngioma)',
#    'Neoplastic Process'],
#   ['C1535939', 'PCP (Pneumocystis jiroveci pneumonia)', 'Disease or Syndrome'],
#   ['C3896095',
#    'PCP (peptidyl carrier protein activity)',
#    'Molecular Function']],
#  'platelet-rich plasma (prp)': [['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C0032027', 'PRP (Pityriasis Rubra Pilaris)', 'Disease or Syndrome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C1412228', 'PRP (ADCYAP1 gene)', 'Gene or Genome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C1704926', 'PRP (ABCB6 wt Allele)', 'Gene or Genome'],
#   ['C0370220',
#    'PLATELET RICH PLASMA (Platelet rich plasma)',
#    'Body Substance'],
#   ['C3889430', 'PRP (CARD14 wt Allele)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C0032027', 'PRP (Pityriasis Rubra Pilaris)', 'Disease or Syndrome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C1412228', 'PRP (ADCYAP1 gene)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C1704926', 'PRP (ABCB6 wt Allele)', 'Gene or Genome'],
#   ['C1546754',
#    'Platelet rich plasma (Specimen Source Codes - Platelet rich plasma)',
#    'Intellectual Product'],
#   ['C3889430', 'PRP (CARD14 wt Allele)', 'Gene or Genome']]}

# %%
conditions_unmapped_list = list(set(conditions_unmapped.downcase_name.to_list())) # get unique unmapped terms
conditions_unmapped_list[:100]
# Out:
# ['kearns sayer',
#  'hereditary angioedema - type 1',
#  'respiratory muscles',
#  'hepatic tumor',
#  'parent-child relationship',
#  'caesarean scar pregnancy',
#  'sleep hygiene',
#  'ganglioneuroblastoma of central nervous system',
#  'g6pd',
#  'antineoplastic adverse reaction',
#  'isoflurane',
#  'ocular tumor',
#  'triple negative breast cancer, tnbc',
#  'risk of bone fracture occurrences',
#  'infants',
#  'attenuated or transient psychosis',
#  'erythema migrans',
#  'malignant pleural mesothelioma, advanced',
#  'degenerative',
#  'ataxia',
#  'non alcoholic fatty liver',
#  'myoma of uterus',
#  'macular degeneration, choroidal neovascularization',
#  'newborn, infant, disease',
#  'viral; infection, coxsackie(virus)',
#  'functional dysphonia',
#  'advanced recurrent ovarian tumors',
#  'primary focal hyperhidrosis of the hands',
#  'gallbladder adenocarcinoma, biliary type',
#  'sacral myelomeningocele',
#  'gender differences',
#  'home blood pressure monitoring',
#  'slippery pulse',
#  'neonatal phototherapy',
#  'gene transfer',
#  'thoracic endovascular repair',
#  'drug binding to dat receptors',
#  'periodontal disease and caries',
#  'pulmonary mac',
#  'c-staged hepatocellular carcinoma in bclc classification',
#  'respiratory distress syndrome, pediatric',
#  'bloodpressure',
#  'hepatocyte receptor',
#  'deep wrinkles of the forehead',
#  'clinical decision support system (cdss)',
#  'malignant ovarian endometrioid tumor',
#  'severe marrow failure',
#  'diagnoses that require stem cell transplant',
#  'emotional disorder',
#  'mannose-binding lectin complement pathway',
#  'cervical neoplasia',
#  'hormonal changes',
#  'head and neck surgeries',
#  'hemolytic-uremic syndrome, atypical',
#  'abdominal aortic aneurysms with challenging anatomy',
#  'central blood pressure',
#  'vaccine',
#  'lower grade glioma, recurrent',
#  'male sterilization',
#  'diabetes mellitus type 2 without complication',
#  'body contouring surgery',
#  'parenteral nutrition (no primary condition studied)',
#  'lung structure determination',
#  'immunologically-induced lung disease',
#  'medulloblastoma, group 4',
#  'death, sudden,cardiac',
#  'the clinical application guide of conebeam breast ct',
#  'beta rhythm',
#  'fracture of long bones',
#  'target controlled infusion (tci)',
#  'elite athletes',
#  'primary',
#  'spina bifida and anencephaly',
#  'pre-term birth',
#  'grönblad-stranberg disease (pseudoxanthoma elasticum)',
#  'hip impairments',
#  'vulval dermatoses',
#  'sex hormones',
#  'squamous-cell non-small cell lung cancer',
#  'suspected lung cancer',
#  'sleep disturbances in survivors of critical illness',
#  'age-related sarcopenia',
#  'bra strap fat (bsf)',
#  'chronic periaortitis',
#  'undetected intraoperative blood loss',
#  'human bocavirus',
#  'decayed tooth',
#  'allogeneic hematopoietic cell transplant recipients',
#  'popliteal nerve block',
#  'superinfection lung',
#  'pd',
#  'single dose',
#  'pustular psoriasis',
#  'pharmacologic action',
#  'chronic migraine headache',
#  'additional indications below for module 4 and 5',
#  'methamphetamine withdrawal',
#  'cortical organisation of vestibular integration',
#  'planned rrso',
#  'articular cartilage defects of knee']

# %%
conditions_unmapped_list = list(set(conditions_unmapped.downcase_name.to_list())) # get unique unmapped terms
nr_url = 'https://name-resolution-sri.renci.org/lookup'

nr_dict =  {}
for condition in conditions_unmapped_list[:3]:
    params = {'string':condition,'limit':3}
    response = requests.post(nr_url,params=params)
#     print(response.json())
#     print(json.dumps(response.json(),indent=2))
    jres = response.json()
#     print(jres)
#     jres = json.load(res)
    nr_dict[condition] = jres
    
    
nr_dict
# Out:
# {'kearns sayer': {'MONDO:0010787': ['kearns-sayer syndrome',
#    'kearns sayer syndrome',
#    'kearns sayers syndrome',
#    'KSS',
#    'KSS',
#    'OCS syndrome',
#    'Kearns-Sayre',
#    'Kearn Syndrome',
#    'Kearns Syndrome',
#    'kearns syndrome',
#    "Kearns' Syndrome",
#    'Syndrome, Kearns',
#    "Syndrome, Kearns'",
#    'CPEO WITH MYOPATHY',
#    'CPEO with Myopathy',
#    'CPEO with myopathy',
#    'Myopathy, CPEO with',
#    'kearn sayre syndrome',
#    'CPEO with Myopathies',
#    'kearn sayer syndrome',
#    'kearn sayers syndrome',
#    'Kearns Sayre Syndrome',
#    'kearns-sayre syndrome',
#    'Kearns-Sayre syndrome',
#    'kearns sayre syndrome',
#    'Kearns-Sayre syndrome',
#    'Kearns-Sayre Syndrome',
#    'KEARNS-SAYRE SYNDROME',
#    'Myopathies, CPEO with',
#    'Syndrome, Kearns-Sayre',
#    'Syndrome, Kearns Sayre',
#    'Sayre Syndrome, Kearns',
#    'mitochondrial Cytopathy',
#    'CPEO with ragged-Red fibers',
#    'KSS - Kearns-Sayre syndrome',
#    'Oculocraniosomatic Syndrome',
#    'OCULOCRANIOSOMATIC SYNDROME',
#    'oculocraniosomatic syndrome',
#    'Cpeo With Ragged-Red Fibers',
#    'CPEO WITH RAGGED-RED FIBERS',
#    'Oculocraniosomatic syndrome',
#    'CPEO with Ragged Red Fibers',
#    'CPEO with ragged red fibers',
#    'Oculocraniosomatic dystrophy',
#    'Oculocraniosomatic Syndromes',
#    'Syndrome, Oculocraniosomatic',
#    'OPHTHALMOPLEGIA-PLUS SYNDROME',
#    'ophthalmoplegia plus syndrome',
#    'Ophthalmoplegia plus syndrome',
#    'Ophthalmoplegia Plus Syndrome',
#    'ophthalmoplegia-plus syndrome',
#    'Ophthalmoplegia-plus syndrome',
#    'Mitochondrial ocular myopathy',
#    'Ophthalmoplegia-Plus Syndrome',
#    'Ophthalmoplegia-Plus Syndromes',
#    'Ophthalmoplegia Plus Syndromes',
#    'Syndrome, Ophthalmoplegia-Plus',
#    'Syndrome, Ophthalmoplegia Plus',
#    'Kearns-Sayre mitochon cytopath',
#    'Syndromes, Ophthalmoplegia-Plus',
#    'Kearns Sayre Shy Daroff Syndrome',
#    'Kearns-Sayre syndrome (disorder)',
#    'Kearns-Sayre-Shy-Daroff Syndrome',
#    'Kearns-Sayre syndrome (diagnosis)',
#    'Syndrome, Kearns-Sayre-Shy-Daroff',
#    'Kearn Sayre Mitochondrial Cytopathy',
#    'Kearn-Sayre Mitochondrial Cytopathy',
#    'Kearns-Sayre Mitochondrial Cytopathy',
#    'Mitochondrial Cytopathy, Kearn-Sayre',
#    'Kearns-Sayre mitochondrial cytopathy',
#    'Cytopathy, Kearn-Sayre Mitochondrial',
#    'Kearns Sayre Mitochondrial Cytopathy',
#    'Cytopathy, Kearns-Sayre Mitochondrial',
#    'Mitochondrial Cytopathy, Kearns-Sayre',
#    'Kearns-Sayre Mitochondrial Cytopathies',
#    'Cytopathies, Kearns-Sayre Mitochondrial',
#    'Mitochondrial Cytopathies, Kearns-Sayre',
#    'Ophthalmoplegia plus syndrome (disorder)',
#    'Progressive external ophthalmoplegia-plus syndrome',
#    'chronic progressive external ophthalmoplegia with myopathy',
#    'CHRONIC PROGRESSIVE EXTERNAL OPHTHALMOPLEGIA WITH MYOPATHY',
#    'Chronic Progressive External Ophthalmoplegia with Myopathy',
#    'ophthalmoplegia, progressive external, with ragged-Red fibers',
#    'OPHTHALMOPLEGIA, PROGRESSIVE EXTERNAL, WITH RAGGED-RED FIBERS',
#    'ophthalmoplegia, progressive external, with ragged red fibers',
#    'Ophthalmoplegia, Progressive External, With Ragged-Red Fibers',
#    'Pigmentary degeneration of the retina plus heart block syndrome',
#    'OPHTHALMOPLEGIA, PIGMENTARY DEGENERATION OF RETINA, AND CARDIOMYOPATHY',
#    'Ophthalmoplegia, Pigmentary Degeneration of Retina, and Cardiomyopathy',
#    'ophthalmoplegia, pigmentary Degeneration of retina, and cardiomyopathy']},
#  'hereditary angioedema - type 1': {'MONDO:0015053': ['hereditary angioedema type 1',
#    'Hereditary angioedema - type 1',
#    'HAE 1',
#    'HAE-I',
#    'Heredit angio-edema - type 1',
#    'Heredit angio-oedema - type 1',
#    'Her C1 ester inhib-def factor',
#    'C1 esterase inhibit def-type 1',
#    'Her angioneurotic oedem-type 1',
#    'Hereditary angio-edema - type 1',
#    'Hereditary angio-oedema - type 1',
#    'hereditary angioneurotic edema type 1',
#    'Hereditary angioneurotic edema - type 1',
#    'Hereditary angioneurotic oedema - type 1',
#    'C1 esterase inhibitor deficiency - type 1',
#    'c1 inhibitor deficiency - deficient factor',
#    'hereditary C1 inhibitor deficiency - deficient factor',
#    'Hereditary C1 esterase inhibitor defic - deficient factor',
#    'Hereditary C1 esterase inhibitor deficiency - deficient factor',
#    'hereditary C1 inhibitor deficiency - deficient factor (diagnosis)',
#    'Hereditary C1 esterase inhibitor deficiency - deficient factor (disorder)'],
#   'UMLS:C2717905': ['Hereditary Angioedema Type 1',
#    'Hereditary angioedema type 1',
#    'HAE 1',
#    'HAE-I',
#    'Deficiency of C1 Esterase Inhibitor',
#    'Hereditary Angioedema Types I and II',
#    'C1 Esterase Inhibitor, Deficiency Of',
#    'Hereditary angioneurotic edema type 1',
#    'Angioedema, Hereditary, Types I and II'],
#   'MONDO:0033946': ['angioedema, hereditary, type 1',
#    'angioedema, hereditary, type 1/2',
#    'HAE1',
#    'HANE',
#    'HAE1',
#    'ANGIOEDEMA, HEREDITARY, 1',
#    'hereditary angioedema type I',
#    'Hereditary Angioedema Type I',
#    'hereditary angioedema type I',
#    'Hereditary angioedema type I',
#    'Angioedema, Hereditary, Type I',
#    'angioedema, hereditary, type 2',
#    'ANGIOEDEMA, HEREDITARY, TYPE I',
#    'angioedema, hereditary, type I',
#    'angioedema, hereditary, 1 and 2',
#    'angioneurotic edema, hereditary',
#    'ANGIONEUROTIC EDEMA, HEREDITARY',
#    'C1 ESTERASE INHIBITOR DEFICIENCY',
#    'C1 esterase inhibitor, deficiency of',
#    'hereditary angioedema with C1Inh deficiency']},
#  'respiratory muscles': {'UBERON:0001111': ['Respiratory Muscles',
#    'rib muscle',
#    'intercostales',
#    'Intercostal muscle',
#    'respiratory muscle',
#    'Intercostal Muscle',
#    'intercostal muscle',
#    'intercostal muscles',
#    'intercostals muscle',
#    'Intercostal Muscles',
#    'MUSCLE, INTERCOSTAL',
#    'Intercostal muscles',
#    'Muscle, Intercostal',
#    'Muscles, Intercostal',
#    'Musculus intercostalis',
#    'musculus intercostalis',
#    'Intercostal muscle, NOS',
#    'Structure of intercostal muscle',
#    'Structure of intercostal muscle (body structure)'],
#   'UBERON:0014398': ['respiratory muscles',
#    'Respiratory Muscles',
#    'muscles respiratory',
#    'Respiratory muscles',
#    'Muscles, Respiratory',
#    'respiratory muscle',
#    'Respiratory Muscle',
#    'muscle respiratory',
#    'Ventilatory Muscle',
#    'Muscle, Ventilatory',
#    'Muscle, Respiratory',
#    'Ventilatory Muscles',
#    'Muscles, Ventilatory',
#    'Muscles of respiration',
#    'Muscles of respiration, unspecified'],
#   'UMLS:C0006155': ['muscles respiratory training',
#    'RMT',
#    'breath exercise',
#    'exercise breathing',
#    'breathing exercise',
#    'Breathing exercise',
#    'Breathing Exercises',
#    'Breathing exercises',
#    'Exercise, Breathing',
#    'exercise; breathing',
#    'breathing exercises',
#    'Pt breathing exercise',
#    'Breathing exercise, NOS',
#    'RNIx breathing exercises',
#    'Respiratory Muscle Training',
#    'training respiratory muscle',
#    'respiratory muscle training',
#    'Muscle Training, Respiratory',
#    'Breathing exercise, training',
#    'Training, Respiratory Muscle',
#    'Physiotherapeutic breathing exercise',
#    'RNIx breathing exercises (treatment)',
#    'pulmonary rehabilitation breathing exercises',
#    'Physiotherapeutic breathing exercise (regime/therapy)',
#    'pulmonary rehabilitation breathing exercises (treatment)']}}

# %%
diseases = ['planned rrso', 'human bocavirus', 'articular cartilage defects of knee', 'pustular psoriasis', 'chronic migraine headache']

params = {'string':diseases,'limit':5}
response = requests.post(nr_url,params=params)
print(json.dumps(response.json(),indent=2))

# %%
diseases = ['planned rrso', 'human bocavirus', 'articular cartilage defects of knee', 'pustular psoriasis', 'chronic migraine headache']

params = {'string':"RxCUI 2555",'limit':5}
response = requests.post(nr_url,params=params)
print(json.dumps(response.json(),indent=2))
# Out:
# {}

# %%
with open(os.path.join(outputs_path, "metamapped_conditions.txt"), 'w') as output:
    for key, val in mm_conditions.items():
        print(key)
#             output.write(key + "\t" + val[0] + "\t" + val[1] + "\t" + val[2])
# Out:
# bone status
# kearns sayer
# hereditary angioedema - type 1
# respiratory muscles
# hepatic tumor
# parent-child relationship
# caesarean scar pregnancy
# sleep hygiene
# ganglioneuroblastoma of central nervous system
# g6pd
# antineoplastic adverse reaction
# isoflurane
# ocular tumor
# triple negative breast cancer, tnbc
# risk of bone fracture occurrences
# infants
# attenuated or transient psychosis
# erythema migrans
# malignant pleural mesothelioma, advanced
# degenerative
# ataxia
# full thickness supraspinatus tendon tear
# post endodontic pain
# community-acquired mrsa infections
# low blood pressure
# transmission
# urinary infection
# mini-stroke
# flus
# infective pneumonia
# rhinosinusitis acute
# ovarian reserve
# femoral neuropathy in haemophilic patients
# anaplastic lymphoma kinase positive large b-cell lymphoma
# hyperhidrosis palmaris et plantaris
# complex regional pain syndrome
# antibodies; anti-d
# metastatic non-small cell lung cancer
# pure autonomic failure
# congenital torticollis
# disruption or dehiscence of closure of skull or craniotomy
# lens; anomaly
# acute circulatory failure during one-lung ventilation surgery
# degenerative joint disease of the ankle
# breastfeeding
# transcranial magnetic stimulation repetitive
# post-covid me/cfs
# atrium; fibrillation
# drug-related problems
# urine specimen collection
# rabies pre-exposure prophylaxis
# icd/crt-d indication
# weight loss programs
# family child care homes
# percutaneous tracheostomy
# worries
# this study was focused on selective spinal anesthesia for lower extremity surgery in order to achieve early mobilization and to shorten hospital stay
# autologous transplantation
# pcp
# platelet-rich plasma (prp)

# %%
mm_conditions
# Out:
# {'degenerative joint disease of the ankle': [[['C0409931'],
#    ['Degenerative joint disease of ankle (Osteoarthritis of ankle) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'kearns sayer': [[[], [], []]],
#  'hereditary angioedema - type 1': [[['C0398775'],
#    ['Hereditary angioedema - type 1 (Hereditary C1 esterase inhibitor deficiency - deficient factor) '],
#    ['Disease or Syndrome']],
#   [['C2717905'],
#    ['Hereditary angio oedema Type 1 (Hereditary Angioedema Types I and II) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'respiratory muscles': [[['C0021724'],
#    ['Respiratory Muscles (Structure of intercostal muscle) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C0035231'],
#    ['Respiratory Muscles '],
#    ['Body Part, Organ, or Organ Component']],
#   [[], [], []]],
#  'hepatic tumor': [[['C0023903'],
#    ['Hepatic tumour (Liver neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'parent-child relationship': [[['C0030542'],
#    ['Parent-Child Relationship '],
#    ['Social Behavior']],
#   [['C1705423'],
#    ['Parent-Child Relationship (isa Relationship) '],
#    ['Idea or Concept']],
#   [['C2826537'],
#    ['Parent-Child Relationship (has_a Relationship) '],
#    ['Conceptual Entity']],
#   [[], [], []]],
#  'caesarean scar pregnancy': [[['C4289806'],
#    ['Cesarean Scar Pregnancy '],
#    ['Finding']],
#   [[], [], []]],
#  'sleep hygiene': [[['C4277672'], ['Sleep Hygiene '], ['Individual Behavior']],
#   [[], [], []]],
#  'ganglioneuroblastoma of central nervous system': [[['C2010420'],
#    ['Ganglioneuroblastoma of central nervous system (Central Nervous System Ganglioneuroblastoma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'g6pd': [[['C0017757'],
#    ['G6PD (Glucosephosphate Dehydrogenase) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C1333652'], ['G6PD (G6PD gene) '], ['Gene or Genome']],
#   [['C2939465'],
#    ['G6PD (Deficiency of glucose-6-phosphate dehydrogenase) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'antineoplastic adverse reaction': [[['C0569491'],
#    ['Antineoplastic adverse reaction '],
#    ['Pathologic Function']],
#   [[], [], []]],
#  'isoflurane': [[['C0022180'],
#    ['ISOFLURANE (isoflurane) '],
#    ['Organic Chemical,Pharmacologic Substance']],
#   [[], [], []]],
#  'ocular tumor': [[['C0015414'],
#    ['Ocular Tumour (Eye Neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'triple negative breast cancer, tnbc': [[['C3539878'],
#    ['TNBC - Triple-negative breast cancer (Triple Negative Breast Neoplasms) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'risk of bone fracture occurrences': [[['C0035647'],
#    ['Risk '],
#    ['Idea or Concept']],
#   [['C0016658'], ['Fracture of Bone (Fracture) '], ['Injury or Poisoning']],
#   [['C2745955'], ['Occurrences (Occurrence) '], ['Temporal Concept']],
#   [['C4552904'], ['risk (Subject Risk) '], ['Conceptual Entity']],
#   [['C0016658'], ['Fracture of Bone (Fracture) '], ['Injury or Poisoning']],
#   [['C2745955'], ['Occurrences (Occurrence) '], ['Temporal Concept']],
#   [[], [], []]],
#  'infants': [[['C0021270'], ['Infants (Infant) '], ['Age Group']],
#   [[], [], []]],
#  'attenuated or transient psychosis': [[['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0332161'],
#    ['Attenuated (Attenuated by (contextual qualifier)) '],
#    ['Qualitative Concept']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0040704'],
#    ['Transient (Transient Population Group) '],
#    ['Population Group']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0033975'],
#    ['PSYCHOSIS (Psychotic Disorders) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C0349204'],
#    ['Psychosis NOS (Nonorganic psychosis) '],
#    ['Mental or Behavioral Dysfunction']],
#   [['C0599946'], ['Attenuated (Attenuation) '], ['Activity']],
#   [['C0205374'], ['Transient (Transitory) '], ['Temporal Concept']],
#   [['C4554629'], ['Psychosis (Psychosis, CTCAE) '], ['Finding']],
#   [[], [], []]],
#  'erythema migrans': [[['C0014740'],
#    ['Erythema Migrans (Erythema Chronicum Migrans) '],
#    ['Disease or Syndrome']],
#   [['C0017677'],
#    ['erythema migrans (Glossitis, Benign Migratory) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'malignant pleural mesothelioma, advanced': [[['C0854889'],
#    ['Advanced Malignant pleural mesothelioma (Advanced Pleural Malignant Mesothelioma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'degenerative': [[['C0011164'],
#    ['Degenerative (Abnormal degeneration) '],
#    ['Pathologic Function']],
#   [['C1880269'],
#    ['Degenerative (biologic degeneration) '],
#    ['Functional Concept']],
#   [[], [], []]],
#  'ataxia': [[['C0004134'], ['ATAXIA (Ataxia) '], ['Sign or Symptom']],
#   [['C0007758'], ['Ataxia (Cerebellar Ataxia) '], ['Disease or Syndrome']],
#   [['C4554639'], ['Ataxia (Ataxia, CTCAE 5.0) '], ['Finding']],
#   [[], [], []]],
#  'non alcoholic fatty liver': [[['C0400966'],
#    ['Nonalcoholic Fatty Liver (Non-alcoholic Fatty Liver Disease) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'myoma of uterus': [[['C0042133'],
#    ['uterus myoma (Uterine Fibroids) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'macular degeneration, choroidal neovascularization': [[['C0027686'],
#    ['Neovascularisation (Pathologic Neovascularization) '],
#    ['Pathologic Function']],
#   [['C0423425'],
#    ['Macular Choroidal degeneration (Macular choroidal sclerosis) '],
#    ['Finding']],
#   [[], [], []]],
#  'newborn, infant, disease': [[['C0021290'],
#    ['Infant, Newborn, Diseases (Neonatal disorder) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'viral; infection, coxsackie(virus)': [[['C0010246'],
#    ['Coxsackievirus Infection (Coxsackievirus Infections) '],
#    ['Disease or Syndrome']],
#   [['C0042776'], ['VIRUSES (Virus) '], ['Virus']],
#   [['C0010246'],
#    ['Coxsackievirus Infection (Coxsackievirus Infections) '],
#    ['Disease or Syndrome']],
#   [['C0521026'], ['viruses (Viral) '], ['Functional Concept']],
#   [[], [], []]],
#  'functional dysphonia': [[['C0264622'],
#    ['functional dysphonia (Psychogenic voice disorder) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'advanced recurrent ovarian tumors': [[['C0205179'],
#    ['Advanced (Advanced phase) '],
#    ['Qualitative Concept']],
#   [['C0521158'],
#    ['Recurrent Tumors (Recurrent tumor) '],
#    ['Neoplastic Process']],
#   [['C0205065'], ['Ovarian '], ['Body Part, Organ, or Organ Component']],
#   [['C0205179'], ['Advanced (Advanced phase) '], ['Qualitative Concept']],
#   [['C1455761'], ['Recurrent (Episodic) '], ['Temporal Concept']],
#   [['C0919267'],
#    ['Ovarian Tumors (ovarian neoplasm) '],
#    ['Neoplastic Process']],
#   [['C0205179'], ['Advanced (Advanced phase) '], ['Qualitative Concept']],
#   [['C2945760'], ['RECURRENT (Recurrent) '], ['Temporal Concept']],
#   [['C0919267'],
#    ['Ovarian Tumors (ovarian neoplasm) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'primary focal hyperhidrosis of the hands': [[['C1456132'],
#    ['Primary focal hyperhidrosis '],
#    ['Disease or Syndrome']],
#   [['C0018563'], ['Hands (Hand) '], ['Body Part, Organ, or Organ Component']],
#   [['C1456132'], ['Primary focal hyperhidrosis '], ['Disease or Syndrome']],
#   [['C1552914'], ['hand (hand - unit of measure) '], ['Quantitative Concept']],
#   [[], [], []]],
#  'gallbladder adenocarcinoma, biliary type': [[['C3273113'],
#    ['Gallbladder Adenocarcinoma, Biliary Type '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'sacral myelomeningocele': [[['C0521556'],
#    ['Sacral Myelomeningocele (Congenital sacral meningocele) '],
#    ['Congenital Abnormality']],
#   [[], [], []]],
#  'gender differences': [[['C0036866'],
#    ['Gender Differences (Sex Characteristics) '],
#    ['Organism Attribute']],
#   [[], [], []]],
#  'home blood pressure monitoring': [[['C1449681'],
#    ['Blood Pressure Monitoring, Home '],
#    ['Diagnostic Procedure']],
#   [[], [], []]],
#  'slippery pulse': [[['C0232117'],
#    ['PULSE (Pulse Rate) '],
#    ['Clinical Attribute']],
#   [['C0391850'], ['Pulse (Physiologic pulse) '], ['Physiologic Function']],
#   [['C1947910'], ['Pulse (Pulse phenomenon) '], ['Phenomenon or Process']],
#   [[], [], []]],
#  'neonatal phototherapy': [[['C0199741'],
#    ['Neonatal phototherapy (Phototherapy of newborn) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'gene transfer': [[['C0017296'],
#    ['Gene transfer (gene therapy) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1517499'], ['Gene Transfer '], ['Molecular Biology Research Technique']],
#   [[], [], []]],
#  'thoracic endovascular repair': [[['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C0043240'], ['Repair, NOS (Wound Healing) '], ['Organism Function']],
#   [['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C0374711'],
#    ['Repair, NOS (Surgical repair) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0524425'],
#    ['Endovascular (inside the blood vessel) '],
#    ['Body Location or Region']],
#   [['C4319951'], ['Repair '], ['Functional Concept']],
#   [[], [], []]],
#  'drug binding to dat receptors': [[['C0678749'],
#    ['drug binding '],
#    ['Physiologic Function']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0597357'],
#    ['Receptors (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0678749'], ['drug binding '], ['Physiologic Function']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [['C0597357'],
#    ['Receptors (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1145667'], ['Binding (Binding action) '], ['Activity']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1145667'], ['Binding (Binding action) '], ['Activity']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1167622'],
#    ['Binding (Binding (Molecular Function)) '],
#    ['Molecular Function']],
#   [['C1439340'],
#    ['DAT (SLC6A3 protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Biologically Active Substance']],
#   [['C0034799'],
#    ['Drug receptors (Receptors, Drug) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C1167622'],
#    ['Binding (Binding (Molecular Function)) '],
#    ['Molecular Function']],
#   [['C3813713'], ['DAT (SLC6A3 wt Allele) '], ['Gene or Genome']],
#   [[], [], []]],
#  'periodontal disease and caries': [[['C0031090'],
#    ['PERIODONTAL DISEASE (Periodontal Diseases) '],
#    ['Disease or Syndrome']],
#   [['C0011334'], ['Caries (Dental caries) '], ['Disease or Syndrome']],
#   [['C0031090'],
#    ['PERIODONTAL DISEASE (Periodontal Diseases) '],
#    ['Disease or Syndrome']],
#   [['C0333519'],
#    ['Caries (Caries (morphologic abnormality)) '],
#    ['Disease or Syndrome']],
#   [['C1559300'],
#    ['Periodontal Disease (Periodontal Disease, CTCAE) '],
#    ['Finding']],
#   [['C0011334'], ['Caries (Dental caries) '], ['Disease or Syndrome']],
#   [['C1559300'],
#    ['Periodontal Disease (Periodontal Disease, CTCAE) '],
#    ['Finding']],
#   [['C0333519'],
#    ['Caries (Caries (morphologic abnormality)) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'pulmonary mac': [[['C0024109'],
#    ['pulmonary (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C0024109'],
#    ['pulmonary (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C2707265'],
#    ['Pulmonary (Pulmonary:-:Point in time:^Patient:-) '],
#    ['Clinical Attribute']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C2707265'],
#    ['Pulmonary (Pulmonary:-:Point in time:^Patient:-) '],
#    ['Clinical Attribute']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C2709248'],
#    ['Pulmonary (Pulmonary (qualifier value)) '],
#    ['Qualitative Concept']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C2709248'],
#    ['Pulmonary (Pulmonary (qualifier value)) '],
#    ['Qualitative Concept']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [['C4522268'], ['Pulmonary (Pulmonary (intended site)) '], ['Finding']],
#   [['C3538559'],
#    ['MAC (Mitochondrion-associated adherens complex location) '],
#    ['Cell Component']],
#   [['C4522268'], ['Pulmonary (Pulmonary (intended site)) '], ['Finding']],
#   [['C4049728'], ['MAC (MARCKS wt Allele) '], ['Gene or Genome']],
#   [[], [], []]],
#  'c-staged hepatocellular carcinoma in bclc classification': [[['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0008902'], ['Classification '], ['Classification']],
#   [['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0008903'], ['classification (Taxonomic) '], ['Functional Concept']],
#   [['C3899977'],
#    ['BCLC Stage C Hepatocellular Carcinoma '],
#    ['Neoplastic Process']],
#   [['C0678229'],
#    ['classification (Classification of information) '],
#    ['Occupational Activity']],
#   [[], [], []]],
#  'respiratory distress syndrome, pediatric': [[['C5392184'],
#    ['Respiratory Distress Syndrome, Pediatric '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'bloodpressure': [[['C0005823'],
#    ['BLOOD PRESSURE (Blood Pressure) '],
#    ['Organism Function']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [[], [], []]],
#  'hepatocyte receptor': [[['C0227525'], ['Hepatocyte '], ['Cell']],
#   [['C0597357'],
#    ['Receptor (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [['C0669372'],
#    ['Hepatocyte NOS (NOS2A protein, human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0597357'],
#    ['Receptor (receptor) '],
#    ['Amino Acid, Peptide, or Protein,Receptor']],
#   [[], [], []]],
#  'deep wrinkles of the forehead': [[['C0205125'],
#    ['DEEP (Deep (qualifier value)) '],
#    ['Spatial Concept']],
#   [['C1997891'], ['Wrinkle of forehead (Rhytide of forehead) '], ['Finding']],
#   [['C4318566'], ['Deep (Deep Resection Margin) '], ['Clinical Attribute']],
#   [['C1997891'], ['Wrinkle of forehead (Rhytide of forehead) '], ['Finding']],
#   [[], [], []]],
#  'clinical decision support system': [[['C0525070'],
#    ['Clinical Decision Support System (Decision Support Systems, Clinical) '],
#    ['Intellectual Product']],
#   [[], [], []]],
#  'malignant ovarian endometrioid tumor': [[['C1518231'],
#    ['Malignant Ovarian Endometrioid Tumor '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'severe marrow failure': [[['C0205082'],
#    ['SEVERE (Severe (severity modifier)) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C0205082'], ['SEVERE (Severe (severity modifier)) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050465'], ['Severe (Severe Extremity Pain) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4050466'],
#    ['Severe (Borg Category-Ratio 10 Perceived Exertion Score 5) '],
#    ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4722466'], ['Severe (Severe Hallucination) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C4761449'], ['Severe (Epidermal cGVHD Score 4) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0086590'], ['Marrow (Vegetable marrow) '], ['Food']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C0376152'], ['Marrow '], ['Body Part, Organ, or Organ Component']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0231174'],
#    ['Failure (Failure (biologic function)) '],
#    ['Functional Concept']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C0680095'], ['failure (Personal failure) '], ['Individual Behavior']],
#   [['C5203119'], ['Severe (Intensity and Distress 5) '], ['Finding']],
#   [['C1546708'],
#    ['Marrow (Marrow - Specimen Source Codes) '],
#    ['Intellectual Product']],
#   [['C5200924'], ['FAILURE (Failure) '], ['Idea or Concept']],
#   [[], [], []]],
#  'diagnoses that require stem cell transplant': [[['C0011900'],
#    ['Diagnoses (Diagnosis) '],
#    ['Diagnostic Procedure']],
#   [['C1504389'],
#    ['Stem Cell Transplant (Stem cell transplant) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'emotional disorder': [[['C0233459'],
#    ['Emotional disorder '],
#    ['Mental or Behavioral Dysfunction']],
#   [[], [], []]],
#  'mannose-binding lectin complement pathway': [[['C1138407'],
#    ['Complement Pathway, Mannose-Binding Lectin '],
#    ['Molecular Function']],
#   [[], [], []]],
#  'cervical neoplasia': [[['C0007873'],
#    ['cervical Neoplasia (Uterine Cervical Neoplasm) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'hormonal changes': [[['C1134488'],
#    ['hormonal changes (Hormonal Change) '],
#    ['Finding']],
#   [[], [], []]],
#  'head and neck surgeries': [[['C1512343'],
#    ['Head and Neck Surgery '],
#    ['Health Care Activity']],
#   [[], [], []]],
#  'hemolytic-uremic syndrome, atypical': [[['C2931788'],
#    ['Atypical haemolytic uraemic syndrome (Atypical Hemolytic Uremic Syndrome) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'abdominal aortic aneurysms with challenging anatomy': [[['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0798503'],
#    ['Challenge (Challenge:Type:Point in time:^Patient:Nominal) '],
#    ['Clinical Attribute']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C0805586'], ['Challenge '], ['Health Care Activity']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C0002808'],
#    ['Anatomy (Science of Anatomy) '],
#    ['Biomedical Occupation or Discipline']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C0700276'], ['Anatomy (Anatomic structures) '], ['Anatomical Structure']],
#   [['C0162871'],
#    ['Aortic Aneurysms, Abdominal (Aortic Aneurysm, Abdominal) '],
#    ['Disease or Syndrome']],
#   [['C3274764'],
#    ['Challenge (Proficiency Testing Challenge) '],
#    ['Conceptual Entity']],
#   [['C1384516'], ['anatomy (Anatomy aspects) '], ['Qualitative Concept']],
#   [[], [], []]],
#  'central blood pressure': [[['C0205099'],
#    ['CENTRAL (Central) '],
#    ['Spatial Concept']],
#   [['C0005823'], ['BLOOD PRESSURE (Blood Pressure) '], ['Organism Function']],
#   [['C0205099'], ['CENTRAL (Central) '], ['Spatial Concept']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C0205099'], ['CENTRAL (Central) '], ['Spatial Concept']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C0005823'], ['BLOOD PRESSURE (Blood Pressure) '], ['Organism Function']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C1271104'], ['Blood Pressure (Blood pressure finding) '], ['Finding']],
#   [['C1879652'], ['Central - (Central Minus) '], ['Laboratory Procedure']],
#   [['C1272641'],
#    ['Blood pressure (Systemic arterial pressure) '],
#    ['Finding']],
#   [[], [], []]],
#  'vaccine': [[['C0042210'],
#    ['Vaccine (Vaccines) '],
#    ['Amino Acid, Peptide, or Protein,Immunologic Factor,Pharmacologic Substance']],
#   [['C5399710'], ['Vaccine (Vaccine '], ['APC', 'Pharmacologic Substance']],
#   [[], [], []]],
#  'lower grade glioma, recurrent': [[['C4688341'],
#    ['Recurrent Low-Grade Glioma (Recurrent WHO Grade II Glioma) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'male sterilization': [[['C0024559'],
#    ['Male sterilisation (Male sterilization) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'diabetes mellitus type 2 without complication': [[['C0494290'],
#    ['Type 2 diabetes mellitus without complication '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'body contouring surgery': [[['C2224569'],
#    ['Surgery, Body Contouring (Body Contouring) '],
#    ['Therapeutic or Preventive Procedure']],
#   [[], [], []]],
#  'parenteral nutrition (no primary condition studied)': [[['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C0557651'],
#    ['Study (Room of building - Study) '],
#    ['Manufactured Object']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C2603343'], ['Study '], ['Research Activity']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030547'],
#    ['PARENTERAL NUTRITION (Parenteral Nutrition) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C0557651'],
#    ['Study (Room of building - Study) '],
#    ['Manufactured Object']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0277554'],
#    ['primary condition (primary disorders) '],
#    ['Disease or Syndrome']],
#   [['C2603343'], ['Study '], ['Research Activity']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [['C0030548'],
#    ['parenteral nutrition (Parenteral Nutrition, Total) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [['C2985574'], ['Study Condition '], ['Qualitative Concept']],
#   [[], [], []]],
#  'lung structure determination': [[['C0024109'],
#    ['Lung structure (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C0521095'], ['Determination (Determined by) '], ['Qualitative Concept']],
#   [['C0024109'],
#    ['Lung structure (Lung) '],
#    ['Body Part, Organ, or Organ Component']],
#   [['C1148554'],
#    ['determination (Determination Aspects) '],
#    ['Laboratory Procedure']],
#   [[], [], []]],
#  'immunologically-induced lung disease': [[['C0205263'],
#    ['Induced (Induce (action)) '],
#    ['Functional Concept']],
#   [['C0024115'], ['Disease, Lung (Lung diseases) '], ['Disease or Syndrome']],
#   [[], [], []]],
#  'medulloblastoma, group 4': [[['C4330666'],
#    ['Medulloblastoma, group 4 (Medulloblastoma, Non-WNT/Non-SHH, Group 4) '],
#    ['Neoplastic Process']],
#   [[], [], []]],
#  'death, sudden,cardiac': [[['C0085298'],
#    ['Death, Sudden, Cardiac (Sudden Cardiac Death) '],
#    ['Pathologic Function']],
#   [[], [], []]],
#  'the clinical application guide of conebeam breast ct': [[['C0681467'],
#    ['clinical guide '],
#    ['Intellectual Product']],
#   [['C0185125'],
#    ['Application (Application procedure) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C1947919'],
#    ['Application (Application (Document)) '],
#    ['Intellectual Product']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C2347934'],
#    ['Application (Regulatory Application) '],
#    ['Intellectual Product']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C3539080'],
#    ['APPLICATION (Application Dosing Unit) '],
#    ['Quantitative Concept']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [['C0681467'], ['clinical guide '], ['Intellectual Product']],
#   [['C4048755'], ['Application (Apply) '], ['Functional Concept']],
#   [['C0412609'], ['CT of breast '], ['Diagnostic Procedure']],
#   [[], [], []]],
#  'beta rhythm': [[['C0005167'],
#    ['Beta Rhythm '],
#    ['Organ or Tissue Function']],
#   [[], [], []]],
#  'fracture of long bones': [[['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C0205166'], ['LONG (Long) '], ['Qualitative Concept']],
#   [['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C1706317'], ['Long (Long Variable) '], ['Qualitative Concept']],
#   [['C0016658'],
#    ['Fracture of bones NOS (Fracture) '],
#    ['Injury or Poisoning']],
#   [['C5238697'], ['Long (Long Heart Murmur) '], ['Finding']],
#   [[], [], []]],
#  'target controlled infusion': [[['C1521840'],
#    ['Target '],
#    ['Functional Concept']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2587213'], ['Controlled (Control function) '], ['Functional Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2911690'], ['Controlled (Disease Controlled) '], ['Finding']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C0574032'],
#    ['Infusion (Infusion procedures) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C4761797'], ['CONTROLLED (Controlled mark) '], ['Idea or Concept']],
#   [['C1827465'], ['Infusion (Infusion route) '], ['Functional Concept']],
#   [[], [], []]],
#  'elite athletes': [[['C5392984'], ['Elite Athletes '], ['Population Group']],
#   [[], [], []]],
#  'primary': [[['C0205225'], ['Primary '], ['Qualitative Concept']],
#   [['C0439612'],
#    ['Primary (True primary (qualifier value)) '],
#    ['Temporal Concept']],
#   [['C0439631'],
#    ['Primary (Primary operation) '],
#    ['Therapeutic or Preventive Procedure']],
#   [['C0677930'], ['primary (Primary Neoplasm) '], ['Neoplastic Process']],
#   [[], [], []]],
#  'spina bifida and anencephaly': [[['C1845026'],
#    ['Anencephaly-Spina Bifida (Neural tube defects X-linked) '],
#    ['Disease or Syndrome']],
#   [[], [], []]],
#  'pre-term birth': [[['C0151526'],
#    ['Pre-Term (Premature Birth) '],
#    ['Pathologic Function']],
#   [['C0005615'], ['Birth '], ['Organism Function']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C1148523'], ['Birth (Childbirth) '], ['Organism Function']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C1550722'],
#    ['birth (Entity Name Part Qualifier - birth) '],
#    ['Intellectual Product']],
#   [['C0151526'], ['Pre-Term (Premature Birth) '], ['Pathologic Function']],
#   [['C3245487'], ['birth (Name Given at Birth) '], ['Intellectual Product']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C0233324'], ['Term (Term Birth) '], ['Organism Function']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C1515273'], ['Term (Term (temporal)) '], ['Temporal Concept']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C1705313'], ['Term (Term (lexical)) '], ['Idea or Concept']],
#   [['C3844812'], ['Pre-Birth '], ['Finding']],
#   [['C2826302'], ['TERM (Reported Term) '], ['Intellectual Product']],
#   [['C0332152'], ['Pre (Before) '], ['Temporal Concept']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C0740175'], ['Pre (Before values) '], ['Qualitative Concept']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C2257086'],
#    ['PRE (photoreactivating enzyme activity) '],
#    ['Genetic Function']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [['C3669034'], ['PRE (Pure Spanish horse breed (organism)) '], ['Mammal']],
#   [['C0233324'], ['Term Birth '], ['Organism Function']],
#   [[], [], []]],
#  'gr\x1a\x1anblad-stranberg disease (pseudoxanthoma elasticum)': [[['C1552950'],
#    [],
#    ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0033847'],
#    ['PSEUDOXANTHOMA ELASTICUM (Pseudoxanthoma Elasticum) '],
#    ['Disease or Syndrome']],
#   [['C1552950'], [], ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0473583'],
#    ['pseudoxanthoma elasticum (Nevus elasticus) '],
#    ['Neoplastic Process']],
#   [['C1552950'], [], ['gr', 'Quantitative Concept']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C1412081'],
#    ['pseudoxanthoma elasticum (ABCC6 gene) '],
#    ['Gene or Genome']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0033847'],
#    ['PSEUDOXANTHOMA ELASTICUM (Pseudoxanthoma Elasticum) '],
#    ['Disease or Syndrome']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C0473583'],
#    ['pseudoxanthoma elasticum (Nevus elasticus) '],
#    ['Neoplastic Process']],
#   [['C4721873'],
#    ['GR (Glutathione Reductase, Mitochondrial, Human) '],
#    ['Amino Acid, Peptide, or Protein,Enzyme']],
#   [['C0012634'], ['Disease '], ['Disease or Syndrome']],
#   [['C1412081'],
#    ['pseudoxanthoma elasticum (ABCC6 gene) '],
#    ['Gene or Genome']],
# ...
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C1280519'], ['Effectiveness '], ['Qualitative Concept']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C1625163'],
#    ['glucose sensor (glucose sensor activity) '],
#    ['Molecular Function']],
#   [['C2986546'],
#    ['TARGET (Target Lesion Identification) '],
#    ['Diagnostic Procedure']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C1514721'], ['Range '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C2348147'], ['Range (Sample Range) '], ['Quantitative Concept']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C3541902'],
#    ['MEASURED (Measured Tumor Identification) '],
#    ['Diagnostic Procedure']],
#   [['C0428554'],
#    ['blood glucose levels (Finding of blood glucose level) '],
#    ['Laboratory or Test Result']],
#   [['C1883351'], ['To '], ['Qualitative Concept']],
#   [['C1516048'], ['Assess (Assessed) '], ['Activity']],
#   [['C4553491'], ['Effectiveness (Effectiveness (finding)) '], ['Finding']],
#   [['C0024501'], ['Maintain (Maintenance) '], ['Activity']],
#   [['C0030705'], ['Patients '], ['Patient or Disabled Group']],
#   [['C0872382'],
#    ['GLUCOSE SENSOR (glucose sensor device) '],
#    ['Medical Device']],
#   [['C1521840'], ['Target '], ['Functional Concept']],
#   [['C3542016'],
#    ['Range (Concept model range (foundation metadata concept)) '],
#    ['Intellectual Product']],
#   [['C3842584'], ['70% '], ['Quantitative Concept']],
#   [['C4319557'], ['180 '], ['Quantitative Concept']],
#   [['C0439269'], ['mg dl (mg/dL) '], ['Quantitative Concept']],
#   [['C0444706'], ['Measured '], ['Qualitative Concept']],
#   ...],
#  ...}

# %% [markdown]
# # TRY FUZZY MAPPING USING BOTH CANDIDATES FROM METAMAP AND MESH

# %%
conditions_unmapped_per_study
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000110                                          [obesity]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# ...                                                        ...
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
# NCT05794074  [nutrition deficiency (xanth deficiency) due t...
# NCT05794087                                    [air pollution]
#
#              condition_counts
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000110                 1
# NCT00000112                 2
# NCT00000115                 1
# ...                       ...
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
# NCT05794074                 1
# NCT05794087                 1
#
# [344498 rows x 2 columns]

# %%
condition_mesh_leaves
# Out:
#                 id       nct_id             mesh_term    downcase_mesh_term  \
# 0        113697939  NCT00185796              Syndrome              syndrome
# 2        113698185  NCT03516604            Depression            depression
# 5        113698730  NCT00461539            Depression            depression
# 6        113698920  NCT05324137                Polyps                polyps
# 11       113700140  NCT00176514             Mucositis             mucositis
# ...            ...          ...                   ...                   ...
# 2849547  111234990  NCT00733525       Bulimia Nervosa       bulimia nervosa
# 2849551  111234994  NCT02653131  Short Bowel Syndrome  short bowel syndrome
# 2849552  111234995  NCT02653131              Syndrome              syndrome
# 2849564  111204205  NCT04834908            Infections            infections
# 2849565  111204206  NCT04834908              COVID-19              covid-19
#
#          mesh_type
# 0        mesh-list
# 2        mesh-list
# 5        mesh-list
# 6        mesh-list
# 11       mesh-list
# ...            ...
# 2849547  mesh-list
# 2849551  mesh-list
# 2849552  mesh-list
# 2849564  mesh-list
# 2849565  mesh-list
#
# [761406 rows x 5 columns]

# %%
# merge all available MeSH terms for each condition (that is still unmapped)
condition_mesh_terms_per_study = pd.DataFrame(condition_mesh_leaves[["nct_id", "downcase_mesh_term"]].groupby("nct_id")["downcase_mesh_term"].apply(list))
condition_mesh_terms_per_study
# Out:
#                                             downcase_mesh_term
# nct_id
# NCT00000102  [adrenal hyperplasia, congenital, adrenogenita...
# NCT00000104                        [poisoning, lead poisoning]
# NCT00000105                                          [tetanus]
# NCT00000106            [rheumatic diseases, collagen diseases]
# NCT00000107  [heart defects, congenital, congenital abnorma...
# ...                                                        ...
# NCT05793996                          [anemia, iron-deficiency]
# NCT05794022                [myocardial infarction, infarction]
# NCT05794035                                   [skin neoplasms]
# NCT05794048  [pancreatic neoplasms, carcinoma, hepatocellular]
# NCT05794061               [mental disorders, problem behavior]
#
# [370170 rows x 1 columns]

# %%
unmapped_condition_candidates = pd.merge(conditions_unmapped_per_study, condition_mesh_terms_per_study, left_on=["nct_id"], right_on=["nct_id"])
unmapped_condition_candidates
# Out:
#                                                  downcase_name  \
# nct_id
# NCT00000102                   [congenital adrenal hyperplasia]
# NCT00000105                                           [cancer]
# NCT00000112                                [diabetes, obesity]
# NCT00000115                           [macular edema, cystoid]
# NCT00000123                                           [myopia]
# ...                                                        ...
# NCT05793983  [liver failure, acute on chronic, infections, ...
# NCT05793996   [chronic heart failure, iron deficiency, latent]
# NCT05794035                        [skin cancer, non-melanoma]
# NCT05794048                [pancreatic tumor, hepatocarcinoma]
# NCT05794061  [psychiatric disorder, dementia, cognitive imp...
#
#              condition_counts  \
# nct_id
# NCT00000102                 1
# NCT00000105                 1
# NCT00000112                 2
# NCT00000115                 1
# NCT00000123                 1
# ...                       ...
# NCT05793983                 5
# NCT05793996                 2
# NCT05794035                 1
# NCT05794048                 2
# NCT05794061                 3
#
#                                             downcase_mesh_term
# nct_id
# NCT00000102  [adrenal hyperplasia, congenital, adrenogenita...
# NCT00000105                                          [tetanus]
# NCT00000112        [acanthosis nigricans, glucose intolerance]
# NCT00000115                             [macular edema, edema]
# NCT00000123                                      [astigmatism]
# ...                                                        ...
# NCT05793983  [liver cirrhosis, liver diseases, liver failur...
# NCT05793996                          [anemia, iron-deficiency]
# NCT05794035                                   [skin neoplasms]
# NCT05794048  [pancreatic neoplasms, carcinoma, hepatocellular]
# NCT05794061               [mental disorders, problem behavior]
#
# [268411 rows x 3 columns]

# %%
# FOLLOW THIS TUTORIAL:
https://www.datacamp.com/tutorial/fuzzy-string-python

# %%
single_mapped_conditions = condition_mesh_leaves[condition_mesh_leaves.nct_id.isin(unmapped_single_conditions.index)]
single_mapped_conditions
# Out:
#                 id       nct_id        mesh_term downcase_mesh_term  mesh_type
# 0        113697939  NCT00185796         Syndrome           syndrome  mesh-list
# 2        113698185  NCT03516604       Depression         depression  mesh-list
# 5        113698730  NCT00461539       Depression         depression  mesh-list
# 6        113698920  NCT05324137           Polyps             polyps  mesh-list
# 14       113700556  NCT00165893        Back Pain          back pain  mesh-list
# ...            ...          ...              ...                ...        ...
# 2849543  111234985  NCT00733447    Heart Failure      heart failure  mesh-list
# 2849546  111234988  NCT00733525          Bulimia            bulimia  mesh-list
# 2849547  111234990  NCT00733525  Bulimia Nervosa    bulimia nervosa  mesh-list
# 2849564  111204205  NCT04834908       Infections         infections  mesh-list
# 2849565  111204206  NCT04834908         COVID-19           covid-19  mesh-list
#
# [334305 rows x 5 columns]

# %%
# add the single MeSH term that exists for studies with only 1 condition listed
single_mapped_conditions = pd.merge(conditions_unmapped, unmapped_single_conditions, left_on=['nct_id'], right_on = ['nct_id'])
single_mapped_conditions
# Out:
#              nct_id                                               name  \
# 0       NCT00000102                     Congenital Adrenal Hyperplasia
# 1       NCT00000105                                             Cancer
# 2       NCT00000110                                            Obesity
# 3       NCT00000115                             Macular Edema, Cystoid
# 4       NCT00000123                                             Myopia
# ...             ...                                                ...
# 241954  NCT05793944                                          Pregnancy
# 241955  NCT05794009                                   Exercise Therapy
# 241956  NCT05794035                          Skin Cancer, Non-Melanoma
# 241957  NCT05794074  Nutrition Deficiency (Xanth Deficiency) Due to...
# 241958  NCT05794087                                      Air Pollution
#
#                                           downcase_name_x mesh_term  \
# 0                          congenital adrenal hyperplasia       NaN
# 1                                                  cancer       NaN
# 2                                                 obesity       NaN
# 3                                  macular edema, cystoid       NaN
# 4                                                  myopia       NaN
# ...                                                   ...       ...
# 241954                                          pregnancy       NaN
# 241955                                   exercise therapy       NaN
# 241956                          skin cancer, non-melanoma       NaN
# 241957  nutrition deficiency (xanth deficiency) due to...       NaN
# 241958                                      air pollution       NaN
#
#        downcase_mesh_term mesh_type  \
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2                     NaN       NaN
# 3                     NaN       NaN
# 4                     NaN       NaN
# ...                   ...       ...
# 241954                NaN       NaN
# 241955                NaN       NaN
# 241956                NaN       NaN
# 241957                NaN       NaN
# 241958                NaN       NaN
#
#                                           downcase_name_y  condition_counts
# 0                        [congenital adrenal hyperplasia]                 1
# 1                                                [cancer]                 1
# 2                                               [obesity]                 1
# 3                                [macular edema, cystoid]                 1
# 4                                                [myopia]                 1
# ...                                                   ...               ...
# 241954                                        [pregnancy]                 1
# 241955                                 [exercise therapy]                 1
# 241956                        [skin cancer, non-melanoma]                 1
# 241957  [nutrition deficiency (xanth deficiency) due t...                 1
# 241958                                    [air pollution]                 1
#
# [241959 rows x 8 columns]

# %%
# what are the MeSH terms for a study with exactly 1 condition listed. Are there any clinical trials with only 1 condition where there's only 1 MeSH term for it?
condition_mesh_leaves_per_study = pd.DataFrame(condition_mesh_leaves[["nct_id", "downcase_mesh_term"]].groupby('nct_id')['downcase_mesh_term'].apply(list))
condition_mesh_leaves_per_study['mesh_leaf_list_count'] = condition_mesh_leaves_per_study['downcase_mesh_term'].str.len()
singular_condition_mesh_leaves = condition_mesh_leaves_per_study.loc[condition_mesh_leaves_per_study["mesh_leaf_list_count"] == 1] 
single_conditions = singular_condition_mesh_leaves['downcase_mesh_term'].str.get(0)

single_conditions

# %%
# find the studies with only 1 condition listed, and merge the studies with only one term listed with the condition_mesh_leaves with only 1 
conditions_single_mapped = pd.merge(conditions_unmapped, single_conditions, left_on=['nct_id'], right_on = ['nct_id'])
conditions_single_mapped[:20]
