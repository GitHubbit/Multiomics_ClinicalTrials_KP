# %% [markdown]
# ## This notebook constructs the KG/TSVs for Clinical Trials Using Gwenlyn's analysis

# %%
# display cells to maximum width 
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))

# lets you preint multiple outputs per cell, not just last
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import pathlib
import re
import numpy as np
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>

# %% [markdown]
# #### Get Gwen's TSV, clean Conditions and Interventions/Treatments columns, get each per NCT ID per each row

# %%
trials_list = pd.read_csv("trials_list.txt.gz", sep='\t', index_col=False, header=0)
trials_list
# Out:
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 1       NCT00807209       Treatment      Parallel Assignment          2008-12
# 2       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# ...             ...             ...                      ...              ...
# 137111  NCT06310811       Treatment  Single Group Assignment         2024-3-7
# 137112  NCT02375672       Treatment  Single Group Assignment        2015-5-28
# 137113  NCT04252118       Treatment      Parallel Assignment        2020-1-27
# 137114  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 137115  NCT04520607       Treatment      Parallel Assignment        2020-8-25
#
#         n_conditions  n_interventions is_fda_regulated_drug  \
# 0                  1                3                     ?
# 1                  1                5                     ?
# 2                  2                2                     t
# 3                  1                2                     ?
# 4                  1                1                     t
# ...              ...              ...                   ...
# 137111             2                1                     f
# 137112             1                2                     ?
# 137113             1                1                     f
# 137114             3                2                     f
# 137115             1                2                     t
#
#                                                conditions  \
# 0                    Progressive Supranuclear Palsy|1.000
# 1                               Postoperative Pain|-0.092
# 2                     Pruritus|1.000|Skin Disorder|-0.091
# 3                                      Fibromyalgia|1.000
# 4                      Relapsing Multiple Sclerosis|1.000
# ...                                                   ...
# 137111                      Safety|1.000|Effective|-0.048
# 137112                            Colorectal Cancer|1.000
# 137113                                     COVID-19|1.000
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
# 137115                         Osteoarthritis, Knee|0.728
#
#                                   exp_only                     ctr_only  \
# 0                               tideglusib                      placebo
# 1       High Dose SKY0402|Low Dose SKY0402                      Placebo
# 2                N-acetyl cysteine|Placebo                          NaN
# 3                               Pregabalin                      placebo
# 4                                  CNM-Au8                          NaN
# ...                                    ...                          ...
# 137111             RD06-04 Cells injection                          NaN
# 137112              Pembrolizumab|mFOLFOX6                          NaN
# 137113                                MSCs                          NaN
# 137114                                  VC  Sterile Water for Injection
# 137115                Lorecivivint|Placebo                          NaN
#
#                                              both
# 0                                             NaN
# 1       Bupivacaine via epidural|Fentanyl via PCA
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 137111                                        NaN
# 137112                                        NaN
# 137113                                        NaN
# 137114                                        NaN
# 137115                                        NaN
#
# [137116 rows x 11 columns]

# %%
# trials_list_check = trials_list[trials_list['ctr_only'].isnull()] # sometimes exp_only or ctr_only have nulls
# trials_list_check = trials_list[trials_list['exp_only'].isnull()]

# trials_list_check

# %%
scores_list = []
regexp = re.compile(r"^[-+]?[0-9]*\.?[0-9]+$")
conditions = trials_list["conditions"].str.split("|", expand=True)
conditions
high_score_conditions = []
low_score_conditions = []
columns = conditions.columns.tolist()
for index, row in conditions.iterrows():
    for col in columns:
        value = row[col]
        # print(type(value))
        if not value is None:
            # print(value)
            if regexp.search(value):
                condition = conditions.loc[index,col-1]
                # print(condition)
                score = float(value)
                scores_list.append(score)
                if score > 0.9:
                    high_score_conditions.extend([[index, condition]]) 
                else:
                    low_score_conditions.extend([[index, condition]])
# Out:
#                                    0       1                 2       3    \
# 0       Progressive Supranuclear Palsy   1.000              None    None
# 1                   Postoperative Pain  -0.092              None    None
# 2                             Pruritus   1.000     Skin Disorder  -0.091
# 3                         Fibromyalgia   1.000              None    None
# 4         Relapsing Multiple Sclerosis   1.000              None    None
# ...                                ...     ...               ...     ...
# 137111                          Safety   1.000         Effective  -0.048
# 137112               Colorectal Cancer   1.000              None    None
# 137113                        COVID-19   1.000              None    None
# 137114                       Vitamin C   1.000  Pneumonia, Viral   0.462
# 137115            Osteoarthritis, Knee   0.728              None    None
#
#                                      4      5     6     7     8     9    ...  \
# 0                                   None   None  None  None  None  None  ...
# 1                                   None   None  None  None  None  None  ...
# 2                                   None   None  None  None  None  None  ...
# 3                                   None   None  None  None  None  None  ...
# 4                                   None   None  None  None  None  None  ...
# ...                                  ...    ...   ...   ...   ...   ...  ...
# 137111                              None   None  None  None  None  None  ...
# 137112                              None   None  None  None  None  None  ...
# 137113                              None   None  None  None  None  None  ...
# 137114  Pneumonia, Ventilator-Associated  0.071  None  None  None  None  ...
# 137115                              None   None  None  None  None  None  ...
#
#          348   349   350   351   352   353   354   355   356   357
# 0       None  None  None  None  None  None  None  None  None  None
# 1       None  None  None  None  None  None  None  None  None  None
# 2       None  None  None  None  None  None  None  None  None  None
# 3       None  None  None  None  None  None  None  None  None  None
# 4       None  None  None  None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 137111  None  None  None  None  None  None  None  None  None  None
# 137112  None  None  None  None  None  None  None  None  None  None
# 137113  None  None  None  None  None  None  None  None  None  None
# 137114  None  None  None  None  None  None  None  None  None  None
# 137115  None  None  None  None  None  None  None  None  None  None
#
# [137116 rows x 358 columns]

# %%
high_score_conditions[-10:]
# Out:
# [[137101, 'Provoked, Localized Vulvodynia'],
#  [137105, 'Acute Myeloid Leukemia'],
#  [137106, 'Discoid Lupus Erythematosus'],
#  [137108, 'Postoperative Pain'],
#  [137108, 'Oocyte Retrieval'],
#  [137110, 'Allergic Conjunctivitis'],
#  [137111, 'Safety'],
#  [137112, 'Colorectal Cancer'],
#  [137113, 'COVID-19'],
#  [137114, 'Vitamin C']]

# %% [markdown]
# #### HISTOGRAM of scores

# %%
# import matplotlib.pyplot as plt

# from matplotlib.ticker import PercentFormatter

# # data = [1000, 1000, 5000, 3000, 4000, 16000, 2000]

# plt.hist(scores_list, weights=np.ones(len(scores_list)) / len(scores_list), bins=20, edgecolor='black')

# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
# plt.xlim(0.5, 1)
# plt.show()

# %%
trials_list
# Out:
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 1       NCT00807209       Treatment      Parallel Assignment          2008-12
# 2       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# ...             ...             ...                      ...              ...
# 137111  NCT06310811       Treatment  Single Group Assignment         2024-3-7
# 137112  NCT02375672       Treatment  Single Group Assignment        2015-5-28
# 137113  NCT04252118       Treatment      Parallel Assignment        2020-1-27
# 137114  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 137115  NCT04520607       Treatment      Parallel Assignment        2020-8-25
#
#         n_conditions  n_interventions is_fda_regulated_drug  \
# 0                  1                3                     ?
# 1                  1                5                     ?
# 2                  2                2                     t
# 3                  1                2                     ?
# 4                  1                1                     t
# ...              ...              ...                   ...
# 137111             2                1                     f
# 137112             1                2                     ?
# 137113             1                1                     f
# 137114             3                2                     f
# 137115             1                2                     t
#
#                                                conditions  \
# 0                    Progressive Supranuclear Palsy|1.000
# 1                               Postoperative Pain|-0.092
# 2                     Pruritus|1.000|Skin Disorder|-0.091
# 3                                      Fibromyalgia|1.000
# 4                      Relapsing Multiple Sclerosis|1.000
# ...                                                   ...
# 137111                      Safety|1.000|Effective|-0.048
# 137112                            Colorectal Cancer|1.000
# 137113                                     COVID-19|1.000
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
# 137115                         Osteoarthritis, Knee|0.728
#
#                                   exp_only                     ctr_only  \
# 0                               tideglusib                      placebo
# 1       High Dose SKY0402|Low Dose SKY0402                      Placebo
# 2                N-acetyl cysteine|Placebo                          NaN
# 3                               Pregabalin                      placebo
# 4                                  CNM-Au8                          NaN
# ...                                    ...                          ...
# 137111             RD06-04 Cells injection                          NaN
# 137112              Pembrolizumab|mFOLFOX6                          NaN
# 137113                                MSCs                          NaN
# 137114                                  VC  Sterile Water for Injection
# 137115                Lorecivivint|Placebo                          NaN
#
#                                              both
# 0                                             NaN
# 1       Bupivacaine via epidural|Fentanyl via PCA
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 137111                                        NaN
# 137112                                        NaN
# 137113                                        NaN
# 137114                                        NaN
# 137115                                        NaN
#
# [137116 rows x 11 columns]

# %%
#   ---    ----  low score conditions   ----    ---   #
new_rows = []
for l in high_score_conditions:
    idx = l[0]
    corresponding_row = trials_list.loc[idx].tolist()
    new_row = corresponding_row + [l[1]]
    new_rows.append(new_row)

# first_length = len(new_rows[0])
# Check if all inner lists have the same length
# all(len(sublist) == first_length for sublist in new_rows)

ct_high = pd.DataFrame(new_rows)
cols = trials_list.columns.tolist() + ["condition"]
ct_high.columns = cols
ct_high["predicate"] = "in_clinical_trials_for"

#   ---    ----  high score conditions   ----    ---   #
new_rows = []
for l in low_score_conditions:
    idx = l[0]
    corresponding_row = trials_list.loc[idx].tolist()
    new_row = corresponding_row + [l[1]]
    new_rows.append(new_row)

# first_length = len(new_rows[0])
# Check if all inner lists have the same length
# all(len(sublist) == first_length for sublist in new_rows)

ct_low = pd.DataFrame(new_rows)
cols = trials_list.columns.tolist() + ["condition"]
ct_low.columns = cols
ct_low["predicate"] = "mentioned_in_clinical_trials_for"

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct_high[:10])
    
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct_low[:10])
len(ct_high)
len(ct_low)
# Out:
#         nct_id primary_purpose       intervention_model start_month_year  \
# 0  NCT01049399       Treatment      Parallel Assignment          2009-12
# 1  NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 2  NCT01432236       Treatment     Crossover Assignment          2011-10
# 3  NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 4  NCT04681417       Treatment      Parallel Assignment        2021-3-25
# 5  NCT04036227       Treatment      Parallel Assignment         2019-7-3
# 6  NCT05624918       Treatment  Single Group Assignment           2024-4
# 7  NCT02886065      Prevention      Parallel Assignment         2017-3-7
# 8  NCT03683576       Treatment      Parallel Assignment       2018-10-22
# 9  NCT00738673       Treatment  Single Group Assignment           2008-7
#
#    n_conditions  n_interventions is_fda_regulated_drug  \
# 0             1                3                     ?
# 1             2                2                     t
# 2             1                2                     ?
# 3             1                1                     t
# 4             1                7                     f
# 5             1                2                     f
# 6             2                3                     f
# 7             1                4                     t
# 8             1                2                     t
# 9             1                1                     ?
#
#                                                            conditions  \
# 0                                Progressive Supranuclear Palsy|1.000
# 1                                 Pruritus|1.000|Skin Disorder|-0.091
# 2                                                  Fibromyalgia|1.000
# 3                                  Relapsing Multiple Sclerosis|1.000
# 4                                                Retinoblastoma|1.000
# 5                                                       Healthy|1.000
# 6  Pancreatic Adenocarcinoma|1.000|Resectable Pancreatic Cancer|0.566
# 7                                   Smoldering Multiple Myeloma|1.000
# 8                                                        Asthma|1.000
# 9                                               Prostate Cancer|1.000
#
#                                      exp_only  \
# 0                                  tideglusib
# 1                   N-acetyl cysteine|Placebo
# 2                                  Pregabalin
# 3                                     CNM-Au8
# 4          Melphalan or Melphalan + Topotecan
# 5                                      GS-248
# 6  Gemcitabine|Nab paclitaxel|NovoTTF-200T(P)
# 7  Citarinostat|Hiltonol|Lenalidomide|PVX-410
# 8                                       GB001
# 9                                   degarelix
#
#                                                                                                                                ctr_only  \
# 0                                                                                                                               placebo
# 1                                                                                                                                   NaN
# 2                                                                                                                               placebo
# 3                                                                                                                                   NaN
# 4  Carboplatin administered on Day 1|etoposide, carboplatin and vincristine or local ophthalmological treatment without IV chemotherapy
# 5                                                                                                                               Placebo
# 6                                                                                                                                   NaN
# 7                                                                                                                                   NaN
# 8                                                                                                                               Placebo
# 9                                                                                                                                   NaN
#
#                                                                                                                                                                   both  \
# 0                                                                                                                                                                  NaN
# 1                                                                                                                                                                  NaN
# 2                                                                                                                                                                  NaN
# 3                                                                                                                                                                  NaN
# 4  Cryotherapy (local treatment)|Intravitreal Melphalan chemotherapy injections (local treatment)|Iodine-125 plaques (local treatment)|Thermotherapy (local treatment)
# 5                                                                                                                                                                  NaN
# 6                                                                                                                                                                  NaN
# 7                                                                                                                                                                  NaN
# 8                                                                                                                                                                  NaN
# 9                                                                                                                                                                  NaN
#
#                         condition               predicate
# 0  Progressive Supranuclear Palsy  in_clinical_trials_for
# 1                        Pruritus  in_clinical_trials_for
# 2                    Fibromyalgia  in_clinical_trials_for
# 3    Relapsing Multiple Sclerosis  in_clinical_trials_for
# 4                  Retinoblastoma  in_clinical_trials_for
# 5                         Healthy  in_clinical_trials_for
# 6       Pancreatic Adenocarcinoma  in_clinical_trials_for
# 7     Smoldering Multiple Myeloma  in_clinical_trials_for
# 8                          Asthma  in_clinical_trials_for
# 9                 Prostate Cancer  in_clinical_trials_for
#         nct_id primary_purpose       intervention_model start_month_year  \
# 0  NCT00807209       Treatment      Parallel Assignment          2008-12
# 1  NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 2  NCT05624918       Treatment  Single Group Assignment           2024-4
# 3  NCT01003288      Prevention  Single Group Assignment          2009-10
# 4  NCT06257693       Treatment  Single Group Assignment           2024-2
# 5  NCT00003494       Treatment  Single Group Assignment        1996-3-26
# 6  NCT06096909       Treatment      Parallel Assignment        2023-11-1
# 7  NCT00012012       Treatment  Single Group Assignment           2001-8
# 8  NCT05377203       Treatment     Crossover Assignment        2022-7-13
# 9  NCT05762107      Prevention     Crossover Assignment        2023-7-28
#
#    n_conditions  n_interventions is_fda_regulated_drug  \
# 0             1                5                     ?
# 1             2                2                     t
# 2             2                3                     f
# 3             1                1                     ?
# 4             1                1                     t
# 5             1                1                     t
# 6             2                3                     f
# 7             2                4                     ?
# 8             2                2                     f
# 9             1                4                     t
#
#                                                                              conditions  \
# 0                                                             Postoperative Pain|-0.092
# 1                                                   Pruritus|1.000|Skin Disorder|-0.091
# 2                    Pancreatic Adenocarcinoma|1.000|Resectable Pancreatic Cancer|0.566
# 3                                                                        Healthy|-0.400
# 4                                                         Prostate Adenocarcinoma|0.033
# 5                                                       Bronchial Alveolar; Tumor|0.567
# 6  Acute Coronary Syndrome|1.000|Non ST Segment Elevation Acute Coronary Syndrome|0.279
# 7                                        Cervical Cancer|1.000|Radiation Toxicity|0.242
# 8                                        Hypertension|1.000|Arterial Hypertension|0.304
# 9                                      Type 1 Diabetes Mellitus With Hypoglycemia|0.733
#
#                                                                                                                                                                        exp_only  \
# 0                                                                                                                                            High Dose SKY0402|Low Dose SKY0402
# 1                                                                                                                                                     N-acetyl cysteine|Placebo
# 2                                                                                                                                    Gemcitabine|Nab paclitaxel|NovoTTF-200T(P)
# 3                                                                                                                                 Adjuvanted influenza H1N1split virion vaccine
# 4                                                                                                                                                                  enzalutamide
# 5                                                                                                                                Antineoplaston therapy (Atengenal + Astugenal)
# 6                                                                                                                                                                   Tafolecimab
# 7                                                                                   Amifostine trihydrate|Cisplatin|External beam radiation therapy|Intracavitary brachytherapy
# 8  Dual combination of standard dose therapy→ Quadruple combination of half doses therapy|Quadruple combination of half doses therapy→Dual combination of standard dose therapy
# 9                                                                                                                                 Placebo|ZT-01, 15 mg|ZT-01, 22 mg|ZT-01, 7 mg
#
#                            ctr_only  \
# 0                           Placebo
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6  Cholesterol Absorption Inhibitor
# 7                               NaN
# 8                               NaN
# 9                               NaN
#
#                                         both  \
# 0  Bupivacaine via epidural|Fentanyl via PCA
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                     Statin
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
#
#                                           condition  \
# 0                                Postoperative Pain
# 1                                     Skin Disorder
# 2                      Resectable Pancreatic Cancer
# 3                                           Healthy
# 4                           Prostate Adenocarcinoma
# 5                         Bronchial Alveolar; Tumor
# 6  Non ST Segment Elevation Acute Coronary Syndrome
# 7                                Radiation Toxicity
# 8                             Arterial Hypertension
# 9        Type 1 Diabetes Mellitus With Hypoglycemia
#
#                           predicate
# 0  mentioned_in_clinical_trials_for
# 1  mentioned_in_clinical_trials_for
# 2  mentioned_in_clinical_trials_for
# 3  mentioned_in_clinical_trials_for
# 4  mentioned_in_clinical_trials_for
# 5  mentioned_in_clinical_trials_for
# 6  mentioned_in_clinical_trials_for
# 7  mentioned_in_clinical_trials_for
# 8  mentioned_in_clinical_trials_for
# 9  mentioned_in_clinical_trials_for
# 104829
# 131559

# %%
ct = pd.concat([ct_high, ct_low], axis=0)
print(len(ct))

ct_exp_only = ct.copy()
ct_exp_only = ct_exp_only.drop(["ctr_only", "both"], axis=1).reset_index(drop=True)
ct_exp_only["exp_only_copy"] = ct_exp_only["exp_only"]
ct_exp_only.exp_only_copy = ct_exp_only.exp_only_copy.str.split('|')
ct_exp_only = ct_exp_only.explode('exp_only_copy')
ct_exp_only = ct_exp_only.rename(columns={'exp_only_copy': 'treatment'})

ct_ctr_only = ct.copy()
ct_ctr_only = ct_ctr_only.drop(["exp_only", "both"], axis=1).reset_index(drop=True)
ct_ctr_only["ctr_only_copy"] = ct_ctr_only["ctr_only"]
ct_ctr_only.ctr_only_copy = ct_ctr_only.ctr_only_copy.str.split('|')
ct_ctr_only = ct_ctr_only.explode('ctr_only_copy')
ct_ctr_only = ct_ctr_only.rename(columns={'ctr_only_copy': 'treatment'})
ct_ctr_only["predicate"] = "mentioned_in_clinical_trials_for"

ct = pd.concat([ct_exp_only, ct_ctr_only], axis=0)
ct.dropna(subset=['treatment'], inplace=True)
ct = ct[~ct['treatment'].isnull()]
ct = ct.drop(["conditions", "exp_only", "ctr_only", "n_conditions", "n_interventions"], axis=1).reset_index(drop=True)
print(len(ct))

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[-10:])
# Out:
# 236388
# 544550
#              nct_id primary_purpose   intervention_model start_month_year  \
# 544540  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544541  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544542  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544543  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544544  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544545  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544546  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544547  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                              condition  \
# 544540                     ?                Provoked Vestibulodynia
# 544541                     ?                    Vulvar Vestibulitis
# 544542                     ?                   Bronchiolitis, Viral
# 544543                     ?            Saline Solution, Hypertonic
# 544544                     ?  First Line Non-Small Cell Lung Cancer
# 544545                     ?  First Line Non-Small Cell Lung Cancer
# 544546                     ?  First Line Non-Small Cell Lung Cancer
# 544547                     ?  First Line Non-Small Cell Lung Cancer
# 544548                     f                       Pneumonia, Viral
# 544549                     f       Pneumonia, Ventilator-Associated
#
#                                predicate                     treatment
# 544540  mentioned_in_clinical_trials_for     Non-classical acupuncture
# 544541  mentioned_in_clinical_trials_for     Non-classical acupuncture
# 544542  mentioned_in_clinical_trials_for  Nebulized 0.9% Normal Saline
# 544543  mentioned_in_clinical_trials_for  Nebulized 0.9% Normal Saline
# 544544  mentioned_in_clinical_trials_for                   Carboplatin
# 544545  mentioned_in_clinical_trials_for                   Gemcitabine
# 544546  mentioned_in_clinical_trials_for                    Paclitaxel
# 544547  mentioned_in_clinical_trials_for                    Pemetrexed
# 544548  mentioned_in_clinical_trials_for   Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for   Sterile Water for Injection

# %%
# List of interventions to block 
undesirable_interventions = [
    "placebo", "standard of care", "laboratory biomarker analysis",
    "questionnaire", "standard treatment",
    "data collection", "educational intervention",
    "intervention group", "training", "management of therapy complications", 
    "contingency management", "active control", "experimental group",
    " sham ", "sham intervention", "active comparator",
    "patient navigation", "self-management", "quality of life",
    "treatment group", "study", "routine care",
]

ct["treatment_lower"] = ct["treatment"].str.lower()
# Create a boolean mask for each substring and combine them with logical OR
mask = ct['treatment_lower'].str.contains('|'.join(undesirable_interventions))
# Filter the DataFrame using the mask and replace matching rows with None
ct.loc[mask, 'treatment_lower'] = None
ct = ct[ct['treatment_lower'].notna()]
ct = ct[~ct['treatment_lower'].isnull()]
print(len(ct))

ct["condition_lower"] = ct["condition"].str.lower()
# Create a boolean mask for each substring and combine them with logical OR
mask = ct['condition_lower'].str.contains('|'.join(undesirable_interventions))
# Filter the DataFrame using the mask and replace matching rows with None
ct.loc[mask, 'condition_lower'] = None
ct = ct[ct['condition_lower'].notna()]
ct = ct[~ct['condition_lower'].isnull()]
print(len(ct))

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])
# Out:
# 470185
# 469833
#          nct_id primary_purpose       intervention_model start_month_year  \
# 0   NCT01049399       Treatment      Parallel Assignment          2009-12
# 1   NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3   NCT01432236       Treatment     Crossover Assignment          2011-10
# 4   NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5   NCT04681417       Treatment      Parallel Assignment        2021-3-25
# 6   NCT04036227       Treatment      Parallel Assignment         2019-7-3
# 7   NCT05624918       Treatment  Single Group Assignment           2024-4
# 8   NCT05624918       Treatment  Single Group Assignment           2024-4
# 9   NCT05624918       Treatment  Single Group Assignment           2024-4
# 10  NCT02886065      Prevention      Parallel Assignment         2017-3-7
#
#    is_fda_regulated_drug                       condition  \
# 0                      ?  Progressive Supranuclear Palsy
# 1                      t                        Pruritus
# 3                      ?                    Fibromyalgia
# 4                      t    Relapsing Multiple Sclerosis
# 5                      f                  Retinoblastoma
# 6                      f                         Healthy
# 7                      f       Pancreatic Adenocarcinoma
# 8                      f       Pancreatic Adenocarcinoma
# 9                      f       Pancreatic Adenocarcinoma
# 10                     t     Smoldering Multiple Myeloma
#
#                  predicate                           treatment  \
# 0   in_clinical_trials_for                          tideglusib
# 1   in_clinical_trials_for                   N-acetyl cysteine
# 3   in_clinical_trials_for                          Pregabalin
# 4   in_clinical_trials_for                             CNM-Au8
# 5   in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# 6   in_clinical_trials_for                              GS-248
# 7   in_clinical_trials_for                         Gemcitabine
# 8   in_clinical_trials_for                      Nab paclitaxel
# 9   in_clinical_trials_for                     NovoTTF-200T(P)
# 10  in_clinical_trials_for                        Citarinostat
#
#                        treatment_lower                 condition_lower
# 0                           tideglusib  progressive supranuclear palsy
# 1                    n-acetyl cysteine                        pruritus
# 3                           pregabalin                    fibromyalgia
# 4                              cnm-au8    relapsing multiple sclerosis
# 5   melphalan or melphalan + topotecan                  retinoblastoma
# 6                               gs-248                         healthy
# 7                          gemcitabine       pancreatic adenocarcinoma
# 8                       nab paclitaxel       pancreatic adenocarcinoma
# 9                      novottf-200t(p)       pancreatic adenocarcinoma
# 10                        citarinostat     smoldering multiple myeloma

# %%
# ct.to_csv("ct_check.tsv", sep='\t', index=False, header=True)
ct.dtypes
# Out:
# nct_id                   object
# primary_purpose          object
# intervention_model       object
# start_month_year         object
# is_fda_regulated_drug    object
# condition                object
# predicate                object
# treatment                object
# treatment_lower          object
# condition_lower          object
# dtype: object

# %%
ct['condition_outside_p'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['condition_lower']]
ct['condition_inside_p'] = ct['condition_lower'].str.extract(r"\((.*?)\)", expand=True)

ct['treatment_outside_p'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['treatment_lower']]
ct['treatment_inside_p'] = ct['treatment_lower'].str.extract(r"\((.*?)\)", expand=True)

ct['condition_outside_b'] =  [re.sub(r'\[([^\]]+)\]','', str(x)) for x in ct['condition_lower']]
ct['condition_inside_b'] = ct['condition_lower'].str.extract(r'\[([^\]]+)\]', expand=True)

ct['treatment_outside_b'] =  [re.sub(r'\[([^\]]+)\]','', str(x)) for x in ct['treatment_lower']]
ct['treatment_inside_b'] = ct['treatment_lower'].str.extract(r'\[([^\]]+)\]', expand=True)

ct = ct.apply(lambda x: x.str.strip() if x.dtype == "object" else x) # strip leading and trailing whitespace
ct = ct[~ct['condition_lower'].isnull()]
ct = ct[~ct['treatment_lower'].isnull()]

split_chars = [",", "+", "/", " and ", "&", " or "]
split_chars = [re.escape(char) for char in split_chars]

# Function to split column based on list of characters
def split_column(df, column, split_chars):
    # Create a temporary dataframe to store split values
    temp_df = df[column].str.split('|'.join(split_chars), expand=True)
    # Rename columns of the temporary dataframe
    temp_df.columns = [f'{column}_{i+1}' for i in range(temp_df.shape[1])]
    return temp_df

# Apply split_column function to the desired column
split_con_outside_p = split_column(ct, 'condition_outside_p', split_chars)
split_con_inside_p = split_column(ct, 'condition_inside_p', split_chars)
split_trmnt_outside_p = split_column(ct, 'treatment_outside_p', split_chars)
split_trmnt_inside_p = split_column(ct, 'treatment_inside_p', split_chars)

split_con_outside_b = split_column(ct, 'condition_outside_b', split_chars)
split_con_inside_b = split_column(ct, 'condition_inside_b', split_chars)
split_trmnt_outside_b = split_column(ct, 'treatment_outside_b', split_chars)
split_trmnt_inside_b = split_column(ct, 'treatment_inside_b', split_chars)

# Concatenate the split dataframe with the original dataframe
split_df = pd.concat([split_con_outside_p, split_con_inside_p, split_trmnt_outside_p, split_trmnt_inside_p,
                     split_con_outside_b, split_con_inside_b, split_trmnt_outside_b, split_trmnt_inside_b], axis=1)
split_df = split_df.fillna(np.nan).replace([np.nan], [None]) # replace NaN values in dataframe with None (just for consistency)
split_df = pd.concat([ct["condition_lower"], ct["treatment_lower"], split_df], axis=1)

split_df = split_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x) # strip leading and trailing whitespace

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(split_df[:10])
# Out:
#                    condition_lower                     treatment_lower  \
# 0   progressive supranuclear palsy                          tideglusib
# 1                         pruritus                   n-acetyl cysteine
# 3                     fibromyalgia                          pregabalin
# 4     relapsing multiple sclerosis                             cnm-au8
# 5                   retinoblastoma  melphalan or melphalan + topotecan
# 6                          healthy                              gs-248
# 7        pancreatic adenocarcinoma                         gemcitabine
# 8        pancreatic adenocarcinoma                      nab paclitaxel
# 9        pancreatic adenocarcinoma                     novottf-200t(p)
# 10     smoldering multiple myeloma                        citarinostat
#
#              condition_outside_p_1 condition_outside_p_2  \
# 0   progressive supranuclear palsy                  None
# 1                         pruritus                  None
# 3                     fibromyalgia                  None
# 4     relapsing multiple sclerosis                  None
# 5                   retinoblastoma                  None
# 6                          healthy                  None
# 7        pancreatic adenocarcinoma                  None
# 8        pancreatic adenocarcinoma                  None
# 9        pancreatic adenocarcinoma                  None
# 10     smoldering multiple myeloma                  None
#
#    condition_outside_p_3 condition_outside_p_4 condition_outside_p_5  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_p_6 condition_outside_p_7 condition_outside_p_8  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_p_9 condition_outside_p_10 condition_outside_p_11  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 3                   None                   None                   None
# 4                   None                   None                   None
# 5                   None                   None                   None
# 6                   None                   None                   None
# 7                   None                   None                   None
# 8                   None                   None                   None
# 9                   None                   None                   None
# 10                  None                   None                   None
#
#    condition_outside_p_12 condition_inside_p_1 condition_inside_p_2  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 3                    None                 None                 None
# 4                    None                 None                 None
# 5                    None                 None                 None
# 6                    None                 None                 None
# 7                    None                 None                 None
# 8                    None                 None                 None
# 9                    None                 None                 None
# 10                   None                 None                 None
#
#    condition_inside_p_3 condition_inside_p_4 condition_inside_p_5  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    condition_inside_p_6 treatment_outside_p_1 treatment_outside_p_2  \
# 0                  None            tideglusib                  None
# 1                  None     n-acetyl cysteine                  None
# 3                  None            pregabalin                  None
# 4                  None               cnm-au8                  None
# 5                  None             melphalan             melphalan
# 6                  None                gs-248                  None
# 7                  None           gemcitabine                  None
# 8                  None        nab paclitaxel                  None
# 9                  None          novottf-200t                  None
# 10                 None          citarinostat                  None
#
#    treatment_outside_p_3 treatment_outside_p_4 treatment_outside_p_5  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5              topotecan                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_p_6 treatment_outside_p_7 treatment_outside_p_8  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_p_9 treatment_outside_p_10 treatment_outside_p_11  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 3                   None                   None                   None
# 4                   None                   None                   None
# 5                   None                   None                   None
# 6                   None                   None                   None
# 7                   None                   None                   None
# 8                   None                   None                   None
# 9                   None                   None                   None
# 10                  None                   None                   None
#
#    treatment_outside_p_12 treatment_outside_p_13 treatment_outside_p_14  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_p_15 treatment_outside_p_16 treatment_inside_p_1  \
# 0                    None                   None                 None
# 1                    None                   None                 None
# 3                    None                   None                 None
# 4                    None                   None                 None
# 5                    None                   None                 None
# 6                    None                   None                 None
# 7                    None                   None                 None
# 8                    None                   None                 None
# 9                    None                   None                    p
# 10                   None                   None                 None
#
#    treatment_inside_p_2 treatment_inside_p_3 treatment_inside_p_4  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_inside_p_5 treatment_inside_p_6 treatment_inside_p_7  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_inside_p_8 treatment_inside_p_9           condition_outside_b_1  \
# 0                  None                 None  progressive supranuclear palsy
# 1                  None                 None                        pruritus
# 3                  None                 None                    fibromyalgia
# 4                  None                 None    relapsing multiple sclerosis
# 5                  None                 None                  retinoblastoma
# 6                  None                 None                         healthy
# 7                  None                 None       pancreatic adenocarcinoma
# 8                  None                 None       pancreatic adenocarcinoma
# 9                  None                 None       pancreatic adenocarcinoma
# 10                 None                 None     smoldering multiple myeloma
#
#    condition_outside_b_2 condition_outside_b_3 condition_outside_b_4  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_b_5 condition_outside_b_6 condition_outside_b_7  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_b_8 condition_outside_b_9 condition_outside_b_10  \
# 0                   None                  None                   None
# 1                   None                  None                   None
# 3                   None                  None                   None
# 4                   None                  None                   None
# 5                   None                  None                   None
# 6                   None                  None                   None
# 7                   None                  None                   None
# 8                   None                  None                   None
# 9                   None                  None                   None
# 10                  None                  None                   None
#
#    condition_outside_b_11 condition_outside_b_12 condition_inside_b_1  \
# 0                    None                   None                 None
# 1                    None                   None                 None
# 3                    None                   None                 None
# 4                    None                   None                 None
# 5                    None                   None                 None
# 6                    None                   None                 None
# 7                    None                   None                 None
# 8                    None                   None                 None
# 9                    None                   None                 None
# 10                   None                   None                 None
#
#    treatment_outside_b_1 treatment_outside_b_2 treatment_outside_b_3  \
# 0             tideglusib                  None                  None
# 1      n-acetyl cysteine                  None                  None
# 3             pregabalin                  None                  None
# 4                cnm-au8                  None                  None
# 5              melphalan             melphalan             topotecan
# 6                 gs-248                  None                  None
# 7            gemcitabine                  None                  None
# 8         nab paclitaxel                  None                  None
# 9        novottf-200t(p)                  None                  None
# 10          citarinostat                  None                  None
#
#    treatment_outside_b_4 treatment_outside_b_5 treatment_outside_b_6  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_b_7 treatment_outside_b_8 treatment_outside_b_9  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_b_10 treatment_outside_b_11 treatment_outside_b_12  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_b_13 treatment_outside_b_14 treatment_outside_b_15  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_b_16 treatment_inside_b_1 treatment_inside_b_2  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 3                    None                 None                 None
# 4                    None                 None                 None
# 5                    None                 None                 None
# 6                    None                 None                 None
# 7                    None                 None                 None
# 8                    None                 None                 None
# 9                    None                 None                 None
# 10                   None                 None                 None
#
#    treatment_inside_b_3 treatment_inside_b_4 treatment_inside_b_5
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None

# %%
split_t = split_df.transpose()
split_t = split_t.apply(lambda x: x.mask(x.duplicated(), None))
split_df = split_t.transpose()
split_df = split_df[~split_df['condition_lower'].isnull()]
split_df = split_df[~split_df['treatment_lower'].isnull()]

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(split_df[:10])
# Out:
#                    condition_lower                     treatment_lower  \
# 0   progressive supranuclear palsy                          tideglusib
# 1                         pruritus                   n-acetyl cysteine
# 3                     fibromyalgia                          pregabalin
# 4     relapsing multiple sclerosis                             cnm-au8
# 5                   retinoblastoma  melphalan or melphalan + topotecan
# 6                          healthy                              gs-248
# 7        pancreatic adenocarcinoma                         gemcitabine
# 8        pancreatic adenocarcinoma                      nab paclitaxel
# 9        pancreatic adenocarcinoma                     novottf-200t(p)
# 10     smoldering multiple myeloma                        citarinostat
#
#    condition_outside_p_1 condition_outside_p_2 condition_outside_p_3  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_p_4 condition_outside_p_5 condition_outside_p_6  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_p_7 condition_outside_p_8 condition_outside_p_9  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_p_10 condition_outside_p_11 condition_outside_p_12  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    condition_inside_p_1 condition_inside_p_2 condition_inside_p_3  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    condition_inside_p_4 condition_inside_p_5 condition_inside_p_6  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_outside_p_1 treatment_outside_p_2 treatment_outside_p_3  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5              melphalan                  None             topotecan
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9           novottf-200t                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_p_4 treatment_outside_p_5 treatment_outside_p_6  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_p_7 treatment_outside_p_8 treatment_outside_p_9  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_p_10 treatment_outside_p_11 treatment_outside_p_12  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_p_13 treatment_outside_p_14 treatment_outside_p_15  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_p_16 treatment_inside_p_1 treatment_inside_p_2  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 3                    None                 None                 None
# 4                    None                 None                 None
# 5                    None                 None                 None
# 6                    None                 None                 None
# 7                    None                 None                 None
# 8                    None                 None                 None
# 9                    None                    p                 None
# 10                   None                 None                 None
#
#    treatment_inside_p_3 treatment_inside_p_4 treatment_inside_p_5  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_inside_p_6 treatment_inside_p_7 treatment_inside_p_8  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_inside_p_9 condition_outside_b_1 condition_outside_b_2  \
# 0                  None                  None                  None
# 1                  None                  None                  None
# 3                  None                  None                  None
# 4                  None                  None                  None
# 5                  None                  None                  None
# 6                  None                  None                  None
# 7                  None                  None                  None
# 8                  None                  None                  None
# 9                  None                  None                  None
# 10                 None                  None                  None
#
#    condition_outside_b_3 condition_outside_b_4 condition_outside_b_5  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_b_6 condition_outside_b_7 condition_outside_b_8  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    condition_outside_b_9 condition_outside_b_10 condition_outside_b_11  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 3                   None                   None                   None
# 4                   None                   None                   None
# 5                   None                   None                   None
# 6                   None                   None                   None
# 7                   None                   None                   None
# 8                   None                   None                   None
# 9                   None                   None                   None
# 10                  None                   None                   None
#
#    condition_outside_b_12 condition_inside_b_1 treatment_outside_b_1  \
# 0                    None                 None                  None
# 1                    None                 None                  None
# 3                    None                 None                  None
# 4                    None                 None                  None
# 5                    None                 None                  None
# 6                    None                 None                  None
# 7                    None                 None                  None
# 8                    None                 None                  None
# 9                    None                 None                  None
# 10                   None                 None                  None
#
#    treatment_outside_b_2 treatment_outside_b_3 treatment_outside_b_4  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_b_5 treatment_outside_b_6 treatment_outside_b_7  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
#
#    treatment_outside_b_8 treatment_outside_b_9 treatment_outside_b_10  \
# 0                   None                  None                   None
# 1                   None                  None                   None
# 3                   None                  None                   None
# 4                   None                  None                   None
# 5                   None                  None                   None
# 6                   None                  None                   None
# 7                   None                  None                   None
# 8                   None                  None                   None
# 9                   None                  None                   None
# 10                  None                  None                   None
#
#    treatment_outside_b_11 treatment_outside_b_12 treatment_outside_b_13  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_outside_b_14 treatment_outside_b_15 treatment_outside_b_16  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
#
#    treatment_inside_b_1 treatment_inside_b_2 treatment_inside_b_3  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
# 5                  None                 None                 None
# 6                  None                 None                 None
# 7                  None                 None                 None
# 8                  None                 None                 None
# 9                  None                 None                 None
# 10                 None                 None                 None
#
#    treatment_inside_b_4 treatment_inside_b_5
# 0                  None                 None
# 1                  None                 None
# 3                  None                 None
# 4                  None                 None
# 5                  None                 None
# 6                  None                 None
# 7                  None                 None
# 8                  None                 None
# 9                  None                 None
# 10                 None                 None

# %%
len(ct)
len(split_df)
# Out:
# 469833
# 469034

# %%
test = split_df[split_df['treatment_lower'].isnull()]
test
# Out:
# Empty DataFrame
# Columns: [condition_lower, treatment_lower, condition_outside_p_1, condition_outside_p_2, condition_outside_p_3, condition_outside_p_4, condition_outside_p_5, condition_outside_p_6, condition_outside_p_7, condition_outside_p_8, condition_outside_p_9, condition_outside_p_10, condition_outside_p_11, condition_outside_p_12, condition_inside_p_1, condition_inside_p_2, condition_inside_p_3, condition_inside_p_4, condition_inside_p_5, condition_inside_p_6, treatment_outside_p_1, treatment_outside_p_2, treatment_outside_p_3, treatment_outside_p_4, treatment_outside_p_5, treatment_outside_p_6, treatment_outside_p_7, treatment_outside_p_8, treatment_outside_p_9, treatment_outside_p_10, treatment_outside_p_11, treatment_outside_p_12, treatment_outside_p_13, treatment_outside_p_14, treatment_outside_p_15, treatment_outside_p_16, treatment_inside_p_1, treatment_inside_p_2, treatment_inside_p_3, treatment_inside_p_4, treatment_inside_p_5, treatment_inside_p_6, treatment_inside_p_7, treatment_inside_p_8, treatment_inside_p_9, condition_outside_b_1, condition_outside_b_2, condition_outside_b_3, condition_outside_b_4, condition_outside_b_5, condition_outside_b_6, condition_outside_b_7, condition_outside_b_8, condition_outside_b_9, condition_outside_b_10, condition_outside_b_11, condition_outside_b_12, condition_inside_b_1, treatment_outside_b_1, treatment_outside_b_2, treatment_outside_b_3, treatment_outside_b_4, treatment_outside_b_5, treatment_outside_b_6, treatment_outside_b_7, treatment_outside_b_8, treatment_outside_b_9, treatment_outside_b_10, treatment_outside_b_11, treatment_outside_b_12, treatment_outside_b_13, treatment_outside_b_14, treatment_outside_b_15, treatment_outside_b_16, treatment_inside_b_1, treatment_inside_b_2, treatment_inside_b_3, treatment_inside_b_4, treatment_inside_b_5]
# Index: []
#
# [0 rows x 79 columns]

# %%
condition_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['condition']])] # find columns with "condition" in it 
treatment_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['treatment']])] # find columns with "treatment" in it 
condition_cols[:5]
treatment_cols[:5]
# Out:
# ['condition_lower',
#  'condition_outside_p_1',
#  'condition_outside_p_2',
#  'condition_outside_p_3',
#  'condition_outside_p_4']
# ['treatment_lower',
#  'treatment_outside_p_1',
#  'treatment_outside_p_2',
#  'treatment_outside_p_3',
#  'treatment_outside_p_4']

# %%
split_df["condition_collections"] = split_df[condition_cols].stack().groupby(level=0).apply(list).values.tolist()  # get the columns with conditions into a list in a single column, ignoring the None values
split_df["treatment_collections"] = split_df[treatment_cols].stack().groupby(level=0).apply(list).values.tolist()  # get the columns with treatments into a list in a single column, ignoring the None values

# split_df
# trmnts = split_df[treatment_cols].stack().groupby(level=0).apply(list).values.tolist()
# len(trmnts)

# conds = split_df[condition_cols].stack().groupby(level=0).apply(list).values.tolist()
# len(conds)

# %%
ct["condition_collections"] = split_df["condition_collections"]
ct["treatment_collections"] = split_df["treatment_collections"]
cols_to_keep = [element for element in ct.columns if not any(substring in element for substring in ['inside', 'outside', 'lower'])]
ct = ct[cols_to_keep]
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[-10:])
# Out:
#              nct_id primary_purpose   intervention_model start_month_year  \
# 544540  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544541  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544542  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544543  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544544  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544545  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544546  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544547  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                              condition  \
# 544540                     ?                Provoked Vestibulodynia
# 544541                     ?                    Vulvar Vestibulitis
# 544542                     ?                   Bronchiolitis, Viral
# 544543                     ?            Saline Solution, Hypertonic
# 544544                     ?  First Line Non-Small Cell Lung Cancer
# 544545                     ?  First Line Non-Small Cell Lung Cancer
# 544546                     ?  First Line Non-Small Cell Lung Cancer
# 544547                     ?  First Line Non-Small Cell Lung Cancer
# 544548                     f                       Pneumonia, Viral
# 544549                     f       Pneumonia, Ventilator-Associated
#
#                                predicate                     treatment  \
# 544540  mentioned_in_clinical_trials_for     Non-classical acupuncture
# 544541  mentioned_in_clinical_trials_for     Non-classical acupuncture
# 544542  mentioned_in_clinical_trials_for  Nebulized 0.9% Normal Saline
# 544543  mentioned_in_clinical_trials_for  Nebulized 0.9% Normal Saline
# 544544  mentioned_in_clinical_trials_for                   Carboplatin
# 544545  mentioned_in_clinical_trials_for                   Gemcitabine
# 544546  mentioned_in_clinical_trials_for                    Paclitaxel
# 544547  mentioned_in_clinical_trials_for                    Pemetrexed
# 544548  mentioned_in_clinical_trials_for   Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for   Sterile Water for Injection
#
#                                                        condition_collections  \
# 544540                                             [provoked vestibulodynia]
# 544541                                                 [vulvar vestibulitis]
# 544542                          [bronchiolitis, viral, bronchiolitis, viral]
# 544543            [saline solution, hypertonic, saline solution, hypertonic]
# 544544                               [first line non-small cell lung cancer]
# 544545                               [first line non-small cell lung cancer]
# 544546                               [first line non-small cell lung cancer]
# 544547                               [first line non-small cell lung cancer]
# 544548                                  [pneumonia, viral, pneumonia, viral]
# 544549  [pneumonia, ventilator-associated, pneumonia, ventilator-associated]
#
#                  treatment_collections
# 544540     [non-classical acupuncture]
# 544541     [non-classical acupuncture]
# 544542  [nebulized 0.9% normal saline]
# 544543  [nebulized 0.9% normal saline]
# 544544                   [carboplatin]
# 544545                   [gemcitabine]
# 544546                    [paclitaxel]
# 544547                    [pemetrexed]
# 544548   [sterile water for injection]
# 544549   [sterile water for injection]

# %%
ct = ct.explode('condition_collections')
ct = ct.explode('treatment_collections')
len(ct)
# Out:
# 795705

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[-10:])
# Out:
#              nct_id primary_purpose   intervention_model start_month_year  \
# 544544  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544545  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544546  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544547  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                              condition  \
# 544544                     ?  First Line Non-Small Cell Lung Cancer
# 544545                     ?  First Line Non-Small Cell Lung Cancer
# 544546                     ?  First Line Non-Small Cell Lung Cancer
# 544547                     ?  First Line Non-Small Cell Lung Cancer
# 544548                     f                       Pneumonia, Viral
# 544548                     f                       Pneumonia, Viral
# 544548                     f                       Pneumonia, Viral
# 544549                     f       Pneumonia, Ventilator-Associated
# 544549                     f       Pneumonia, Ventilator-Associated
# 544549                     f       Pneumonia, Ventilator-Associated
#
#                                predicate                    treatment  \
# 544544  mentioned_in_clinical_trials_for                  Carboplatin
# 544545  mentioned_in_clinical_trials_for                  Gemcitabine
# 544546  mentioned_in_clinical_trials_for                   Paclitaxel
# 544547  mentioned_in_clinical_trials_for                   Pemetrexed
# 544548  mentioned_in_clinical_trials_for  Sterile Water for Injection
# 544548  mentioned_in_clinical_trials_for  Sterile Water for Injection
# 544548  mentioned_in_clinical_trials_for  Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for  Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for  Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for  Sterile Water for Injection
#
#                         condition_collections        treatment_collections
# 544544  first line non-small cell lung cancer                  carboplatin
# 544545  first line non-small cell lung cancer                  gemcitabine
# 544546  first line non-small cell lung cancer                   paclitaxel
# 544547  first line non-small cell lung cancer                   pemetrexed
# 544548                       pneumonia, viral  sterile water for injection
# 544548                              pneumonia  sterile water for injection
# 544548                                  viral  sterile water for injection
# 544549       pneumonia, ventilator-associated  sterile water for injection
# 544549                              pneumonia  sterile water for injection
# 544549                  ventilator-associated  sterile water for injection

# %%
ct['condition_collections'] = ct['condition_collections'].apply(lambda x: x if len(str(x)) > 3 else None)
ct['treatment_collections'] = ct['treatment_collections'].apply(lambda x: x if len(str(x)) > 3 else None)
ct = ct[~ct['condition_collections'].isnull()]
ct = ct[~ct['treatment_collections'].isnull()]
ct
# Out:
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 1       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5       NCT04681417       Treatment      Parallel Assignment        2021-3-25
# ...             ...             ...                      ...              ...
# 544548  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544548  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                         condition  \
# 0                          ?    Progressive Supranuclear Palsy
# 1                          t                          Pruritus
# 3                          ?                      Fibromyalgia
# 4                          t      Relapsing Multiple Sclerosis
# 5                          f                    Retinoblastoma
# ...                      ...                               ...
# 544548                     f                  Pneumonia, Viral
# 544548                     f                  Pneumonia, Viral
# 544549                     f  Pneumonia, Ventilator-Associated
# 544549                     f  Pneumonia, Ventilator-Associated
# 544549                     f  Pneumonia, Ventilator-Associated
#
#                                predicate                           treatment  \
# 0                 in_clinical_trials_for                          tideglusib
# 1                 in_clinical_trials_for                   N-acetyl cysteine
# 3                 in_clinical_trials_for                          Pregabalin
# 4                 in_clinical_trials_for                             CNM-Au8
# 5                 in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# ...                                  ...                                 ...
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
#
#                    condition_collections               treatment_collections
# 0         progressive supranuclear palsy                          tideglusib
# 1                               pruritus                   n-acetyl cysteine
# 3                           fibromyalgia                          pregabalin
# 4           relapsing multiple sclerosis                             cnm-au8
# 5                         retinoblastoma  melphalan or melphalan + topotecan
# ...                                  ...                                 ...
# 544548                         pneumonia         sterile water for injection
# 544548                             viral         sterile water for injection
# 544549  pneumonia, ventilator-associated         sterile water for injection
# 544549                         pneumonia         sterile water for injection
# 544549             ventilator-associated         sterile water for injection
#
# [750068 rows x 10 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[8700:8710])
# Out:
#            nct_id primary_purpose    intervention_model start_month_year  \
# 6084  NCT06012760       Treatment   Parallel Assignment         2024-4-1
# 6084  NCT06012760       Treatment   Parallel Assignment         2024-4-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6085  NCT03676309       Treatment   Parallel Assignment         2017-9-1
# 6086  NCT04015492       Treatment  Crossover Assignment         2019-8-8
# 6086  NCT04015492       Treatment  Crossover Assignment         2019-8-8
#
#      is_fda_regulated_drug                  condition               predicate  \
# 6084                     f            Cardiac Surgery  in_clinical_trials_for
# 6084                     f            Cardiac Surgery  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6085                     f  Diabetes Mellitus, Type 2  in_clinical_trials_for
# 6086                     t               Hemophilia A  in_clinical_trials_for
# 6086                     t               Hemophilia A  in_clinical_trials_for
#
#                                                     treatment  \
# 6084  Iron sucrose, Human Erythropoietin Injection, Vitamin C
# 6084  Iron sucrose, Human Erythropoietin Injection, Vitamin C
# 6085                              Nutriceutical Oral Capsule,
# 6085                              Nutriceutical Oral Capsule,
# 6085                              Nutriceutical Oral Capsule,
# 6085                              Nutriceutical Oral Capsule,
# 6085                              Nutriceutical Oral Capsule,
# 6085                              Nutriceutical Oral Capsule,
# 6086                 Damoctocog-alfa-pegol (BAY94-9027, Jivi)
# 6086                 Damoctocog-alfa-pegol (BAY94-9027, Jivi)
#
#           condition_collections                     treatment_collections
# 6084            cardiac surgery            human erythropoietin injection
# 6084            cardiac surgery                                 vitamin c
# 6085  diabetes mellitus, type 2               nutriceutical oral capsule,
# 6085  diabetes mellitus, type 2                nutriceutical oral capsule
# 6085          diabetes mellitus               nutriceutical oral capsule,
# 6085          diabetes mellitus                nutriceutical oral capsule
# 6085                     type 2               nutriceutical oral capsule,
# 6085                     type 2                nutriceutical oral capsule
# 6086               hemophilia a  damoctocog-alfa-pegol (bay94-9027, jivi)
# 6086               hemophilia a                     damoctocog-alfa-pegol

# %% [markdown]
# #### Map CURIEs from mapper to ct dataframe

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.condition_collections.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatment_collections.map(interventions_dict)
ct
# Out:
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 1       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5       NCT04681417       Treatment      Parallel Assignment        2021-3-25
# ...             ...             ...                      ...              ...
# 544548  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544548  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                         condition  \
# 0                          ?    Progressive Supranuclear Palsy
# 1                          t                          Pruritus
# 3                          ?                      Fibromyalgia
# 4                          t      Relapsing Multiple Sclerosis
# 5                          f                    Retinoblastoma
# ...                      ...                               ...
# 544548                     f                  Pneumonia, Viral
# 544548                     f                  Pneumonia, Viral
# 544549                     f  Pneumonia, Ventilator-Associated
# 544549                     f  Pneumonia, Ventilator-Associated
# 544549                     f  Pneumonia, Ventilator-Associated
#
#                                predicate                           treatment  \
# 0                 in_clinical_trials_for                          tideglusib
# 1                 in_clinical_trials_for                   N-acetyl cysteine
# 3                 in_clinical_trials_for                          Pregabalin
# 4                 in_clinical_trials_for                             CNM-Au8
# 5                 in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# ...                                  ...                                 ...
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
#
#                    condition_collections               treatment_collections  \
# 0         progressive supranuclear palsy                          tideglusib
# 1                               pruritus                   n-acetyl cysteine
# 3                           fibromyalgia                          pregabalin
# 4           relapsing multiple sclerosis                             cnm-au8
# 5                         retinoblastoma  melphalan or melphalan + topotecan
# ...                                  ...                                 ...
# 544548                         pneumonia         sterile water for injection
# 544548                             viral         sterile water for injection
# 544549  pneumonia, ventilator-associated         sterile water for injection
# 544549                         pneumonia         sterile water for injection
# 544549             ventilator-associated         sterile water for injection
#
#                                      condition_curie_info  \
# 0       {'mapped_name': 'Progressive supranuclear pals...
# 1       {'mapped_name': 'Pruritus', 'mapped_curie': 'C...
# 3       {'mapped_name': 'Fibromyalgia', 'mapped_curie'...
# 4       {'mapped_name': 'Multiple Sclerosis', 'mapped_...
# 5       {'mapped_name': 'Retinoblastoma', 'mapped_curi...
# ...                                                   ...
# 544548  {'mapped_name': 'Pneumonia', 'mapped_curie': '...
# 544548                                                NaN
# 544549  {'mapped_name': 'Pneumonia, Ventilator-Associa...
# 544549  {'mapped_name': 'Pneumonia', 'mapped_curie': '...
# 544549                                                NaN
#
#                                      treatment_curie_info
# 0       {'mapped_name': 'Tideglusib', 'mapped_curie': ...
# 1       {'mapped_name': 'acetylcysteine', 'mapped_curi...
# 3       {'mapped_name': 'pregabalin', 'mapped_curie': ...
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 544548  {'mapped_name': 'Sterile Water for Injection',...
# 544548  {'mapped_name': 'Sterile Water for Injection',...
# 544549  {'mapped_name': 'Sterile Water for Injection',...
# 544549  {'mapped_name': 'Sterile Water for Injection',...
# 544549  {'mapped_name': 'Sterile Water for Injection',...
#
# [750068 rows x 12 columns]

# %%
ct = ct.dropna(subset=["condition_curie_info", "treatment_curie_info"])
ct
# Out:
#              nct_id primary_purpose    intervention_model start_month_year  \
# 0       NCT01049399       Treatment   Parallel Assignment          2009-12
# 1       NCT05287724       Treatment  Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment  Crossover Assignment          2011-10
# 5       NCT04681417       Treatment   Parallel Assignment        2021-3-25
# 5       NCT04681417       Treatment   Parallel Assignment        2021-3-25
# ...             ...             ...                   ...              ...
# 544547  NCT02576574       Treatment   Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment   Parallel Assignment        2020-2-14
# 544548  NCT04264533       Treatment   Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment   Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment   Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                              condition  \
# 0                          ?         Progressive Supranuclear Palsy
# 1                          t                               Pruritus
# 3                          ?                           Fibromyalgia
# 5                          f                         Retinoblastoma
# 5                          f                         Retinoblastoma
# ...                      ...                                    ...
# 544547                     ?  First Line Non-Small Cell Lung Cancer
# 544548                     f                       Pneumonia, Viral
# 544548                     f                       Pneumonia, Viral
# 544549                     f       Pneumonia, Ventilator-Associated
# 544549                     f       Pneumonia, Ventilator-Associated
#
#                                predicate                           treatment  \
# 0                 in_clinical_trials_for                          tideglusib
# 1                 in_clinical_trials_for                   N-acetyl cysteine
# 3                 in_clinical_trials_for                          Pregabalin
# 5                 in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# 5                 in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# ...                                  ...                                 ...
# 544547  mentioned_in_clinical_trials_for                          Pemetrexed
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544548  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
# 544549  mentioned_in_clinical_trials_for         Sterile Water for Injection
#
#                         condition_collections        treatment_collections  \
# 0              progressive supranuclear palsy                   tideglusib
# 1                                    pruritus            n-acetyl cysteine
# 3                                fibromyalgia                   pregabalin
# 5                              retinoblastoma                    melphalan
# 5                              retinoblastoma                    topotecan
# ...                                       ...                          ...
# 544547  first line non-small cell lung cancer                   pemetrexed
# 544548                       pneumonia, viral  sterile water for injection
# 544548                              pneumonia  sterile water for injection
# 544549       pneumonia, ventilator-associated  sterile water for injection
# 544549                              pneumonia  sterile water for injection
#
#                                      condition_curie_info  \
# 0       {'mapped_name': 'Progressive supranuclear pals...
# 1       {'mapped_name': 'Pruritus', 'mapped_curie': 'C...
# 3       {'mapped_name': 'Fibromyalgia', 'mapped_curie'...
# 5       {'mapped_name': 'Retinoblastoma', 'mapped_curi...
# 5       {'mapped_name': 'Retinoblastoma', 'mapped_curi...
# ...                                                   ...
# 544547  {'mapped_name': 'Non-Small Cell Lung Carcinoma...
# 544548  {'mapped_name': 'Pneumonia, Viral', 'mapped_cu...
# 544548  {'mapped_name': 'Pneumonia', 'mapped_curie': '...
# 544549  {'mapped_name': 'Pneumonia, Ventilator-Associa...
# 544549  {'mapped_name': 'Pneumonia', 'mapped_curie': '...
#
#                                      treatment_curie_info
# 0       {'mapped_name': 'Tideglusib', 'mapped_curie': ...
# 1       {'mapped_name': 'acetylcysteine', 'mapped_curi...
# 3       {'mapped_name': 'pregabalin', 'mapped_curie': ...
# 5       {'mapped_name': 'melphalan', 'mapped_curie': '...
# 5       {'mapped_name': 'topotecan', 'mapped_curie': '...
# ...                                                   ...
# 544547  {'mapped_name': 'pemetrexed', 'mapped_curie': ...
# 544548  {'mapped_name': 'Sterile Water for Injection',...
# 544548  {'mapped_name': 'Sterile Water for Injection',...
# 544549  {'mapped_name': 'Sterile Water for Injection',...
# 544549  {'mapped_name': 'Sterile Water for Injection',...
#
# [341720 rows x 12 columns]

# %%
ct.to_csv("ct_check.tsv", sep='\t', index=False, header=True)

# %%
ct["conditions_split"] = pd.Series(condition_collections)
ct["treatments_split"] = pd.Series(treatment_collections)
ct

# %%
condition_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['condition']])] # find columns with "condition" in it 
treatment_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['treatment']])] # find columns with "treatment" in it 

def filter_sublist(sublist):
    return [x for x in sublist if x is not None and (not isinstance(x, float) or not np.isnan(x)) and len(x) >= 3]

condition_collections = split_df[condition_cols].values.tolist()
condition_collections = [filter_sublist(sublist) for sublist in condition_collections]

treatment_collections = split_df[treatment_cols].values.tolist()
treatment_collections = [filter_sublist(sublist) for sublist in treatment_collections]

# %%
ct["conditions_split"] = pd.Series(condition_collections)
ct["treatments_split"] = pd.Series(treatment_collections)
cols_to_keep = [element for element in ct.columns if not any(substring in element for substring in ['inside', 'outside'])]
ct = ct[cols_to_keep]
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])

# %%
ct = ct.explode('conditions_split')
ct = ct.explode('treatments_split')
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])

# %% [markdown]
# #### Map CURIEs from mapper to ct dataframe

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.conditions_split.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatments_split.map(interventions_dict)
# ct = ct.drop(["conditions_split", "treatments_split", "condition_lower", "treatment_lower"], axis=1).reset_index(drop=True)
ct = ct.drop(["condition_lower", "treatment_lower"], axis=1).reset_index(drop=True)
ct.dropna(subset=['condition_curie_info', 'treatment_curie_info'], inplace=True)

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])
# Out:
#          nct_id primary_purpose       intervention_model start_month_year  \
# 0   NCT01049399       Treatment      Parallel Assignment          2009-12
# 1   NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 4   NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5   NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 7   NCT04036227       Treatment      Parallel Assignment         2019-7-3
# 10  NCT05624918       Treatment  Single Group Assignment           2024-4
# 11  NCT05624918       Treatment  Single Group Assignment           2024-4
# 12  NCT02886065      Prevention      Parallel Assignment         2017-3-7
# 13  NCT02886065      Prevention      Parallel Assignment         2017-3-7
# 16  NCT03683576       Treatment      Parallel Assignment       2018-10-22
#
#    is_fda_regulated_drug                       condition  \
# 0                      ?  Progressive Supranuclear Palsy
# 1                      t                        Pruritus
# 4                      t    Relapsing Multiple Sclerosis
# 5                      t    Relapsing Multiple Sclerosis
# 7                      f                         Healthy
# 10                     f       Pancreatic Adenocarcinoma
# 11                     f       Pancreatic Adenocarcinoma
# 12                     t     Smoldering Multiple Myeloma
# 13                     t     Smoldering Multiple Myeloma
# 16                     t                          Asthma
#
#                  predicate          treatment                conditions_split  \
# 0   in_clinical_trials_for         tideglusib  progressive supranuclear palsy
# 1   in_clinical_trials_for  N-acetyl cysteine                        pruritus
# 4   in_clinical_trials_for            CNM-Au8                  retinoblastoma
# 5   in_clinical_trials_for            CNM-Au8                  retinoblastoma
# 7   in_clinical_trials_for             GS-248       pancreatic adenocarcinoma
# 10  in_clinical_trials_for     Nab paclitaxel       pancreatic adenocarcinoma
# 11  in_clinical_trials_for    NovoTTF-200T(P)     smoldering multiple myeloma
# 12  in_clinical_trials_for       Citarinostat     smoldering multiple myeloma
# 13  in_clinical_trials_for           Hiltonol     smoldering multiple myeloma
# 16  in_clinical_trials_for              GB001                 prostate cancer
#
#      treatments_split  \
# 0          tideglusib
# 1   n-acetyl cysteine
# 4           melphalan
# 5           topotecan
# 7         gemcitabine
# 10       novottf-200t
# 11       citarinostat
# 12           hiltonol
# 13       lenalidomide
# 16          degarelix
#
#                                                                                                                   condition_curie_info  \
# 0   {'mapped_name': 'Progressive supranuclear palsy', 'mapped_curie': 'C0038868', 'mapped_score': '5.18', 'mapped_semtypes': '[dsyn]'}
# 1                         {'mapped_name': 'Pruritus', 'mapped_curie': 'C0033774', 'mapped_score': '5.18', 'mapped_semtypes': '[fndg]'}
# 4                   {'mapped_name': 'Retinoblastoma', 'mapped_curie': 'C0035335', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 5                   {'mapped_name': 'Retinoblastoma', 'mapped_curie': 'C0035335', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 7       {'mapped_name': 'Adenocarcinoma of pancreas', 'mapped_curie': 'C0281361', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 10      {'mapped_name': 'Adenocarcinoma of pancreas', 'mapped_curie': 'C0281361', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 11              {'mapped_name': 'Smoldering myeloma', 'mapped_curie': 'C1531608', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 12              {'mapped_name': 'Smoldering myeloma', 'mapped_curie': 'C1531608', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 13              {'mapped_name': 'Smoldering myeloma', 'mapped_curie': 'C1531608', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
# 16              {'mapped_name': 'Prostate carcinoma', 'mapped_curie': 'C0600139', 'mapped_score': '5.18', 'mapped_semtypes': '[neop]'}
#
#                                                                                                                        treatment_curie_info
# 0                       {'mapped_name': 'Tideglusib', 'mapped_curie': 'C3273375', 'mapped_score': '5.18', 'mapped_semtypes': '[orch,phsu]'}
# 1                   {'mapped_name': 'acetylcysteine', 'mapped_curie': 'C0001047', 'mapped_score': '5.18', 'mapped_semtypes': '[aapp,phsu]'}
# 4                        {'mapped_name': 'melphalan', 'mapped_curie': 'C0025241', 'mapped_score': '5.18', 'mapped_semtypes': '[aapp,phsu]'}
# 5                        {'mapped_name': 'topotecan', 'mapped_curie': 'C0146224', 'mapped_score': '5.18', 'mapped_semtypes': '[orch,phsu]'}
# 7                      {'mapped_name': 'gemcitabine', 'mapped_curie': 'C0045093', 'mapped_score': '5.18', 'mapped_semtypes': '[nnon,phsu]'}
# 10  {'mapped_name': 'NovoTTF-200A Device', 'mapped_curie': 'UMLS:C4683819', 'mapped_score': 14.063435, 'mapped_semtypes': 'biolink:Device'}
# 11                    {'mapped_name': 'Citarinostat', 'mapped_curie': 'C4724808', 'mapped_score': '5.18', 'mapped_semtypes': '[orch,phsu]'}
# 12                             {'mapped_name': 'hiltonol', 'mapped_curie': 'C2698842', 'mapped_score': '5.18', 'mapped_semtypes': '[phsu]'}
# 13                    {'mapped_name': 'lenalidomide', 'mapped_curie': 'C1144149', 'mapped_score': '5.18', 'mapped_semtypes': '[orch,phsu]'}
# 16                  {'mapped_name': 'degarelix', 'mapped_curie': 'C1455035', 'mapped_score': '5.18', 'mapped_semtypes': '[aapp,horm,phsu]'}

# %%
ct.to_csv("ct_check.tsv", sep='\t', index=False, header=True)

# %%
ct.columns
# Out:
# Index(['nct_id', 'primary_purpose', 'intervention_model', 'start_month_year',
#        'is_fda_regulated_drug', 'condition', 'predicate', 'treatment',
#        'conditions_split', 'treatments_split', 'condition_curie_info',
#        'treatment_curie_info'],
#       dtype='object')

# %%
# ct = ct.drop(["condition_lower", "treatment_lower"], axis=1).reset_index(drop=True)

# %%
high_conditions = {}
for sublist in high_score_conditions:
    if sublist[0] not in high_conditions:
        high_conditions[sublist[0]] = []
    high_conditions[sublist[0]].append(sublist[1]) # dict where key is index of df, and value is the condition
# high_score_conditions

low_conditions = {}
for sublist in low_score_conditions:
    if sublist[0] not in low_conditions:
        low_conditions[sublist[0]] = []
    low_conditions[sublist[0]].append(sublist[1]) # dict where key is index of df, and value is the condition
# high_score_conditions

# %%
ct_high = trials_list.copy()
ct_high['conditions_cleaned'] = ct_high.index.map(high_conditions)
ct_high = ct_high.explode('conditions_cleaned')
ct_high.dropna(subset=['conditions_cleaned'], inplace=True)
ct_high["predicate"] = "in_clinical_trials_for"

ct_low = trials_list.copy()
ct_low['conditions_cleaned'] = ct_low.index.map(low_conditions)
ct_low = ct_low.explode('conditions_cleaned')
ct_low.dropna(subset=['conditions_cleaned'], inplace=True)
ct_low["predicate"] = "mentioned_in_clinical_trials_for"

ct = pd.concat([ct_high, ct_low], axis=0)
ct = ct.replace(np.nan, None)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(ct[:10])
# Out:
#          nct_id primary_purpose       intervention_model start_month_year  \
# 0   NCT01049399       Treatment      Parallel Assignment          2009-12
# 2   NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3   NCT01432236       Treatment     Crossover Assignment          2011-10
# 4   NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5   NCT04681417       Treatment      Parallel Assignment        2021-3-25
# 6   NCT04036227       Treatment      Parallel Assignment         2019-7-3
# 7   NCT05624918       Treatment  Single Group Assignment           2024-4
# 9   NCT02886065      Prevention      Parallel Assignment         2017-3-7
# 12  NCT03683576       Treatment      Parallel Assignment       2018-10-22
# 13  NCT00738673       Treatment  Single Group Assignment           2008-7
#
#     n_conditions  n_interventions is_fda_regulated_drug  \
# 0              1                3                     ?
# 2              2                2                     t
# 3              1                2                     ?
# 4              1                1                     t
# 5              1                7                     f
# 6              1                2                     f
# 7              2                3                     f
# 9              1                4                     t
# 12             1                2                     t
# 13             1                1                     ?
#
#                                            conditions  \
# 0                Progressive Supranuclear Palsy|1.000
# 2                 Pruritus|1.000|Skin Disorder|-0.091
# 3                                  Fibromyalgia|1.000
# 4                  Relapsing Multiple Sclerosis|1.000
# 5                                Retinoblastoma|1.000
# 6                                       Healthy|1.000
# 7   Pancreatic Adenocarcinoma|1.000|Resectable Pan...
# 9                   Smoldering Multiple Myeloma|1.000
# 12                                       Asthma|1.000
# 13                              Prostate Cancer|1.000
#
#                                       exp_only  \
# 0                                   tideglusib
# 2                    N-acetyl cysteine|Placebo
# 3                                   Pregabalin
# 4                                      CNM-Au8
# 5           Melphalan or Melphalan + Topotecan
# 6                                       GS-248
# 7   Gemcitabine|Nab paclitaxel|NovoTTF-200T(P)
# 9   Citarinostat|Hiltonol|Lenalidomide|PVX-410
# 12                                       GB001
# 13                                   degarelix
#
#                                              ctr_only  \
# 0                                             placebo
# 2                                                None
# 3                                             placebo
# 4                                                None
# 5   Carboplatin administered on Day 1|etoposide, c...
# 6                                             Placebo
# 7                                                None
# 9                                                None
# 12                                            Placebo
# 13                                               None
#
#                                                  both  \
# 0                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   Cryotherapy (local treatment)|Intravitreal Mel...
# 6                                                None
# 7                                                None
# 9                                                None
# 12                                               None
# 13                                               None
#
#                 conditions_cleaned               predicate
# 0   Progressive Supranuclear Palsy  in_clinical_trials_for
# 2                         Pruritus  in_clinical_trials_for
# 3                     Fibromyalgia  in_clinical_trials_for
# 4     Relapsing Multiple Sclerosis  in_clinical_trials_for
# 5                   Retinoblastoma  in_clinical_trials_for
# 6                          Healthy  in_clinical_trials_for
# 7        Pancreatic Adenocarcinoma  in_clinical_trials_for
# 9      Smoldering Multiple Myeloma  in_clinical_trials_for
# 12                          Asthma  in_clinical_trials_for
# 13                 Prostate Cancer  in_clinical_trials_for

# %%
ct_treatments = ct.copy()
interventions = ct_treatments["exp_only"].str.split("|", expand=True)
interventions['treatments']= interventions.values.tolist()
interventions['treatments'] = interventions['treatments'].apply(lambda x: list(filter(None, x)))
ct_treatments["treatment"] = interventions['treatments']
ct_treatments = ct_treatments[ct_treatments['treatment'].map(lambda d: len(d)) > 0]

ct_controls = ct.copy()
controls = ct_controls["ctr_only"].str.split("|", expand=True)
controls['control']= controls.values.tolist()
controls['control'] = controls['control'].apply(lambda x: list(filter(None, x)))
controls = controls.rename(columns={'control': 'treatment'})
ct_controls["treatment"] = controls['treatment']
ct_controls["predicate"] = "mentioned_in_clincal_trials_for"
ct_controls = ct_controls[ct_controls['treatment'].map(lambda d: len(d)) > 0]





# data['Power'] = np.where(data['Power'].str.contains('null'), np.nan, data['Power'])

# ct_treatments["treatments"] = interventions['treatments']
# ct_treatments = ct_treatments.explode('treatments')

# ct_controls = ct.copy()
# intervention_controls = ct_controls["ctr_only"].str.split("|", expand=True)
# intervention_controls['controls']= intervention_controls.values.tolist()
# intervention_controls['predicate'] = "mentioned_in_clincal_trials_for"
# intervention_controls['controls'] = intervention_controls['controls'].apply(lambda x: list(filter(None, x)))
# intervention_controls = intervention_controls.rename(columns={'controls': 'treatments'})
# intervention_controls = intervention_controls.explode('treatments')

# ct = pd.concat([ct_treatments, ct_controls], axis=0)

# ct["treatments_cleaned"] = interventions["treatments"]
# ct["controls_cleaned"] = intervention_controls["controls"]
# ct = ct.explode('treatments_cleaned')
# ct = ct.explode('controls_cleaned')
# ct['condition'] = ct['conditions_cleaned'].str.lower()
# ct['treatment'] = ct['treatments_cleaned'].str.lower()
# ct['control'] = ct['controls_cleaned'].str.lower()
# ct = ct.drop(["conditions", "exp_only", "ctr_only", "both", "n_conditions", "n_interventions", "conditions_cleaned", "treatments_cleaned"], axis=1).reset_index(drop=True)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     display(ct_treatments[:10])
    
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     display(ct[:1000])

ct_controls
ct_treatments
# Out:
#              nct_id primary_purpose    intervention_model start_month_year  \
# 0       NCT01049399       Treatment   Parallel Assignment          2009-12
# 3       NCT01432236       Treatment  Crossover Assignment          2011-10
# 5       NCT04681417       Treatment   Parallel Assignment        2021-3-25
# 6       NCT04036227       Treatment   Parallel Assignment         2019-7-3
# 12      NCT03683576       Treatment   Parallel Assignment       2018-10-22
# ...             ...             ...                   ...              ...
# 137104  NCT01247064       Treatment   Parallel Assignment          2010-10
# 137104  NCT01247064       Treatment   Parallel Assignment          2010-10
# 137109  NCT02576574       Treatment   Parallel Assignment       2015-10-29
# 137114  NCT04264533       Treatment   Parallel Assignment        2020-2-14
# 137114  NCT04264533       Treatment   Parallel Assignment        2020-2-14
#
#         n_conditions  n_interventions is_fda_regulated_drug  \
# 0                  1                3                     ?
# 3                  1                2                     ?
# 5                  1                7                     f
# 6                  1                2                     f
# 12                 1                2                     t
# ...              ...              ...                   ...
# 137104             2                2                     ?
# 137104             2                2                     ?
# 137109             1                9                     ?
# 137114             3                2                     f
# 137114             3                2                     f
#
#                                                conditions  \
# 0                    Progressive Supranuclear Palsy|1.000
# 3                                      Fibromyalgia|1.000
# 5                                    Retinoblastoma|1.000
# 6                                           Healthy|1.000
# 12                                           Asthma|1.000
# ...                                                   ...
# 137104  Bronchiolitis, Viral|0.449|Saline Solution, Hy...
# 137104  Bronchiolitis, Viral|0.449|Saline Solution, Hy...
# 137109        First Line Non-Small Cell Lung Cancer|0.581
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
#
#                                   exp_only  \
# 0                               tideglusib
# 3                               Pregabalin
# 5       Melphalan or Melphalan + Topotecan
# 6                                   GS-248
# 12                                   GB001
# ...                                    ...
# 137104                 Nebulized 3% saline
# 137104                 Nebulized 3% saline
# 137109  Avelumab|Avelumab Weekly|Cisplatin
# 137114                                  VC
# 137114                                  VC
#
#                                                  ctr_only  \
# 0                                                 placebo
# 3                                                 placebo
# 5       Carboplatin administered on Day 1|etoposide, c...
# 6                                                 Placebo
# 12                                                Placebo
# ...                                                   ...
# 137104                       Nebulized 0.9% Normal Saline
# 137104                       Nebulized 0.9% Normal Saline
# 137109      Carboplatin|Gemcitabine|Paclitaxel|Pemetrexed
# 137114                        Sterile Water for Injection
# 137114                        Sterile Water for Injection
#
#                                                      both  \
# 0                                                    None
# 3                                                    None
# 5       Cryotherapy (local treatment)|Intravitreal Mel...
# 6                                                    None
# 12                                                   None
# ...                                                   ...
# 137104                                               None
# 137104                                               None
# 137109                                               None
# 137114                                               None
# 137114                                               None
#
#                            conditions_cleaned  \
# 0              Progressive Supranuclear Palsy
# 3                                Fibromyalgia
# 5                              Retinoblastoma
# 6                                     Healthy
# 12                                     Asthma
# ...                                       ...
# 137104                   Bronchiolitis, Viral
# 137104            Saline Solution, Hypertonic
# 137109  First Line Non-Small Cell Lung Cancer
# 137114                       Pneumonia, Viral
# 137114       Pneumonia, Ventilator-Associated
#
#                               predicate  \
# 0       mentioned_in_clincal_trials_for
# 3       mentioned_in_clincal_trials_for
# 5       mentioned_in_clincal_trials_for
# 6       mentioned_in_clincal_trials_for
# 12      mentioned_in_clincal_trials_for
# ...                                 ...
# 137104  mentioned_in_clincal_trials_for
# 137104  mentioned_in_clincal_trials_for
# 137109  mentioned_in_clincal_trials_for
# 137114  mentioned_in_clincal_trials_for
# 137114  mentioned_in_clincal_trials_for
#
#                                                 treatment
# 0                                               [placebo]
# 3                                               [placebo]
# 5       [Carboplatin administered on Day 1, etoposide,...
# 6                                               [Placebo]
# 12                                              [Placebo]
# ...                                                   ...
# 137104                     [Nebulized 0.9% Normal Saline]
# 137104                     [Nebulized 0.9% Normal Saline]
# 137109  [Carboplatin, Gemcitabine, Paclitaxel, Pemetre...
# 137114                      [Sterile Water for Injection]
# 137114                      [Sterile Water for Injection]
#
# [81839 rows x 14 columns]
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 2       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5       NCT04681417       Treatment      Parallel Assignment        2021-3-25
# ...             ...             ...                      ...              ...
# 137109  NCT02576574       Treatment      Parallel Assignment       2015-10-29
# 137111  NCT06310811       Treatment  Single Group Assignment         2024-3-7
# 137114  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 137114  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 137115  NCT04520607       Treatment      Parallel Assignment        2020-8-25
#
#         n_conditions  n_interventions is_fda_regulated_drug  \
# 0                  1                3                     ?
# 2                  2                2                     t
# 3                  1                2                     ?
# 4                  1                1                     t
# 5                  1                7                     f
# ...              ...              ...                   ...
# 137109             1                9                     ?
# 137111             2                1                     f
# 137114             3                2                     f
# 137114             3                2                     f
# 137115             1                2                     t
#
#                                                conditions  \
# 0                    Progressive Supranuclear Palsy|1.000
# 2                     Pruritus|1.000|Skin Disorder|-0.091
# 3                                      Fibromyalgia|1.000
# 4                      Relapsing Multiple Sclerosis|1.000
# 5                                    Retinoblastoma|1.000
# ...                                                   ...
# 137109        First Line Non-Small Cell Lung Cancer|0.581
# 137111                      Safety|1.000|Effective|-0.048
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
# 137114  Vitamin C|1.000|Pneumonia, Viral|0.462|Pneumon...
# 137115                         Osteoarthritis, Knee|0.728
#
#                                   exp_only  \
# 0                               tideglusib
# 2                N-acetyl cysteine|Placebo
# 3                               Pregabalin
# 4                                  CNM-Au8
# 5       Melphalan or Melphalan + Topotecan
# ...                                    ...
# 137109  Avelumab|Avelumab Weekly|Cisplatin
# 137111             RD06-04 Cells injection
# 137114                                  VC
# 137114                                  VC
# 137115                Lorecivivint|Placebo
#
#                                                  ctr_only  \
# 0                                                 placebo
# 2                                                    None
# 3                                                 placebo
# 4                                                    None
# 5       Carboplatin administered on Day 1|etoposide, c...
# ...                                                   ...
# 137109      Carboplatin|Gemcitabine|Paclitaxel|Pemetrexed
# 137111                                               None
# 137114                        Sterile Water for Injection
# 137114                        Sterile Water for Injection
# 137115                                               None
#
#                                                      both  \
# 0                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# 5       Cryotherapy (local treatment)|Intravitreal Mel...
# ...                                                   ...
# 137109                                               None
# 137111                                               None
# 137114                                               None
# 137114                                               None
# 137115                                               None
#
#                            conditions_cleaned  \
# 0              Progressive Supranuclear Palsy
# 2                                    Pruritus
# 3                                Fibromyalgia
# 4                Relapsing Multiple Sclerosis
# 5                              Retinoblastoma
# ...                                       ...
# 137109  First Line Non-Small Cell Lung Cancer
# 137111                              Effective
# 137114                       Pneumonia, Viral
# 137114       Pneumonia, Ventilator-Associated
# 137115                   Osteoarthritis, Knee
#
#                                predicate  \
# 0                 in_clinical_trials_for
# 2                 in_clinical_trials_for
# 3                 in_clinical_trials_for
# 4                 in_clinical_trials_for
# 5                 in_clinical_trials_for
# ...                                  ...
# 137109  mentioned_in_clinical_trials_for
# 137111  mentioned_in_clinical_trials_for
# 137114  mentioned_in_clinical_trials_for
# 137114  mentioned_in_clinical_trials_for
# 137115  mentioned_in_clinical_trials_for
#
#                                      treatment
# 0                                 [tideglusib]
# 2                 [N-acetyl cysteine, Placebo]
# 3                                 [Pregabalin]
# 4                                    [CNM-Au8]
# 5         [Melphalan or Melphalan + Topotecan]
# ...                                        ...
# 137109  [Avelumab, Avelumab Weekly, Cisplatin]
# 137111               [RD06-04 Cells injection]
# 137114                                    [VC]
# 137114                                    [VC]
# 137115                 [Lorecivivint, Placebo]
#
# [225656 rows x 14 columns]

# %%
ct = pd.concat([ct_treatments, ct_controls], axis=0)
ct = ct.drop(["conditions", "exp_only", "ctr_only", "both", "n_conditions", "n_interventions"], axis=1).reset_index(drop=True)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     display(ct.iloc[-1000:])
ct = ct.explode('treatment')
ct['condition'] = ct['conditions_cleaned'].str.lower()
ct['treatment'] = ct['treatment'].str.lower()
ct = ct.drop(["conditions_cleaned"], axis=1).reset_index(drop=True)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(ct.iloc[-10:])
# Out:
#              nct_id primary_purpose   intervention_model start_month_year  \
# 544540  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544541  NCT01996384       Treatment  Parallel Assignment          2013-11
# 544542  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544543  NCT01247064       Treatment  Parallel Assignment          2010-10
# 544544  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544545  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544546  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544547  NCT02576574       Treatment  Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment  Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment  Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                        predicate  \
# 544540                     ?  mentioned_in_clincal_trials_for
# 544541                     ?  mentioned_in_clincal_trials_for
# 544542                     ?  mentioned_in_clincal_trials_for
# 544543                     ?  mentioned_in_clincal_trials_for
# 544544                     ?  mentioned_in_clincal_trials_for
# 544545                     ?  mentioned_in_clincal_trials_for
# 544546                     ?  mentioned_in_clincal_trials_for
# 544547                     ?  mentioned_in_clincal_trials_for
# 544548                     f  mentioned_in_clincal_trials_for
# 544549                     f  mentioned_in_clincal_trials_for
#
#                            treatment                              condition
# 544540     non-classical acupuncture                provoked vestibulodynia
# 544541     non-classical acupuncture                    vulvar vestibulitis
# 544542  nebulized 0.9% normal saline                   bronchiolitis, viral
# 544543  nebulized 0.9% normal saline            saline solution, hypertonic
# 544544                   carboplatin  first line non-small cell lung cancer
# 544545                   gemcitabine  first line non-small cell lung cancer
# 544546                    paclitaxel  first line non-small cell lung cancer
# 544547                    pemetrexed  first line non-small cell lung cancer
# 544548   sterile water for injection                       pneumonia, viral
# 544549   sterile water for injection       pneumonia, ventilator-associated

# %%
# List of interventions to block 
undesirable_interventions = [
    "placebo", "standard of care", "laboratory biomarker analysis",
    "questionnaire", "standard treatment",
    "data collection", "educational intervention",
    "intervention group", "training", "management of therapy complications", 
    "contingency management", "active control", "experimental group",
    "sham intervention", "active comparator", "patient navigation",
    "self-management", "quality of life",
    "treatment group", "study"
]

# Create a boolean mask for each substring and combine them with logical OR
mask = ct['treatment'].str.contains('|'.join(undesirable_interventions))
# Filter the DataFrame using the mask and replace matching rows with None
ct.loc[mask, 'treatment'] = None
ct = ct[ct['treatment'].notna()]
ct = ct[ct['condition'].notna()]
ct
# Out:
#              nct_id primary_purpose       intervention_model start_month_year  \
# 0       NCT01049399       Treatment      Parallel Assignment          2009-12
# 1       NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3       NCT01432236       Treatment     Crossover Assignment          2011-10
# 4       NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5       NCT04681417       Treatment      Parallel Assignment        2021-3-25
# ...             ...             ...                      ...              ...
# 544545  NCT02576574       Treatment      Parallel Assignment       2015-10-29
# 544546  NCT02576574       Treatment      Parallel Assignment       2015-10-29
# 544547  NCT02576574       Treatment      Parallel Assignment       2015-10-29
# 544548  NCT04264533       Treatment      Parallel Assignment        2020-2-14
# 544549  NCT04264533       Treatment      Parallel Assignment        2020-2-14
#
#        is_fda_regulated_drug                        predicate  \
# 0                          ?           in_clinical_trials_for
# 1                          t           in_clinical_trials_for
# 3                          ?           in_clinical_trials_for
# 4                          t           in_clinical_trials_for
# 5                          f           in_clinical_trials_for
# ...                      ...                              ...
# 544545                     ?  mentioned_in_clincal_trials_for
# 544546                     ?  mentioned_in_clincal_trials_for
# 544547                     ?  mentioned_in_clincal_trials_for
# 544548                     f  mentioned_in_clincal_trials_for
# 544549                     f  mentioned_in_clincal_trials_for
#
#                                  treatment  \
# 0                               tideglusib
# 1                        n-acetyl cysteine
# 3                               pregabalin
# 4                                  cnm-au8
# 5       melphalan or melphalan + topotecan
# ...                                    ...
# 544545                         gemcitabine
# 544546                          paclitaxel
# 544547                          pemetrexed
# 544548         sterile water for injection
# 544549         sterile water for injection
#
#                                     condition
# 0              progressive supranuclear palsy
# 1                                    pruritus
# 3                                fibromyalgia
# 4                relapsing multiple sclerosis
# 5                              retinoblastoma
# ...                                       ...
# 544545  first line non-small cell lung cancer
# 544546  first line non-small cell lung cancer
# 544547  first line non-small cell lung cancer
# 544548                       pneumonia, viral
# 544549       pneumonia, ventilator-associated
#
# [470240 rows x 8 columns]

# %%
ct['condition_outside_()'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['condition']]
ct['condition_inside_()'] = ct['condition'].str.extract(r"\((.*?)\)", expand=True)

ct['treatment_outside_()'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['treatment']]
ct['treatment_inside_()'] = ct['treatment'].str.extract(r"\((.*?)\)", expand=True)

split_chars = [",", "+", "/", " and ", "&", " or "]
split_chars = [re.escape(char) for char in split_chars]

# Function to split column based on list of characters
def split_column(df, column, split_chars):
    # Create a temporary dataframe to store split values
    temp_df = df[column].str.split('|'.join(split_chars), expand=True)
    # Rename columns of the temporary dataframe
    temp_df.columns = [f'{column}_{i+1}' for i in range(temp_df.shape[1])]
    return temp_df

# Apply split_column function to the desired column
split_con_outside = split_column(ct, 'condition_outside_()', split_chars)
split_con_inside = split_column(ct, 'condition_inside_()', split_chars)
split_trmnt_outside = split_column(ct, 'treatment_outside_()', split_chars)
split_trmnt_inside = split_column(ct, 'treatment_inside_()', split_chars)

# Concatenate the split dataframe with the original dataframe
split_df = pd.concat([split_con_outside, split_con_inside, split_trmnt_outside, split_trmnt_inside], axis=1)
split_df = split_df.fillna(np.nan).replace([np.nan], [None]) # replace NaN values in dataframe with None (just for consistency)
split_df = pd.concat([ct["condition"], ct["treatment"], split_df], axis=1)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(split_df[:100])
# Out:
#                                                condition  \
# 0                         Progressive Supranuclear Palsy
# 1                                               Pruritus
# 2                                           Fibromyalgia
# 3                           Relapsing Multiple Sclerosis
# 4                                         Retinoblastoma
# 5                                                Healthy
# 6                              Pancreatic Adenocarcinoma
# 7                              Pancreatic Adenocarcinoma
# 8                              Pancreatic Adenocarcinoma
# 9                            Smoldering Multiple Myeloma
# 10                           Smoldering Multiple Myeloma
# 11                           Smoldering Multiple Myeloma
# 12                           Smoldering Multiple Myeloma
# 13                                                Asthma
# 14                                       Prostate Cancer
# 15                               Acute Coronary Syndrome
# 16                                       Cervical Cancer
# 17                                       Cervical Cancer
# 18                                       Cervical Cancer
# 19                                       Cervical Cancer
# 20                                          Osteosarcoma
# 21                                       Newly Diagnosed
# 22                                       Newly Diagnosed
# 23                            Small Lymphocytic Lymphoma
# 24                            Small Lymphocytic Lymphoma
# 25                          Chronic Lymphocytic Leukemia
# 26                          Chronic Lymphocytic Leukemia
# 27                                          Hypertension
# 28                                          Hypertension
# 29                                          Osteoporosis
# 30                                      Multiple Myeloma
# 31                                  Head and Neck Cancer
# 32                                  Head and Neck Cancer
# 33                                  Head and Neck Cancer
# 34                                  Head and Neck Cancer
# 35                                  Head and Neck Cancer
# 36                         Obsessive-Compulsive Disorder
# 37                                            Sintilimab
# 38                                            Sintilimab
# 39                                            Sintilimab
# 40                                            Lenvatinib
# 41                                            Lenvatinib
# 42                                            Lenvatinib
# 43                              Hepatocellular Carcinoma
# 44                              Hepatocellular Carcinoma
# 45                              Hepatocellular Carcinoma
# 46                                         Submental Fat
# 47                                            Cystinuria
# 48                                   Alzheimer's Disease
# 49                        Treatment-resistant Depression
# 50                                         Spinal Fusion
# 51  Relapsed or Refractory B-cell Non-Hodgkin's Lymphoma
# 52                                         Rectal Cancer
# 53                                         Rectal Cancer
# 54                                      Multiple Myeloma
# 55                                         Haemophilia A
# 56                                 Advanced Solid Tumors
# 57                                               Healthy
# 58                                               Healthy
# 59   Relapsed or Refractory Acute Lymphoblastic Leukemia
# 60                                         Schizophrenia
# 61                                              Covid-19
# 62                                             Sars-CoV2
# 63                                    Alcohol Withdrawal
# 64                                              COVID-19
# 65                                              Vitiligo
# 66                                              Melanoma
# 67                                              Melanoma
# 68                                              Melanoma
# 69                                              Melanoma
# 70                                  Hepatitis B, Chronic
# 71                                     Hepatitis B Virus
# 72                                        Abdominal Pain
# 73                                          Hypogonadism
# 74                                          Hypogonadism
# 75                        Generalized Pustular Psoriasis
# 76                        Generalized Pustular Psoriasis
# 77                                      Multiple Myeloma
# 78                                      Multiple Myeloma
# 79                          Systemic Lupus Erythematosus
# 80                            Non-small Cell Lung Cancer
# 81                                            Xerostomia
# 82                                        Hyposalivation
# 83                                            Stem Cells
# 84                                             Dry Mouth
# 85                                     Oropharynx Cancer
# 86                                Mesenchymal Stem Cells
# 87                                              Melanoma
# 88                                              Melanoma
# 89                                      Neuropathic Pain
# 90                                 Salivary Gland Tumors
# 91                                 Salivary Gland Tumors
# 92                                 Salivary Gland Tumors
# 93                                 Salivary Gland Tumors
# 94                                    Systemic Sclerosis
# 95        Posterior Lumbosacral Spine Fixation Surgeries
# 96        Posterior Lumbosacral Spine Fixation Surgeries
# 97                                          Polycythemia
# 98                          Metastatic Colorectal Cancer
# 99                                     Venous Thrombosis
#
#                                                                                  treatment  \
# 0                                                                               tideglusib
# 1                                                                        N-acetyl cysteine
# 2                                                                               Pregabalin
# 3                                                                                  CNM-Au8
# 4                                                       Melphalan or Melphalan + Topotecan
# 5                                                                                   GS-248
# 6                                                                              Gemcitabine
# 7                                                                           Nab paclitaxel
# 8                                                                          NovoTTF-200T(P)
# 9                                                                             Citarinostat
# 10                                                                                Hiltonol
# 11                                                                            Lenalidomide
# 12                                                                                 PVX-410
# 13                                                                                   GB001
# 14                                                                               degarelix
# 15                                                                             Tafolecimab
# 16                                                                   Amifostine trihydrate
# 17                                                                               Cisplatin
# 18                                                         External beam radiation therapy
# 19                                                             Intracavitary brachytherapy
# 20                                                           Methotrexate,Calcium folinate
# 21                               Zanubrutinib, Fludarabine, cyclophosphamide and rituximab
# 22                                                   Zanubrutinib, bendamustine, rituximab
# 23                               Zanubrutinib, Fludarabine, cyclophosphamide and rituximab
# 24                                                   Zanubrutinib, bendamustine, rituximab
# 25                               Zanubrutinib, Fludarabine, cyclophosphamide and rituximab
# 26                                                   Zanubrutinib, bendamustine, rituximab
# 27  Dual combination of standard dose therapy→ Quadruple combination of half doses therapy
# 28   Quadruple combination of half doses therapy→Dual combination of standard dose therapy
# 29                                                                  SMC021 Oral calcitonin
# 30                                                                              Iberdomide
# 31                                                                           5Fluorouracil
# 32                                                                             Carboplatin
# 33                                                                              Paclitaxel
# 34                                                                           Pembrolizumab
# 35                                                                              Pemetrexed
# 36                                                                  N-Acetylcysteine (NAC)
# 37                                                                              Lenvatinib
# 38                                                                              Sintilimab
# 39                                                                               bTAE-HAIC
# 40                                                                              Lenvatinib
# 41                                                                              Sintilimab
# 42                                                                               bTAE-HAIC
# 43                                                                              Lenvatinib
# 44                                                                              Sintilimab
# 45                                                                               bTAE-HAIC
# 46                                                                                   MT921
# 47                                                                           Dapagliflozin
# 48                                                                   AAB-003 (PF-05236812)
# 49                                                                        Psilocybin 25 mg
# 50                                                                                 EXPAREL
# 51                                                                       BAFFR-CAR T cells
# 52                                                 Capecitabine, Oxaliplatin and Cetuximab
# 53                                                                               Radiation
# 54                                                                               Masitinib
# 55                                                                   turoctocog alfa pegol
# 56                                                                                ABBV-085
# 57                                                       Treatment A: Canagliflozin 100 mg
# 58                                                       Treatment B: Canagliflozin 300 mg
# 59                                                                   single dose of CNCT19
# 60                                                                             minocycline
# 61                                                                           RUTI® vaccine
# 62                                                                           RUTI® vaccine
# 63                                                                                Prazosin
# 64                                                Recombinant COVID-19 vaccine (Sf9 cells)
# 65                                                                               Ibuprofen
# 66                                                                             Aldesleukin
# 67                                                                        Cyclophosphamide
# 68                                                              DMF5 Melanoma Reactive TIL
# 69                                                                             Fludarabine
# 70                                                                       AHB-137 injection
# 71                                                               Peginterferon + Vitamin D
# 72                                                                          Peppermint oil
# 73                                              Vitamin D supplementation in eugonadal men
# 74                                            Vitamin D supplementation in hypogonadal men
# 75                                                                   Imsidolimab high dose
# 76                                                                    Imsidolimab low dose
# 77                                                                            bendamustine
# 78                                                                              bortezomib
# 79                                                                              Zishenqing
# 80                                                                Anlotinib Plus Docetaxel
# 81                                           Allogeneic adipose derived stem/stromal cells
# 82                                           Allogeneic adipose derived stem/stromal cells
# 83                                           Allogeneic adipose derived stem/stromal cells
# 84                                           Allogeneic adipose derived stem/stromal cells
# 85                                           Allogeneic adipose derived stem/stromal cells
# 86                                           Allogeneic adipose derived stem/stromal cells
# 87                                                                              bortezomib
# 88                                                                               sorafenib
# 89                                                                               Donepezil
# 90                                                                               Cisplatin
# 91                                                                               Docetaxel
# 92                                                        Intensity-modulated radiotherapy
# 93                                                                              Pemetrexed
# 94                                                     ADSVF application in the right hand
# 95                                                   Bupivacaine 0.25% Injectable Solution
# 96                                                               Dexmedetomidine injection
# 97                                                     Continuous positive airway pressure
# 98                                                                             regorafenib
# 99                                                                                Apixaban
#
#                             condition_outside_()_1  \
# 0                   Progressive Supranuclear Palsy
# 1                                         Pruritus
# 2                                     Fibromyalgia
# 3                     Relapsing Multiple Sclerosis
# 4                                   Retinoblastoma
# 5                                          Healthy
# 6                        Pancreatic Adenocarcinoma
# 7                        Pancreatic Adenocarcinoma
# 8                        Pancreatic Adenocarcinoma
# 9                      Smoldering Multiple Myeloma
# 10                     Smoldering Multiple Myeloma
# 11                     Smoldering Multiple Myeloma
# 12                     Smoldering Multiple Myeloma
# 13                                          Asthma
# 14                                 Prostate Cancer
# 15                         Acute Coronary Syndrome
# 16                                 Cervical Cancer
# 17                                 Cervical Cancer
# 18                                 Cervical Cancer
# 19                                 Cervical Cancer
# 20                                    Osteosarcoma
# 21                                 Newly Diagnosed
# 22                                 Newly Diagnosed
# 23                      Small Lymphocytic Lymphoma
# 24                      Small Lymphocytic Lymphoma
# 25                    Chronic Lymphocytic Leukemia
# 26                    Chronic Lymphocytic Leukemia
# 27                                    Hypertension
# 28                                    Hypertension
# 29                                    Osteoporosis
# 30                                Multiple Myeloma
# 31                                            Head
# 32                                            Head
# 33                                            Head
# 34                                            Head
# 35                                            Head
# 36                   Obsessive-Compulsive Disorder
# 37                                      Sintilimab
# 38                                      Sintilimab
# 39                                      Sintilimab
# 40                                      Lenvatinib
# 41                                      Lenvatinib
# 42                                      Lenvatinib
# 43                        Hepatocellular Carcinoma
# 44                        Hepatocellular Carcinoma
# 45                        Hepatocellular Carcinoma
# 46                                   Submental Fat
# 47                                      Cystinuria
# 48                             Alzheimer's Disease
# 49                  Treatment-resistant Depression
# 50                                   Spinal Fusion
# 51                                        Relapsed
# 52                                   Rectal Cancer
# 53                                   Rectal Cancer
# 54                                Multiple Myeloma
# 55                                   Haemophilia A
# 56                           Advanced Solid Tumors
# 57                                         Healthy
# 58                                         Healthy
# 59                                        Relapsed
# 60                                   Schizophrenia
# 61                                        Covid-19
# 62                                       Sars-CoV2
# 63                              Alcohol Withdrawal
# 64                                        COVID-19
# 65                                        Vitiligo
# 66                                        Melanoma
# 67                                        Melanoma
# 68                                        Melanoma
# 69                                        Melanoma
# 70                                     Hepatitis B
# 71                               Hepatitis B Virus
# 72                                  Abdominal Pain
# 73                                    Hypogonadism
# 74                                    Hypogonadism
# 75                  Generalized Pustular Psoriasis
# 76                  Generalized Pustular Psoriasis
# 77                                Multiple Myeloma
# 78                                Multiple Myeloma
# 79                    Systemic Lupus Erythematosus
# 80                      Non-small Cell Lung Cancer
# 81                                      Xerostomia
# 82                                  Hyposalivation
# 83                                      Stem Cells
# 84                                       Dry Mouth
# 85                               Oropharynx Cancer
# 86                          Mesenchymal Stem Cells
# 87                                        Melanoma
# 88                                        Melanoma
# 89                                Neuropathic Pain
# 90                           Salivary Gland Tumors
# 91                           Salivary Gland Tumors
# 92                           Salivary Gland Tumors
# 93                           Salivary Gland Tumors
# 94                              Systemic Sclerosis
# 95  Posterior Lumbosacral Spine Fixation Surgeries
# 96  Posterior Lumbosacral Spine Fixation Surgeries
# 97                                    Polycythemia
# 98                    Metastatic Colorectal Cancer
# 99                               Venous Thrombosis
#
#                       condition_outside_()_2 condition_outside_()_3  \
# 0                                       None                   None
# 1                                       None                   None
# 2                                       None                   None
# 3                                       None                   None
# 4                                       None                   None
# 5                                       None                   None
# 6                                       None                   None
# 7                                       None                   None
# 8                                       None                   None
# 9                                       None                   None
# 10                                      None                   None
# 11                                      None                   None
# 12                                      None                   None
# 13                                      None                   None
# 14                                      None                   None
# 15                                      None                   None
# 16                                      None                   None
# 17                                      None                   None
# 18                                      None                   None
# 19                                      None                   None
# 20                                      None                   None
# 21                                      None                   None
# 22                                      None                   None
# 23                                      None                   None
# 24                                      None                   None
# 25                                      None                   None
# 26                                      None                   None
# 27                                      None                   None
# 28                                      None                   None
# 29                                      None                   None
# 30                                      None                   None
# 31                               Neck Cancer                   None
# 32                               Neck Cancer                   None
# 33                               Neck Cancer                   None
# 34                               Neck Cancer                   None
# 35                               Neck Cancer                   None
# 36                                      None                   None
# 37                                      None                   None
# 38                                      None                   None
# 39                                      None                   None
# 40                                      None                   None
# 41                                      None                   None
# 42                                      None                   None
# 43                                      None                   None
# 44                                      None                   None
# 45                                      None                   None
# 46                                      None                   None
# 47                                      None                   None
# 48                                      None                   None
# 49                                      None                   None
# 50                                      None                   None
# 51  Refractory B-cell Non-Hodgkin's Lymphoma                   None
# 52                                      None                   None
# 53                                      None                   None
# 54                                      None                   None
# 55                                      None                   None
# 56                                      None                   None
# 57                                      None                   None
# 58                                      None                   None
# 59   Refractory Acute Lymphoblastic Leukemia                   None
# 60                                      None                   None
# 61                                      None                   None
# 62                                      None                   None
# 63                                      None                   None
# 64                                      None                   None
# 65                                      None                   None
# 66                                      None                   None
# 67                                      None                   None
# 68                                      None                   None
# 69                                      None                   None
# 70                                   Chronic                   None
# 71                                      None                   None
# 72                                      None                   None
# 73                                      None                   None
# 74                                      None                   None
# 75                                      None                   None
# 76                                      None                   None
# 77                                      None                   None
# 78                                      None                   None
# 79                                      None                   None
# 80                                      None                   None
# 81                                      None                   None
# 82                                      None                   None
# 83                                      None                   None
# 84                                      None                   None
# 85                                      None                   None
# 86                                      None                   None
# 87                                      None                   None
# 88                                      None                   None
# 89                                      None                   None
# 90                                      None                   None
# 91                                      None                   None
# 92                                      None                   None
# 93                                      None                   None
# 94                                      None                   None
# 95                                      None                   None
# 96                                      None                   None
# 97                                      None                   None
# 98                                      None                   None
# 99                                      None                   None
#
#    condition_outside_()_4 condition_outside_()_5 condition_outside_()_6  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 2                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
# 11                   None                   None                   None
# 12                   None                   None                   None
# 13                   None                   None                   None
# 14                   None                   None                   None
# 15                   None                   None                   None
# 16                   None                   None                   None
# 17                   None                   None                   None
# 18                   None                   None                   None
# 19                   None                   None                   None
# 20                   None                   None                   None
# 21                   None                   None                   None
# 22                   None                   None                   None
# 23                   None                   None                   None
# 24                   None                   None                   None
# 25                   None                   None                   None
# 26                   None                   None                   None
# 27                   None                   None                   None
# 28                   None                   None                   None
# 29                   None                   None                   None
# 30                   None                   None                   None
# 31                   None                   None                   None
# 32                   None                   None                   None
# 33                   None                   None                   None
# 34                   None                   None                   None
# 35                   None                   None                   None
# 36                   None                   None                   None
# 37                   None                   None                   None
# 38                   None                   None                   None
# 39                   None                   None                   None
# 40                   None                   None                   None
# 41                   None                   None                   None
# 42                   None                   None                   None
# 43                   None                   None                   None
# 44                   None                   None                   None
# 45                   None                   None                   None
# 46                   None                   None                   None
# 47                   None                   None                   None
# 48                   None                   None                   None
# 49                   None                   None                   None
# 50                   None                   None                   None
# 51                   None                   None                   None
# 52                   None                   None                   None
# 53                   None                   None                   None
# 54                   None                   None                   None
# 55                   None                   None                   None
# 56                   None                   None                   None
# 57                   None                   None                   None
# 58                   None                   None                   None
# 59                   None                   None                   None
# 60                   None                   None                   None
# 61                   None                   None                   None
# 62                   None                   None                   None
# 63                   None                   None                   None
# 64                   None                   None                   None
# 65                   None                   None                   None
# 66                   None                   None                   None
# 67                   None                   None                   None
# 68                   None                   None                   None
# 69                   None                   None                   None
# 70                   None                   None                   None
# 71                   None                   None                   None
# 72                   None                   None                   None
# 73                   None                   None                   None
# 74                   None                   None                   None
# 75                   None                   None                   None
# 76                   None                   None                   None
# 77                   None                   None                   None
# 78                   None                   None                   None
# 79                   None                   None                   None
# 80                   None                   None                   None
# 81                   None                   None                   None
# 82                   None                   None                   None
# 83                   None                   None                   None
# 84                   None                   None                   None
# 85                   None                   None                   None
# 86                   None                   None                   None
# 87                   None                   None                   None
# 88                   None                   None                   None
# 89                   None                   None                   None
# 90                   None                   None                   None
# 91                   None                   None                   None
# 92                   None                   None                   None
# 93                   None                   None                   None
# 94                   None                   None                   None
# 95                   None                   None                   None
# 96                   None                   None                   None
# 97                   None                   None                   None
# 98                   None                   None                   None
# 99                   None                   None                   None
#
#    condition_outside_()_7 condition_outside_()_8 condition_outside_()_9  \
# 0                    None                   None                   None
# 1                    None                   None                   None
# 2                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
# 5                    None                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8                    None                   None                   None
# 9                    None                   None                   None
# 10                   None                   None                   None
# 11                   None                   None                   None
# 12                   None                   None                   None
# 13                   None                   None                   None
# 14                   None                   None                   None
# 15                   None                   None                   None
# 16                   None                   None                   None
# 17                   None                   None                   None
# 18                   None                   None                   None
# 19                   None                   None                   None
# 20                   None                   None                   None
# 21                   None                   None                   None
# 22                   None                   None                   None
# 23                   None                   None                   None
# 24                   None                   None                   None
# 25                   None                   None                   None
# 26                   None                   None                   None
# 27                   None                   None                   None
# 28                   None                   None                   None
# 29                   None                   None                   None
# 30                   None                   None                   None
# 31                   None                   None                   None
# 32                   None                   None                   None
# 33                   None                   None                   None
# 34                   None                   None                   None
# 35                   None                   None                   None
# 36                   None                   None                   None
# 37                   None                   None                   None
# 38                   None                   None                   None
# 39                   None                   None                   None
# 40                   None                   None                   None
# 41                   None                   None                   None
# 42                   None                   None                   None
# 43                   None                   None                   None
# 44                   None                   None                   None
# 45                   None                   None                   None
# 46                   None                   None                   None
# 47                   None                   None                   None
# 48                   None                   None                   None
# 49                   None                   None                   None
# 50                   None                   None                   None
# 51                   None                   None                   None
# 52                   None                   None                   None
# 53                   None                   None                   None
# 54                   None                   None                   None
# 55                   None                   None                   None
# 56                   None                   None                   None
# 57                   None                   None                   None
# 58                   None                   None                   None
# 59                   None                   None                   None
# 60                   None                   None                   None
# 61                   None                   None                   None
# 62                   None                   None                   None
# 63                   None                   None                   None
# 64                   None                   None                   None
# 65                   None                   None                   None
# 66                   None                   None                   None
# 67                   None                   None                   None
# 68                   None                   None                   None
# 69                   None                   None                   None
# 70                   None                   None                   None
# 71                   None                   None                   None
# 72                   None                   None                   None
# 73                   None                   None                   None
# 74                   None                   None                   None
# 75                   None                   None                   None
# 76                   None                   None                   None
# 77                   None                   None                   None
# 78                   None                   None                   None
# 79                   None                   None                   None
# 80                   None                   None                   None
# 81                   None                   None                   None
# 82                   None                   None                   None
# 83                   None                   None                   None
# 84                   None                   None                   None
# 85                   None                   None                   None
# 86                   None                   None                   None
# 87                   None                   None                   None
# 88                   None                   None                   None
# 89                   None                   None                   None
# 90                   None                   None                   None
# 91                   None                   None                   None
# 92                   None                   None                   None
# 93                   None                   None                   None
# 94                   None                   None                   None
# 95                   None                   None                   None
# 96                   None                   None                   None
# 97                   None                   None                   None
# 98                   None                   None                   None
# 99                   None                   None                   None
#
#    condition_outside_()_10 condition_outside_()_11 condition_outside_()_12  \
# 0                     None                    None                    None
# 1                     None                    None                    None
# 2                     None                    None                    None
# 3                     None                    None                    None
# 4                     None                    None                    None
# 5                     None                    None                    None
# 6                     None                    None                    None
# 7                     None                    None                    None
# 8                     None                    None                    None
# 9                     None                    None                    None
# 10                    None                    None                    None
# 11                    None                    None                    None
# 12                    None                    None                    None
# 13                    None                    None                    None
# 14                    None                    None                    None
# 15                    None                    None                    None
# 16                    None                    None                    None
# 17                    None                    None                    None
# 18                    None                    None                    None
# 19                    None                    None                    None
# 20                    None                    None                    None
# 21                    None                    None                    None
# 22                    None                    None                    None
# 23                    None                    None                    None
# 24                    None                    None                    None
# 25                    None                    None                    None
# 26                    None                    None                    None
# 27                    None                    None                    None
# 28                    None                    None                    None
# 29                    None                    None                    None
# 30                    None                    None                    None
# 31                    None                    None                    None
# 32                    None                    None                    None
# 33                    None                    None                    None
# 34                    None                    None                    None
# 35                    None                    None                    None
# 36                    None                    None                    None
# 37                    None                    None                    None
# 38                    None                    None                    None
# 39                    None                    None                    None
# 40                    None                    None                    None
# 41                    None                    None                    None
# 42                    None                    None                    None
# 43                    None                    None                    None
# 44                    None                    None                    None
# 45                    None                    None                    None
# 46                    None                    None                    None
# 47                    None                    None                    None
# 48                    None                    None                    None
# 49                    None                    None                    None
# 50                    None                    None                    None
# 51                    None                    None                    None
# 52                    None                    None                    None
# 53                    None                    None                    None
# 54                    None                    None                    None
# 55                    None                    None                    None
# 56                    None                    None                    None
# 57                    None                    None                    None
# ...
# 79                  None                  None                  None
# 80                  None                  None                  None
# 81                  None                  None                  None
# 82                  None                  None                  None
# 83                  None                  None                  None
# 84                  None                  None                  None
# 85                  None                  None                  None
# 86                  None                  None                  None
# 87                  None                  None                  None
# 88                  None                  None                  None
# 89                  None                  None                  None
# 90                  None                  None                  None
# 91                  None                  None                  None
# 92                  None                  None                  None
# 93                  None                  None                  None
# 94                  None                  None                  None
# 95                  None                  None                  None
# 96                  None                  None                  None
# 97                  None                  None                  None
# 98                  None                  None                  None
# 99                  None                  None                  None
#
#    treatment_inside_()_4 treatment_inside_()_5 treatment_inside_()_6  \
# 0                   None                  None                  None
# 1                   None                  None                  None
# 2                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
# 11                  None                  None                  None
# 12                  None                  None                  None
# 13                  None                  None                  None
# 14                  None                  None                  None
# 15                  None                  None                  None
# 16                  None                  None                  None
# 17                  None                  None                  None
# 18                  None                  None                  None
# 19                  None                  None                  None
# 20                  None                  None                  None
# 21                  None                  None                  None
# 22                  None                  None                  None
# 23                  None                  None                  None
# 24                  None                  None                  None
# 25                  None                  None                  None
# 26                  None                  None                  None
# 27                  None                  None                  None
# 28                  None                  None                  None
# 29                  None                  None                  None
# 30                  None                  None                  None
# 31                  None                  None                  None
# 32                  None                  None                  None
# 33                  None                  None                  None
# 34                  None                  None                  None
# 35                  None                  None                  None
# 36                  None                  None                  None
# 37                  None                  None                  None
# 38                  None                  None                  None
# 39                  None                  None                  None
# 40                  None                  None                  None
# 41                  None                  None                  None
# 42                  None                  None                  None
# 43                  None                  None                  None
# 44                  None                  None                  None
# 45                  None                  None                  None
# 46                  None                  None                  None
# 47                  None                  None                  None
# 48                  None                  None                  None
# 49                  None                  None                  None
# 50                  None                  None                  None
# 51                  None                  None                  None
# 52                  None                  None                  None
# 53                  None                  None                  None
# 54                  None                  None                  None
# 55                  None                  None                  None
# 56                  None                  None                  None
# 57                  None                  None                  None
# 58                  None                  None                  None
# 59                  None                  None                  None
# 60                  None                  None                  None
# 61                  None                  None                  None
# 62                  None                  None                  None
# 63                  None                  None                  None
# 64                  None                  None                  None
# 65                  None                  None                  None
# 66                  None                  None                  None
# 67                  None                  None                  None
# 68                  None                  None                  None
# 69                  None                  None                  None
# 70                  None                  None                  None
# 71                  None                  None                  None
# 72                  None                  None                  None
# 73                  None                  None                  None
# 74                  None                  None                  None
# 75                  None                  None                  None
# 76                  None                  None                  None
# 77                  None                  None                  None
# 78                  None                  None                  None
# 79                  None                  None                  None
# 80                  None                  None                  None
# 81                  None                  None                  None
# 82                  None                  None                  None
# 83                  None                  None                  None
# 84                  None                  None                  None
# 85                  None                  None                  None
# 86                  None                  None                  None
# 87                  None                  None                  None
# 88                  None                  None                  None
# 89                  None                  None                  None
# 90                  None                  None                  None
# 91                  None                  None                  None
# 92                  None                  None                  None
# 93                  None                  None                  None
# 94                  None                  None                  None
# 95                  None                  None                  None
# 96                  None                  None                  None
# 97                  None                  None                  None
# 98                  None                  None                  None
# 99                  None                  None                  None
#
#    treatment_inside_()_7 treatment_inside_()_8 treatment_inside_()_9
# 0                   None                  None                  None
# 1                   None                  None                  None
# 2                   None                  None                  None
# 3                   None                  None                  None
# 4                   None                  None                  None
# 5                   None                  None                  None
# 6                   None                  None                  None
# 7                   None                  None                  None
# 8                   None                  None                  None
# 9                   None                  None                  None
# 10                  None                  None                  None
# 11                  None                  None                  None
# 12                  None                  None                  None
# 13                  None                  None                  None
# 14                  None                  None                  None
# 15                  None                  None                  None
# 16                  None                  None                  None
# 17                  None                  None                  None
# 18                  None                  None                  None
# 19                  None                  None                  None
# 20                  None                  None                  None
# 21                  None                  None                  None
# 22                  None                  None                  None
# 23                  None                  None                  None
# 24                  None                  None                  None
# 25                  None                  None                  None
# 26                  None                  None                  None
# 27                  None                  None                  None
# 28                  None                  None                  None
# 29                  None                  None                  None
# 30                  None                  None                  None
# 31                  None                  None                  None
# 32                  None                  None                  None
# 33                  None                  None                  None
# 34                  None                  None                  None
# 35                  None                  None                  None
# 36                  None                  None                  None
# 37                  None                  None                  None
# 38                  None                  None                  None
# 39                  None                  None                  None
# 40                  None                  None                  None
# 41                  None                  None                  None
# 42                  None                  None                  None
# 43                  None                  None                  None
# 44                  None                  None                  None
# 45                  None                  None                  None
# 46                  None                  None                  None
# 47                  None                  None                  None
# 48                  None                  None                  None
# 49                  None                  None                  None
# 50                  None                  None                  None
# 51                  None                  None                  None
# 52                  None                  None                  None
# 53                  None                  None                  None
# 54                  None                  None                  None
# 55                  None                  None                  None
# 56                  None                  None                  None
# 57                  None                  None                  None
# 58                  None                  None                  None
# 59                  None                  None                  None
# 60                  None                  None                  None
# 61                  None                  None                  None
# 62                  None                  None                  None
# 63                  None                  None                  None
# 64                  None                  None                  None
# 65                  None                  None                  None
# 66                  None                  None                  None
# 67                  None                  None                  None
# 68                  None                  None                  None
# 69                  None                  None                  None
# 70                  None                  None                  None
# 71                  None                  None                  None
# 72                  None                  None                  None
# 73                  None                  None                  None
# 74                  None                  None                  None
# 75                  None                  None                  None
# 76                  None                  None                  None
# 77                  None                  None                  None
# 78                  None                  None                  None
# 79                  None                  None                  None
# 80                  None                  None                  None
# 81                  None                  None                  None
# 82                  None                  None                  None
# 83                  None                  None                  None
# 84                  None                  None                  None
# 85                  None                  None                  None
# 86                  None                  None                  None
# 87                  None                  None                  None
# 88                  None                  None                  None
# 89                  None                  None                  None
# 90                  None                  None                  None
# 91                  None                  None                  None
# 92                  None                  None                  None
# 93                  None                  None                  None
# 94                  None                  None                  None
# 95                  None                  None                  None
# 96                  None                  None                  None
# 97                  None                  None                  None
# 98                  None                  None                  None
# 99                  None                  None                  None

# %%
split_df
# Out:
#                                     condition  \
# 0              progressive supranuclear palsy
# 1                                    pruritus
# 3                                fibromyalgia
# 4                relapsing multiple sclerosis
# 5                              retinoblastoma
# ...                                       ...
# 544545  first line non-small cell lung cancer
# 544546  first line non-small cell lung cancer
# 544547  first line non-small cell lung cancer
# 544548                       pneumonia, viral
# 544549       pneumonia, ventilator-associated
#
#                                  treatment  \
# 0                               tideglusib
# 1                        n-acetyl cysteine
# 3                               pregabalin
# 4                                  cnm-au8
# 5       melphalan or melphalan + topotecan
# ...                                    ...
# 544545                         gemcitabine
# 544546                          paclitaxel
# 544547                          pemetrexed
# 544548         sterile water for injection
# 544549         sterile water for injection
#
#                        condition_outside_()_1  condition_outside_()_2  \
# 0              progressive supranuclear palsy                    None
# 1                                    pruritus                    None
# 3                                fibromyalgia                    None
# 4                relapsing multiple sclerosis                    None
# 5                              retinoblastoma                    None
# ...                                       ...                     ...
# 544545  first line non-small cell lung cancer                    None
# 544546  first line non-small cell lung cancer                    None
# 544547  first line non-small cell lung cancer                    None
# 544548                              pneumonia                   viral
# 544549                              pneumonia   ventilator-associated
#
#        condition_outside_()_3 condition_outside_()_4 condition_outside_()_5  \
# 0                        None                   None                   None
# 1                        None                   None                   None
# 3                        None                   None                   None
# 4                        None                   None                   None
# 5                        None                   None                   None
# ...                       ...                    ...                    ...
# 544545                   None                   None                   None
# 544546                   None                   None                   None
# 544547                   None                   None                   None
# 544548                   None                   None                   None
# 544549                   None                   None                   None
#
#        condition_outside_()_6 condition_outside_()_7 condition_outside_()_8  \
# 0                        None                   None                   None
# 1                        None                   None                   None
# 3                        None                   None                   None
# 4                        None                   None                   None
# 5                        None                   None                   None
# ...                       ...                    ...                    ...
# 544545                   None                   None                   None
# 544546                   None                   None                   None
# 544547                   None                   None                   None
# 544548                   None                   None                   None
# 544549                   None                   None                   None
#
#         ... treatment_outside_()_16 treatment_inside_()_1  \
# 0       ...                    None                  None
# 1       ...                    None                  None
# 3       ...                    None                  None
# 4       ...                    None                  None
# 5       ...                    None                  None
# ...     ...                     ...                   ...
# 544545  ...                    None                  None
# 544546  ...                    None                  None
# 544547  ...                    None                  None
# 544548  ...                    None                  None
# 544549  ...                    None                  None
#
#        treatment_inside_()_2 treatment_inside_()_3 treatment_inside_()_4  \
# 0                       None                  None                  None
# 1                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# 5                       None                  None                  None
# ...                      ...                   ...                   ...
# 544545                  None                  None                  None
# 544546                  None                  None                  None
# 544547                  None                  None                  None
# 544548                  None                  None                  None
# 544549                  None                  None                  None
#
#        treatment_inside_()_5 treatment_inside_()_6 treatment_inside_()_7  \
# 0                       None                  None                  None
# 1                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# 5                       None                  None                  None
# ...                      ...                   ...                   ...
# 544545                  None                  None                  None
# 544546                  None                  None                  None
# 544547                  None                  None                  None
# 544548                  None                  None                  None
# 544549                  None                  None                  None
#
#        treatment_inside_()_8 treatment_inside_()_9
# 0                       None                  None
# 1                       None                  None
# 3                       None                  None
# 4                       None                  None
# 5                       None                  None
# ...                      ...                   ...
# 544545                  None                  None
# 544546                  None                  None
# 544547                  None                  None
# 544548                  None                  None
# 544549                  None                  None
#
# [470240 rows x 45 columns]

# %%
split_t = split_df.transpose()
split_t = split_t.apply(lambda x: x.mask(x.duplicated(), None))
split_df = split_t.transpose()
split_df
# Out:
#                                     condition  \
# 0              progressive supranuclear palsy
# 1                                    pruritus
# 3                                fibromyalgia
# 4                relapsing multiple sclerosis
# 5                              retinoblastoma
# ...                                       ...
# 544545  first line non-small cell lung cancer
# 544546  first line non-small cell lung cancer
# 544547  first line non-small cell lung cancer
# 544548                       pneumonia, viral
# 544549       pneumonia, ventilator-associated
#
#                                  treatment condition_outside_()_1  \
# 0                               tideglusib                   None
# 1                        n-acetyl cysteine                   None
# 3                               pregabalin                   None
# 4                                  cnm-au8                   None
# 5       melphalan or melphalan + topotecan                   None
# ...                                    ...                    ...
# 544545                         gemcitabine                   None
# 544546                          paclitaxel                   None
# 544547                          pemetrexed                   None
# 544548         sterile water for injection              pneumonia
# 544549         sterile water for injection              pneumonia
#
#         condition_outside_()_2 condition_outside_()_3 condition_outside_()_4  \
# 0                         None                   None                   None
# 1                         None                   None                   None
# 3                         None                   None                   None
# 4                         None                   None                   None
# 5                         None                   None                   None
# ...                        ...                    ...                    ...
# 544545                    None                   None                   None
# 544546                    None                   None                   None
# 544547                    None                   None                   None
# 544548                   viral                   None                   None
# 544549   ventilator-associated                   None                   None
#
#        condition_outside_()_5 condition_outside_()_6 condition_outside_()_7  \
# 0                        None                   None                   None
# 1                        None                   None                   None
# 3                        None                   None                   None
# 4                        None                   None                   None
# 5                        None                   None                   None
# ...                       ...                    ...                    ...
# 544545                   None                   None                   None
# 544546                   None                   None                   None
# 544547                   None                   None                   None
# 544548                   None                   None                   None
# 544549                   None                   None                   None
#
#        condition_outside_()_8  ... treatment_outside_()_16  \
# 0                        None  ...                    None
# 1                        None  ...                    None
# 3                        None  ...                    None
# 4                        None  ...                    None
# 5                        None  ...                    None
# ...                       ...  ...                     ...
# 544545                   None  ...                    None
# 544546                   None  ...                    None
# 544547                   None  ...                    None
# 544548                   None  ...                    None
# 544549                   None  ...                    None
#
#        treatment_inside_()_1 treatment_inside_()_2 treatment_inside_()_3  \
# 0                       None                  None                  None
# 1                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# 5                       None                  None                  None
# ...                      ...                   ...                   ...
# 544545                  None                  None                  None
# 544546                  None                  None                  None
# 544547                  None                  None                  None
# 544548                  None                  None                  None
# 544549                  None                  None                  None
#
#        treatment_inside_()_4 treatment_inside_()_5 treatment_inside_()_6  \
# 0                       None                  None                  None
# 1                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# 5                       None                  None                  None
# ...                      ...                   ...                   ...
# 544545                  None                  None                  None
# 544546                  None                  None                  None
# 544547                  None                  None                  None
# 544548                  None                  None                  None
# 544549                  None                  None                  None
#
#        treatment_inside_()_7 treatment_inside_()_8 treatment_inside_()_9
# 0                       None                  None                  None
# 1                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# 5                       None                  None                  None
# ...                      ...                   ...                   ...
# 544545                  None                  None                  None
# 544546                  None                  None                  None
# 544547                  None                  None                  None
# 544548                  None                  None                  None
# 544549                  None                  None                  None
#
# [470240 rows x 45 columns]

# %%
condition_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['condition']])] # find columns with "condition" in it 
treatment_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['treatment']])] # find columns with "treatment" in it 

def filter_sublist(sublist):
    return [x for x in sublist if x is not None and (not isinstance(x, float) or not np.isnan(x)) and len(x) >= 3]

condition_collections = split_df[condition_cols].values.tolist()
condition_collections = [filter_sublist(sublist) for sublist in condition_collections]

treatment_collections = split_df[treatment_cols].values.tolist()
treatment_collections = [filter_sublist(sublist) for sublist in treatment_collections]

# %%
ct["conditions_split"] = pd.Series(condition_collections)
ct["treatments_split"] = pd.Series(treatment_collections)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])
# Out:
#          nct_id primary_purpose       intervention_model start_month_year  \
# 0   NCT01049399       Treatment      Parallel Assignment          2009-12
# 1   NCT05287724       Treatment     Crossover Assignment        2022-6-19
# 3   NCT01432236       Treatment     Crossover Assignment          2011-10
# 4   NCT04626921       Treatment  Single Group Assignment       2020-10-22
# 5   NCT04681417       Treatment      Parallel Assignment        2021-3-25
# 6   NCT04036227       Treatment      Parallel Assignment         2019-7-3
# 7   NCT05624918       Treatment  Single Group Assignment           2024-4
# 8   NCT05624918       Treatment  Single Group Assignment           2024-4
# 9   NCT05624918       Treatment  Single Group Assignment           2024-4
# 10  NCT02886065      Prevention      Parallel Assignment         2017-3-7
#
#    is_fda_regulated_drug                       condition  \
# 0                      ?  Progressive Supranuclear Palsy
# 1                      t                        Pruritus
# 3                      ?                    Fibromyalgia
# 4                      t    Relapsing Multiple Sclerosis
# 5                      f                  Retinoblastoma
# 6                      f                         Healthy
# 7                      f       Pancreatic Adenocarcinoma
# 8                      f       Pancreatic Adenocarcinoma
# 9                      f       Pancreatic Adenocarcinoma
# 10                     t     Smoldering Multiple Myeloma
#
#                  predicate                           treatment  \
# 0   in_clinical_trials_for                          tideglusib
# 1   in_clinical_trials_for                   N-acetyl cysteine
# 3   in_clinical_trials_for                          Pregabalin
# 4   in_clinical_trials_for                             CNM-Au8
# 5   in_clinical_trials_for  Melphalan or Melphalan + Topotecan
# 6   in_clinical_trials_for                              GS-248
# 7   in_clinical_trials_for                         Gemcitabine
# 8   in_clinical_trials_for                      Nab paclitaxel
# 9   in_clinical_trials_for                     NovoTTF-200T(P)
# 10  in_clinical_trials_for                        Citarinostat
#
#                        treatment_lower                 condition_lower  \
# 0                           tideglusib  progressive supranuclear palsy
# 1                    n-acetyl cysteine                        pruritus
# 3                           pregabalin                    fibromyalgia
# 4                              cnm-au8    relapsing multiple sclerosis
# 5   melphalan or melphalan + topotecan                  retinoblastoma
# 6                               gs-248                         healthy
# 7                          gemcitabine       pancreatic adenocarcinoma
# 8                       nab paclitaxel       pancreatic adenocarcinoma
# 9                      novottf-200t(p)       pancreatic adenocarcinoma
# 10                        citarinostat     smoldering multiple myeloma
#
#               condition_outside_() condition_inside_()  \
# 0   progressive supranuclear palsy                 NaN
# 1                         pruritus                 NaN
# 3                     fibromyalgia                 NaN
# 4     relapsing multiple sclerosis                 NaN
# 5                   retinoblastoma                 NaN
# 6                          healthy                 NaN
# 7        pancreatic adenocarcinoma                 NaN
# 8        pancreatic adenocarcinoma                 NaN
# 9        pancreatic adenocarcinoma                 NaN
# 10     smoldering multiple myeloma                 NaN
#
#                   treatment_outside_() treatment_inside_()  \
# 0                           tideglusib                 NaN
# 1                    n-acetyl cysteine                 NaN
# 3                           pregabalin                 NaN
# 4                              cnm-au8                 NaN
# 5   melphalan or melphalan + topotecan                 NaN
# 6                               gs-248                 NaN
# 7                          gemcitabine                 NaN
# 8                       nab paclitaxel                 NaN
# 9                         novottf-200t                   p
# 10                        citarinostat                 NaN
#
#                     conditions_split  \
# 0   [progressive supranuclear palsy]
# 1                         [pruritus]
# 3     [relapsing multiple sclerosis]
# 4                   [retinoblastoma]
# 5                          [healthy]
# 6        [pancreatic adenocarcinoma]
# 7        [pancreatic adenocarcinoma]
# 8        [pancreatic adenocarcinoma]
# 9      [smoldering multiple myeloma]
# 10     [smoldering multiple myeloma]
#
#                                               treatments_split
# 0                                                 [tideglusib]
# 1                                          [n-acetyl cysteine]
# 3                                                    [cnm-au8]
# 4   [melphalan or melphalan + topotecan, melphalan, topotecan]
# 5                                                     [gs-248]
# 6                                                [gemcitabine]
# 7                                             [nab paclitaxel]
# 8                              [novottf-200t(p), novottf-200t]
# 9                                               [citarinostat]
# 10                                                  [hiltonol]

# %%
ct = ct.explode('conditions_split')
ct = ct.explode('treatments_split')
ct = ct.drop_duplicates(keep='first')
ct = ct.drop(["condition", "treatment", "condition_outside_()", "condition_inside_()", "treatment_outside_()", "treatment_inside_()"], axis=1).reset_index(drop=True)

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
#     display(ct[:100])

# %% [markdown]
# # Mapping CURIEs from cache to trials

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.conditions_split.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatments_split.map(interventions_dict)
ct = ct.drop_duplicates(keep='first')
ct

# %%
ct['condition_curie_info'] = ct.condition.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatment.map(interventions_dict)
ct

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])

# %%
temp = ct.copy()

# %%
ct = temp.copy()

# %%
ct['condition_outside_()'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['condition']]
ct['condition_inside_()'] = ct['condition'].str.extract(r"\((.*?)\)", expand=True)

ct['treatment_outside_()'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['treatment']]
ct['treatment_inside_()'] = ct['treatment'].str.extract(r"\((.*?)\)", expand=True)

split_chars = [",", "+", "/", " and ", "&", " or "]
split_chars = [re.escape(char) for char in split_chars]

# Function to split column based on list of characters
def split_column(df, column, split_chars):
    # Create a temporary dataframe to store split values
    temp_df = df[column].str.split('|'.join(split_chars), expand=True)
    # Rename columns of the temporary dataframe
    temp_df.columns = [f'{column}_{i+1}' for i in range(temp_df.shape[1])]
    return temp_df

# Apply split_column function to the desired column
split_con_outside = split_column(ct, 'condition_outside_()', split_chars)
split_con_inside = split_column(ct, 'condition_inside_()', split_chars)
split_trmnt_outside = split_column(ct, 'treatment_outside_()', split_chars)
split_trmnt_inside = split_column(ct, 'treatment_inside_()', split_chars)

# Concatenate the split dataframe with the original dataframe
split_df = pd.concat([split_con_outside, split_con_inside, split_trmnt_outside, split_trmnt_inside], axis=1)
split_df = split_df.fillna(np.nan).replace([np.nan], [None]) # replace NaN values in dataframe with None (just for consistency)
split_df = pd.concat([ct["condition"], ct["treatment"], split_df], axis=1)

# %%
split_df

# %%
split_t = split_df.transpose()
split_t = split_t.apply(lambda x: x.mask(x.duplicated(), None))
split_df = split_t.transpose()
split_df

# %%
condition_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['condition']])] # find columns with "condition" in it 
treatment_cols = [ele for ele in split_df.columns if any([substr in ele for substr in ['treatment']])] # find columns with "treatment" in it 

def filter_sublist(sublist):
    return [x for x in sublist if x is not None and (not isinstance(x, float) or not np.isnan(x))]

condition_collections = split_df[condition_cols].values.tolist()
condition_collections = [filter_sublist(sublist) for sublist in condition_collections]

treatment_collections = split_df[treatment_cols].values.tolist()
treatment_collections = [filter_sublist(sublist) for sublist in treatment_collections]

print(len(condition_collections))
print(len(treatment_collections))

# %%
ct["conditions_split"] = pd.Series(condition_collections)
ct["treatments_split"] = pd.Series(treatment_collections)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])

# %%
ct = ct.explode('conditions_split')
ct = ct.explode('treatments_split')
ct = ct.drop_duplicates(keep='first')
ct = ct.drop(["condition", "treatment", "condition_outside_()", "condition_inside_()", "treatment_outside_()", "treatment_inside_()"], axis=1).reset_index(drop=True)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(ct[:10])

# %% [markdown]
# #### Map CURIEs from mapper to ct dataframe

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.conditions_split.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatments_split.map(interventions_dict)
ct = ct.drop_duplicates(keep='first')
ct

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    # display(ct[78000:79000])
    display(ct[:10])

# %% [markdown]
# #### Map CURIEs from mapper to ct dataframe

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.condition.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatment.map(interventions_dict)
ct

# %%
ct.to_csv('test.csv', sep="\t", index=False, header=True)

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
#     display(split_df[55000:56000])

# %%
ct['condition_outside_p'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['condition']]
ct['condition_inside_p'] = ct['condition'].str.extract(r"\((.*?)\)", expand=True)

ct['treatment_outside_p'] =  [re.sub(r"\((.*?)\)",'', str(x)) for x in ct['treatment']]
ct['treatment_inside_p'] = ct['treatment'].str.extract(r"\((.*?)\)", expand=True)

ct['condition_outside_b'] =  [re.sub(r'\[([^\]]+)\]','', str(x)) for x in ct['condition']]
ct['condition_inside_b'] = ct['condition'].str.extract(r'\[([^\]]+)\]', expand=True)

ct['treatment_outside_b'] =  [re.sub(r'\[([^\]]+)\]','', str(x)) for x in ct['treatment']]
ct['treatment_inside_b'] = ct['treatment'].str.extract(r'\[([^\]]+)\]', expand=True)

split_chars = [",", "+", "/", " and ", "&", " or "]
split_chars = [re.escape(char) for char in split_chars]

# Function to split column based on list of characters
def split_column(df, column, split_chars):
    # Create a temporary dataframe to store split values
    temp_df = df[column].str.split('|'.join(split_chars), expand=True)
    # Rename columns of the temporary dataframe
    temp_df.columns = [f'{column}_{i+1}' for i in range(temp_df.shape[1])]
    return temp_df

# Apply split_column function to the desired column
split_con_outside_p = split_column(ct, 'condition_outside_p', split_chars)
split_con_inside_p = split_column(ct, 'condition_inside_p', split_chars)
split_trmnt_outside_p = split_column(ct, 'treatment_outside_p', split_chars)
split_trmnt_inside_p = split_column(ct, 'treatment_inside_p', split_chars)

split_con_outside_b = split_column(ct, 'condition_outside_b', split_chars)
split_con_inside_b = split_column(ct, 'condition_inside_b', split_chars)
split_trmnt_outside_b = split_column(ct, 'treatment_outside_b', split_chars)
split_trmnt_inside_b = split_column(ct, 'treatment_inside_b', split_chars)

# Concatenate the split dataframe with the original dataframe
split_df = pd.concat([split_con_outside_p, split_con_inside_p, split_trmnt_outside_p, split_trmnt_inside_p,
                     split_con_outside_b, split_con_inside_b, split_trmnt_outside_b, split_trmnt_inside_b], axis=1)
split_df = split_df.fillna(np.nan).replace([np.nan], [None]) # replace NaN values in dataframe with None (just for consistency)
split_df = pd.concat([ct["condition"], ct["treatment"], split_df], axis=1)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(split_df[-100:])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(split_df[55000:56000])

# %%
ct = pd.concat([ct, split_df], axis=1)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(split_df[55000:55010])

# %% [markdown]
# mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
# mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored']
# mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
# mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])
# mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
# mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored']
# mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
# mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])
# mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
# mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored']
# mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
# mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])
# mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
# mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored']
# mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
# mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])
# #### Map CURIEs from mapper to ct dataframe

# %%
mapping_cache = pd.read_csv("mapping_cache.tsv", sep='\t', index_col=False, header=0, dtype="object", on_bad_lines="skip")
mapping_cache = mapping_cache[mapping_cache['score'] != 'unscored'] 
mapping_cache["score"] = pd.to_numeric(mapping_cache["score"], errors='coerce')
mapping_cache = mapping_cache.sort_values(by=['clintrial_term', 'score'], ascending=[False, False])

# %%
idx = mapping_cache.groupby(['clintrial_term', 'term_type'])['score'].transform(max) == mapping_cache['score']
max_scores = mapping_cache[idx]
max_scores = max_scores[max_scores.score >= 70]
conditions_maxscores = max_scores[max_scores.term_type == "condition"]
interventions_maxscores = max_scores[max_scores.term_type == "intervention"]
alt_intervention_maxscores = max_scores[max_scores.term_type == "alternate_intervention"]

# %%
conditions_dict = dict(zip(conditions_maxscores.clintrial_term, conditions_maxscores.mapping_tool_response))
interventions_dict = dict(zip(interventions_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))
alt_intervention_dict = dict(zip(alt_intervention_maxscores.clintrial_term, interventions_maxscores.mapping_tool_response))

# %%
ct['condition_curie_info'] = ct.condition.map(conditions_dict)
ct['treatment_curie_info'] = ct.treatment.map(interventions_dict)
ct

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(ct[:10])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(ct[:10])

# %%
data = {} # data dictionary
pattern = "\((.*?)\)"

# df = pd.Series(data)
# new_data = {}

key = 0
for item in df.items():
    new_data[key] = re.match(pattern, item[1])[1]
    key += 1

print(new_data)
